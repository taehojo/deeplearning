# %% [markdown]
# [<img style="float: right;" src="https://raw.githubusercontent.com/taehojo/taehojo.github.io/master/assets/images/linktocolab.png" /> ](https://colab.research.google.com/github/taehojo/deeplearning_for_everyone_3rd/blob/master/run_project/19_GAN.ipynb)

# %% [markdown]
# # 19장 세상에 없는 얼굴 GAN, 오토인코더

# %% [markdown]
# ## 1. GAN 모델 만들기

# %%
from tensorflow.keras.datasets import mnist
from tensorflow.keras.layers import Input, Dense, Reshape, Flatten, Dropout
from tensorflow.keras.layers import BatchNormalization, Activation, LeakyReLU, UpSampling2D, Conv2D
from tensorflow.keras.models import Sequential, Model

import numpy as np
import matplotlib.pyplot as plt

#이미지가 저장될 폴더가 없다면 만듭니다.
import os
if not os.path.exists("../data/gan_images"):
    os.makedirs("../data/gan_images")

#생성자 모델을 만듭니다.
generator = Sequential()
generator.add(Dense(128*7*7, input_dim=100, activation=LeakyReLU(0.2)))
generator.add(BatchNormalization())
generator.add(Reshape((7, 7, 128)))
generator.add(UpSampling2D())
generator.add(Conv2D(64, kernel_size=5, padding='same'))
generator.add(BatchNormalization())
generator.add(Activation(LeakyReLU(0.2)))
generator.add(UpSampling2D())
generator.add(Conv2D(1, kernel_size=5, padding='same', activation='tanh'))

#판별자 모델을 만듭니다.
discriminator = Sequential()
discriminator.add(Conv2D(64, kernel_size=5, strides=2, input_shape=(28,28,1), padding="same"))
discriminator.add(Activation(LeakyReLU(0.2)))
discriminator.add(Dropout(0.3))
discriminator.add(Conv2D(128, kernel_size=5, strides=2, padding="same"))
discriminator.add(Activation(LeakyReLU(0.2)))
discriminator.add(Dropout(0.3))
discriminator.add(Flatten())
discriminator.add(Dense(1, activation='sigmoid'))
discriminator.compile(loss='binary_crossentropy', optimizer='adam')
discriminator.trainable = False

#생성자와 판별자 모델을 연결시키는 gan 모델을 만듭니다.
ginput = Input(shape=(100,))
dis_output = discriminator(generator(ginput))
gan = Model(ginput, dis_output)
gan.compile(loss='binary_crossentropy', optimizer='adam')
gan.summary()

#신경망을 실행시키는 함수를 만듭니다.
def gan_train(epoch, batch_size, saving_interval):

  # MNIST 데이터를 불러옵니다.

  (X_train, _), (_, _) = mnist.load_data()  # 앞서 불러온 적 있는 MNIST를 다시 이용합니다. 단, 테스트과정은 필요없고 이미지만 사용할 것이기 때문에 X_train만 불러왔습니다.
  X_train = X_train.reshape(X_train.shape[0], 28, 28, 1).astype('float32')
  X_train = (X_train - 127.5) / 127.5  # 픽셀값은 0에서 255사이의 값입니다. 이전에 255로 나누어 줄때는 이를 0~1사이의 값으로 바꾸었던 것인데, 여기서는 127.5를 빼준 뒤 127.5로 나누어 줌으로 인해 -1에서 1사이의 값으로 바뀌게 됩니다.
  #X_train.shape, Y_train.shape, X_test.shape, Y_test.shape

  true = np.ones((batch_size, 1))
  fake = np.zeros((batch_size, 1))

  for i in range(epoch):
          # 실제 데이터를 판별자에 입력하는 부분입니다.
          idx = np.random.randint(0, X_train.shape[0], batch_size)
          imgs = X_train[idx]
          d_loss_real = discriminator.train_on_batch(imgs, true)

          #가상 이미지를 판별자에 입력하는 부분입니다.
          noise = np.random.normal(0, 1, (batch_size, 100))
          gen_imgs = generator.predict(noise)
          d_loss_fake = discriminator.train_on_batch(gen_imgs, fake)

          #판별자와 생성자의 오차를 계산합니다.
          d_loss = 0.5 * np.add(d_loss_real, d_loss_fake)
          g_loss = gan.train_on_batch(noise, true)

          print('epoch:%d' % i, ' d_loss:%.4f' % d_loss, ' g_loss:%.4f' % g_loss)

        # 이부분은 중간 과정을 이미지로 저장해 주는 부분입니다. 본 장의 주요 내용과 관련이 없어
        # 소스코드만 첨부합니다. 만들어진 이미지들은 gan_images 폴더에 저장됩니다.
          if i % saving_interval == 0:
              #r, c = 5, 5
              noise = np.random.normal(0, 1, (25, 100))
              gen_imgs = generator.predict(noise)

              # Rescale images 0 - 1
              gen_imgs = 0.5 * gen_imgs + 0.5

              fig, axs = plt.subplots(5, 5)
              count = 0
              for j in range(5):
                  for k in range(5):
                      axs[j, k].imshow(gen_imgs[count, :, :, 0], cmap='gray')
                      axs[j, k].axis('off')
                      count += 1
              fig.savefig("../data/gan_images/gan_mnist_%d.png" % i)

gan_train(4001, 32, 200)  #4000번 반복되고(+1을 해 주는 것에 주의), 배치 사이즈는 32,  200번 마다 결과가 저장되게 하였습니다.
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 100)]             0
# _________________________________________________________________
# sequential (Sequential)      (None, 28, 28, 1)         865281
# _________________________________________________________________
# sequential_1 (Sequential)    (None, 1)                 212865
# =================================================================
# Total params: 1,078,146
# Trainable params: 852,609
# Non-trainable params: 225,537
# _________________________________________________________________
# epoch:0  d_loss:0.6903  g_loss:0.9217
# epoch:1  d_loss:0.4162  g_loss:1.0295
# epoch:2  d_loss:0.3839  g_loss:0.6518
# epoch:3  d_loss:0.3803  g_loss:0.3472
# epoch:4  d_loss:0.4102  g_loss:0.1492
# epoch:5  d_loss:0.4381  g_loss:0.1861
# epoch:6  d_loss:0.3361  g_loss:0.2118
# epoch:7  d_loss:0.4477  g_loss:0.1244
# epoch:8  d_loss:0.5314  g_loss:0.1001
# epoch:9  d_loss:0.7372  g_loss:0.0731
# epoch:10  d_loss:0.6447  g_loss:0.1442
# epoch:11  d_loss:0.6768  g_loss:0.3007
# epoch:12  d_loss:0.4746  g_loss:0.5848
# epoch:13  d_loss:0.4096  g_loss:0.8828
# epoch:14  d_loss:0.3171  g_loss:1.1217
# epoch:15  d_loss:0.2645  g_loss:1.0634
# epoch:16  d_loss:0.2049  g_loss:1.3382
# epoch:17  d_loss:0.1445  g_loss:1.7829
# epoch:18  d_loss:0.1035  g_loss:2.3341
# epoch:19  d_loss:0.2843  g_loss:2.6272
# epoch:20  d_loss:0.1157  g_loss:2.8795
# epoch:21  d_loss:0.2972  g_loss:3.5666
# epoch:22  d_loss:0.7570  g_loss:3.3538
# epoch:23  d_loss:0.6090  g_loss:2.9266
# epoch:24  d_loss:0.6653  g_loss:2.7068
# epoch:25  d_loss:0.4946  g_loss:2.3339
# epoch:26  d_loss:0.3922  g_loss:2.4249
# epoch:27  d_loss:0.2780  g_loss:2.7641
# epoch:28  d_loss:0.2894  g_loss:2.8296
# epoch:29  d_loss:0.3846  g_loss:2.4698
# epoch:30  d_loss:0.3415  g_loss:2.3672
# epoch:31  d_loss:0.3227  g_loss:2.6755
# epoch:32  d_loss:0.3687  g_loss:2.0454
# epoch:33  d_loss:0.4713  g_loss:1.8489
# epoch:34  d_loss:0.5600  g_loss:1.5758
# epoch:35  d_loss:0.4610  g_loss:1.6177
# epoch:36  d_loss:0.3864  g_loss:1.9650
# epoch:37  d_loss:0.3888  g_loss:2.3004
# epoch:38  d_loss:0.2496  g_loss:2.5653
# epoch:39  d_loss:0.1780  g_loss:2.3953
# epoch:40  d_loss:0.1373  g_loss:2.8014
# epoch:41  d_loss:0.1521  g_loss:3.1219
# epoch:42  d_loss:0.1198  g_loss:3.5705
# epoch:43  d_loss:0.2825  g_loss:2.8432
# epoch:44  d_loss:0.4062  g_loss:2.9912
# epoch:45  d_loss:0.7382  g_loss:3.8058
# epoch:46  d_loss:0.3751  g_loss:3.3896
# epoch:47  d_loss:0.9548  g_loss:2.5740
# epoch:48  d_loss:0.7021  g_loss:2.2272
# epoch:49  d_loss:0.4488  g_loss:3.0151
# epoch:50  d_loss:0.3323  g_loss:3.6602
# epoch:51  d_loss:0.5754  g_loss:2.3997
# epoch:52  d_loss:0.3885  g_loss:1.8427
# epoch:53  d_loss:0.5050  g_loss:2.0825
# epoch:54  d_loss:0.2952  g_loss:2.4787
# epoch:55  d_loss:0.3478  g_loss:2.9226
# epoch:56  d_loss:0.3355  g_loss:3.0092
# epoch:57  d_loss:0.3759  g_loss:2.1763
# epoch:58  d_loss:0.4670  g_loss:1.6839
# epoch:59  d_loss:0.3753  g_loss:1.4675
# epoch:60  d_loss:0.6063  g_loss:1.6692
# epoch:61  d_loss:0.4033  g_loss:1.6770
# epoch:62  d_loss:0.3945  g_loss:2.0029
# epoch:63  d_loss:0.3293  g_loss:2.1922
# epoch:64  d_loss:0.5050  g_loss:1.6665
# epoch:65  d_loss:0.3441  g_loss:1.5332
# epoch:66  d_loss:0.3771  g_loss:1.5297
# epoch:67  d_loss:0.2890  g_loss:1.5438
# epoch:68  d_loss:0.4109  g_loss:1.5378
# epoch:69  d_loss:0.3307  g_loss:2.2174
# epoch:70  d_loss:0.2473  g_loss:2.4761
# epoch:71  d_loss:0.3475  g_loss:2.1642
# epoch:72  d_loss:0.3969  g_loss:1.7153
# epoch:73  d_loss:0.5912  g_loss:1.4858
# epoch:74  d_loss:0.6238  g_loss:1.4704
# epoch:75  d_loss:0.3093  g_loss:2.1815
# epoch:76  d_loss:0.5195  g_loss:1.6125
# epoch:77  d_loss:0.6085  g_loss:1.5714
# epoch:78  d_loss:0.4194  g_loss:1.4956
# epoch:79  d_loss:0.4126  g_loss:1.8351
# epoch:80  d_loss:0.3430  g_loss:1.8758
# epoch:81  d_loss:0.5150  g_loss:1.9069
# epoch:82  d_loss:0.3831  g_loss:2.0657
# epoch:83  d_loss:0.5201  g_loss:1.8329
# epoch:84  d_loss:0.5550  g_loss:2.0842
# epoch:85  d_loss:0.4412  g_loss:2.1322
# epoch:86  d_loss:0.4999  g_loss:2.1230
# epoch:87  d_loss:0.5920  g_loss:1.8855
# epoch:88  d_loss:0.3368  g_loss:2.1270
# epoch:89  d_loss:0.4770  g_loss:2.1049
# epoch:90  d_loss:0.5745  g_loss:1.7270
# epoch:91  d_loss:0.4347  g_loss:1.7093
# epoch:92  d_loss:0.3685  g_loss:1.7063
# epoch:93  d_loss:0.2597  g_loss:2.3755
# epoch:94  d_loss:0.4038  g_loss:2.2533
# epoch:95  d_loss:0.2765  g_loss:2.0722
# epoch:96  d_loss:0.3995  g_loss:1.4803
# epoch:97  d_loss:0.1816  g_loss:2.0580
# epoch:98  d_loss:0.3847  g_loss:2.0925
# epoch:99  d_loss:0.2855  g_loss:2.0159
# epoch:100  d_loss:0.2862  g_loss:2.3936
# epoch:101  d_loss:0.3517  g_loss:2.2367
# epoch:102  d_loss:0.4896  g_loss:2.0141
# epoch:103  d_loss:0.5160  g_loss:2.0251
# epoch:104  d_loss:0.5476  g_loss:1.7662
# epoch:105  d_loss:0.5032  g_loss:1.6925
# epoch:106  d_loss:0.5296  g_loss:1.8485
# epoch:107  d_loss:0.5381  g_loss:1.7250
# epoch:108  d_loss:0.7054  g_loss:1.3912
# epoch:109  d_loss:0.6686  g_loss:1.3342
# epoch:110  d_loss:0.5366  g_loss:1.6744
# epoch:111  d_loss:0.4815  g_loss:1.8736
# epoch:112  d_loss:0.7459  g_loss:1.5646
# epoch:113  d_loss:0.7010  g_loss:1.6021
# epoch:114  d_loss:0.6060  g_loss:1.1600
# epoch:115  d_loss:0.5490  g_loss:1.2645
# epoch:116  d_loss:0.5433  g_loss:1.5743
# epoch:117  d_loss:0.6506  g_loss:1.5067
# epoch:118  d_loss:0.4967  g_loss:1.5241
# epoch:119  d_loss:0.6002  g_loss:1.3035
# epoch:120  d_loss:0.7047  g_loss:0.9422
# epoch:121  d_loss:0.5009  g_loss:1.1966
# epoch:122  d_loss:0.4451  g_loss:1.4218
# epoch:123  d_loss:0.4515  g_loss:1.4154
# epoch:124  d_loss:0.5553  g_loss:1.0594
# epoch:125  d_loss:0.4868  g_loss:1.0405
# epoch:126  d_loss:0.4504  g_loss:1.2187
# epoch:127  d_loss:0.4496  g_loss:1.3930
# epoch:128  d_loss:0.4791  g_loss:1.3461
# epoch:129  d_loss:0.5067  g_loss:1.5693
# epoch:130  d_loss:0.4625  g_loss:1.5012
# epoch:131  d_loss:0.6095  g_loss:1.2539
# epoch:132  d_loss:0.4963  g_loss:1.1852
# epoch:133  d_loss:0.5427  g_loss:1.3143
# epoch:134  d_loss:0.4824  g_loss:1.3116
# epoch:135  d_loss:0.5656  g_loss:1.7769
# epoch:136  d_loss:0.5449  g_loss:1.8293
# epoch:137  d_loss:0.8620  g_loss:1.4970
# epoch:138  d_loss:0.5789  g_loss:1.4586
# epoch:139  d_loss:0.5845  g_loss:1.6484
# epoch:140  d_loss:0.6603  g_loss:1.7193
# epoch:141  d_loss:0.7141  g_loss:1.7994
# epoch:142  d_loss:0.6659  g_loss:1.7167
# epoch:143  d_loss:0.5980  g_loss:2.0305
# epoch:144  d_loss:0.5333  g_loss:1.9826
# epoch:145  d_loss:0.5030  g_loss:1.8998
# epoch:146  d_loss:0.4662  g_loss:1.9757
# epoch:147  d_loss:0.4799  g_loss:1.8201
# epoch:148  d_loss:0.3738  g_loss:2.4942
# epoch:149  d_loss:0.4269  g_loss:2.3363
# epoch:150  d_loss:0.4750  g_loss:2.2857
# epoch:151  d_loss:0.3632  g_loss:2.2846
# epoch:152  d_loss:0.4842  g_loss:1.9273
# epoch:153  d_loss:0.3446  g_loss:2.2569
# epoch:154  d_loss:0.3336  g_loss:2.3465
# epoch:155  d_loss:0.3870  g_loss:2.0870
# epoch:156  d_loss:0.2594  g_loss:1.8830
# epoch:157  d_loss:0.4013  g_loss:1.7934
# epoch:158  d_loss:0.4541  g_loss:1.7178
# epoch:159  d_loss:0.2858  g_loss:2.0817
# epoch:160  d_loss:0.4085  g_loss:1.5847
# epoch:161  d_loss:0.4102  g_loss:2.0413
# epoch:162  d_loss:0.3602  g_loss:2.0426
# epoch:163  d_loss:0.4487  g_loss:2.1026
# epoch:164  d_loss:0.5472  g_loss:1.6415
# epoch:165  d_loss:0.4585  g_loss:1.5542
# epoch:166  d_loss:0.9732  g_loss:1.2153
# epoch:167  d_loss:0.4699  g_loss:1.9611
# epoch:168  d_loss:0.4758  g_loss:2.2345
# epoch:169  d_loss:0.7044  g_loss:2.0475
# epoch:170  d_loss:0.6948  g_loss:1.9093
# epoch:171  d_loss:0.7151  g_loss:1.6552
# epoch:172  d_loss:0.7614  g_loss:1.5428
# epoch:173  d_loss:0.6538  g_loss:1.8677
# epoch:174  d_loss:0.4958  g_loss:2.1884
# epoch:175  d_loss:0.6931  g_loss:2.3536
# epoch:176  d_loss:0.6863  g_loss:1.9957
# epoch:177  d_loss:0.5107  g_loss:2.0191
# epoch:178  d_loss:0.4938  g_loss:1.9467
# epoch:179  d_loss:0.4446  g_loss:1.8097
# epoch:180  d_loss:0.5091  g_loss:1.5513
# epoch:181  d_loss:0.3906  g_loss:2.0410
# epoch:182  d_loss:0.3943  g_loss:2.2695
# epoch:183  d_loss:0.3509  g_loss:2.0768
# epoch:184  d_loss:0.3837  g_loss:1.9253
# epoch:185  d_loss:0.2633  g_loss:2.0009
# epoch:186  d_loss:0.2044  g_loss:1.8731
# epoch:187  d_loss:0.3298  g_loss:1.8783
# epoch:188  d_loss:0.3307  g_loss:2.1427
# epoch:189  d_loss:0.2155  g_loss:2.1704
# epoch:190  d_loss:0.2620  g_loss:2.0101
# epoch:191  d_loss:0.3409  g_loss:2.0550
# epoch:192  d_loss:0.3893  g_loss:2.5813
# epoch:193  d_loss:0.2730  g_loss:2.7152
# epoch:194  d_loss:0.3002  g_loss:2.3136
# epoch:195  d_loss:0.4849  g_loss:1.7919
# epoch:196  d_loss:0.9132  g_loss:1.8669
# epoch:197  d_loss:0.8527  g_loss:1.2866
# epoch:198  d_loss:0.8022  g_loss:1.4765
# epoch:199  d_loss:0.7807  g_loss:2.2065
# epoch:200  d_loss:0.8263  g_loss:1.8308
# epoch:201  d_loss:1.0015  g_loss:1.7828
# epoch:202  d_loss:0.8428  g_loss:1.7225
# epoch:203  d_loss:1.0279  g_loss:1.5480
# epoch:204  d_loss:1.1100  g_loss:1.6834
# epoch:205  d_loss:0.8856  g_loss:1.7651
# epoch:206  d_loss:0.9867  g_loss:1.7100
# epoch:207  d_loss:0.8518  g_loss:1.7169
# epoch:208  d_loss:0.6400  g_loss:1.7310
# epoch:209  d_loss:0.6065  g_loss:1.7087
# epoch:210  d_loss:0.6120  g_loss:1.6014
# epoch:211  d_loss:0.4381  g_loss:1.9887
# epoch:212  d_loss:0.4676  g_loss:1.8916
# epoch:213  d_loss:0.4719  g_loss:2.0389
# epoch:214  d_loss:0.3594  g_loss:1.8200
# epoch:215  d_loss:0.3510  g_loss:1.8783
# epoch:216  d_loss:0.3071  g_loss:2.0151
# epoch:217  d_loss:0.2111  g_loss:2.5588
# epoch:218  d_loss:0.1943  g_loss:2.3822
# epoch:219  d_loss:0.2905  g_loss:2.3860
# epoch:220  d_loss:0.2330  g_loss:2.4938
# epoch:221  d_loss:0.1768  g_loss:2.3132
# epoch:222  d_loss:0.2169  g_loss:2.0811
# epoch:223  d_loss:0.2683  g_loss:2.7646
# epoch:224  d_loss:0.2169  g_loss:2.9049
# epoch:225  d_loss:0.1911  g_loss:3.0175
# epoch:226  d_loss:0.3203  g_loss:2.7630
# epoch:227  d_loss:0.2126  g_loss:2.4589
# epoch:228  d_loss:0.2778  g_loss:2.5029
# epoch:229  d_loss:0.3536  g_loss:2.7924
# epoch:230  d_loss:0.3607  g_loss:2.1037
# epoch:231  d_loss:0.3738  g_loss:2.2047
# epoch:232  d_loss:0.4599  g_loss:1.8382
# epoch:233  d_loss:0.3968  g_loss:2.5973
# epoch:234  d_loss:0.6329  g_loss:1.6628
# epoch:235  d_loss:0.6276  g_loss:2.0273
# epoch:236  d_loss:0.6148  g_loss:1.9390
# epoch:237  d_loss:0.6391  g_loss:1.5494
# epoch:238  d_loss:0.6813  g_loss:1.5365
# epoch:239  d_loss:0.6818  g_loss:1.6328
# epoch:240  d_loss:0.5706  g_loss:1.8587
# epoch:241  d_loss:0.8590  g_loss:1.8524
# epoch:242  d_loss:0.5825  g_loss:1.8543
# epoch:243  d_loss:0.6584  g_loss:1.8833
# epoch:244  d_loss:0.6725  g_loss:1.7468
# epoch:245  d_loss:0.6403  g_loss:2.1233
# epoch:246  d_loss:0.4038  g_loss:2.1912
# epoch:247  d_loss:0.5096  g_loss:2.1340
# epoch:248  d_loss:0.5374  g_loss:2.0812
# epoch:249  d_loss:0.4878  g_loss:2.1041
# epoch:250  d_loss:0.5473  g_loss:1.9911
# epoch:251  d_loss:0.4747  g_loss:2.2433
# epoch:252  d_loss:0.3960  g_loss:2.2740
# epoch:253  d_loss:0.4447  g_loss:2.3723
# epoch:254  d_loss:0.4139  g_loss:2.3311
# epoch:255  d_loss:0.3977  g_loss:2.2627
# epoch:256  d_loss:0.4390  g_loss:1.9908
# epoch:257  d_loss:0.4172  g_loss:2.1962
# epoch:258  d_loss:0.4498  g_loss:2.4387
# epoch:259  d_loss:0.3658  g_loss:2.5690
# epoch:260  d_loss:0.3929  g_loss:2.2882
# epoch:261  d_loss:0.3577  g_loss:2.0450
# epoch:262  d_loss:0.3510  g_loss:2.0272
# epoch:263  d_loss:0.2926  g_loss:2.3635
# epoch:264  d_loss:0.4398  g_loss:2.4521
# epoch:265  d_loss:0.2949  g_loss:2.6027
# epoch:266  d_loss:0.3987  g_loss:2.4112
# epoch:267  d_loss:0.5234  g_loss:1.9699
# epoch:268  d_loss:0.3116  g_loss:2.0500
# epoch:269  d_loss:0.3848  g_loss:2.1866
# epoch:270  d_loss:0.4688  g_loss:2.2471
# epoch:271  d_loss:0.4588  g_loss:2.2218
# epoch:272  d_loss:0.6093  g_loss:2.0762
# epoch:273  d_loss:0.4823  g_loss:2.0921
# epoch:274  d_loss:0.4777  g_loss:1.8838
# epoch:275  d_loss:0.4047  g_loss:2.0433
# epoch:276  d_loss:0.5657  g_loss:2.0044
# epoch:277  d_loss:0.5500  g_loss:2.6576
# epoch:278  d_loss:0.4097  g_loss:2.2805
# epoch:279  d_loss:0.5276  g_loss:1.9183
# epoch:280  d_loss:0.4627  g_loss:1.6855
# epoch:281  d_loss:0.5165  g_loss:1.7928
# epoch:282  d_loss:0.4121  g_loss:2.0355
# epoch:283  d_loss:0.6891  g_loss:1.7324
# epoch:284  d_loss:0.4834  g_loss:2.2038
# epoch:285  d_loss:0.5394  g_loss:2.4842
# epoch:286  d_loss:0.4371  g_loss:2.2546
# epoch:287  d_loss:0.5555  g_loss:1.8682
# epoch:288  d_loss:0.5520  g_loss:1.7096
# epoch:289  d_loss:0.6862  g_loss:1.5676
# epoch:290  d_loss:0.4422  g_loss:1.6833
# epoch:291  d_loss:0.4227  g_loss:1.9180
# epoch:292  d_loss:0.4844  g_loss:1.8189
# epoch:293  d_loss:0.3486  g_loss:2.6610
# epoch:294  d_loss:0.3085  g_loss:2.4124
# epoch:295  d_loss:0.4052  g_loss:2.0896
# epoch:296  d_loss:0.3614  g_loss:2.4490
# epoch:297  d_loss:0.3116  g_loss:2.6894
# epoch:298  d_loss:0.4608  g_loss:2.2329
# epoch:299  d_loss:0.3156  g_loss:2.2868
# epoch:300  d_loss:0.3287  g_loss:2.3538
# epoch:301  d_loss:0.5391  g_loss:2.6091
# epoch:302  d_loss:0.2837  g_loss:2.7869
# epoch:303  d_loss:0.4712  g_loss:2.9193
# epoch:304  d_loss:0.3384  g_loss:2.9379
# epoch:305  d_loss:0.3746  g_loss:2.8545
# epoch:306  d_loss:0.2757  g_loss:2.7998
# epoch:307  d_loss:0.5252  g_loss:2.4640
# epoch:308  d_loss:0.4333  g_loss:2.1838
# epoch:309  d_loss:0.5668  g_loss:2.2390
# epoch:310  d_loss:0.4576  g_loss:2.9300
# epoch:311  d_loss:0.7047  g_loss:2.9780
# epoch:312  d_loss:0.5442  g_loss:3.0160
# epoch:313  d_loss:0.8488  g_loss:2.4628
# epoch:314  d_loss:0.6136  g_loss:2.7796
# epoch:315  d_loss:0.6570  g_loss:2.5695
# epoch:316  d_loss:0.4324  g_loss:3.0266
# epoch:317  d_loss:0.6372  g_loss:2.6432
# epoch:318  d_loss:0.5424  g_loss:2.4679
# epoch:319  d_loss:0.4682  g_loss:2.3002
# epoch:320  d_loss:0.4794  g_loss:2.2408
# epoch:321  d_loss:0.3610  g_loss:2.6736
# epoch:322  d_loss:0.4706  g_loss:2.5791
# epoch:323  d_loss:0.3384  g_loss:3.0889
# epoch:324  d_loss:0.3327  g_loss:2.6907
# epoch:325  d_loss:0.3419  g_loss:2.6061
# epoch:326  d_loss:0.4146  g_loss:2.2998
# epoch:327  d_loss:0.3883  g_loss:2.3403
# epoch:328  d_loss:0.3360  g_loss:2.2944
# epoch:329  d_loss:0.2516  g_loss:2.1172
# epoch:330  d_loss:0.3218  g_loss:2.1234
# epoch:331  d_loss:0.2834  g_loss:2.6547
# epoch:332  d_loss:0.2290  g_loss:2.9336
# epoch:333  d_loss:0.2808  g_loss:2.5524
# epoch:334  d_loss:0.3787  g_loss:2.0708
# epoch:335  d_loss:0.2224  g_loss:2.6931
# epoch:336  d_loss:0.2583  g_loss:2.7623
# epoch:337  d_loss:0.3280  g_loss:2.4940
# epoch:338  d_loss:0.2025  g_loss:2.8426
# epoch:339  d_loss:0.2819  g_loss:2.8865
# epoch:340  d_loss:0.3981  g_loss:2.3696
# epoch:341  d_loss:0.3533  g_loss:2.3701
# epoch:342  d_loss:0.2235  g_loss:2.8262
# epoch:343  d_loss:0.2890  g_loss:2.3108
# epoch:344  d_loss:0.2937  g_loss:2.2768
# epoch:345  d_loss:0.2231  g_loss:2.2983
# epoch:346  d_loss:0.3157  g_loss:2.5042
# epoch:347  d_loss:0.2966  g_loss:2.5871
# epoch:348  d_loss:0.4111  g_loss:2.0030
# epoch:349  d_loss:0.3937  g_loss:2.1636
# epoch:350  d_loss:0.2975  g_loss:2.3793
# epoch:351  d_loss:0.2601  g_loss:2.5392
# epoch:352  d_loss:0.4577  g_loss:2.3519
# epoch:353  d_loss:0.4060  g_loss:2.1372
# epoch:354  d_loss:0.4101  g_loss:2.2685
# epoch:355  d_loss:0.5399  g_loss:2.0272
# epoch:356  d_loss:0.3921  g_loss:2.1206
# epoch:357  d_loss:0.4803  g_loss:1.7661
# epoch:358  d_loss:0.4635  g_loss:2.0653
# epoch:359  d_loss:0.4943  g_loss:2.4063
# epoch:360  d_loss:0.8070  g_loss:1.5230
# epoch:361  d_loss:0.5140  g_loss:1.9370
# epoch:362  d_loss:0.5722  g_loss:2.0177
# epoch:363  d_loss:0.8037  g_loss:2.1924
# epoch:364  d_loss:0.5188  g_loss:2.2397
# epoch:365  d_loss:0.5979  g_loss:2.3873
# epoch:366  d_loss:0.6376  g_loss:1.9717
# epoch:367  d_loss:0.4465  g_loss:2.5494
# epoch:368  d_loss:0.4998  g_loss:2.0673
# epoch:369  d_loss:0.5540  g_loss:1.8044
# epoch:370  d_loss:0.6905  g_loss:1.8784
# epoch:371  d_loss:0.7053  g_loss:1.7619
# epoch:372  d_loss:0.4290  g_loss:2.2811
# epoch:373  d_loss:0.3521  g_loss:2.2707
# epoch:374  d_loss:0.6421  g_loss:1.8871
# epoch:375  d_loss:0.4889  g_loss:1.5618
# epoch:376  d_loss:0.3495  g_loss:2.1363
# epoch:377  d_loss:0.3796  g_loss:2.2191
# epoch:378  d_loss:0.3472  g_loss:2.4664
# epoch:379  d_loss:0.4148  g_loss:1.8373
# epoch:380  d_loss:0.3515  g_loss:1.5618
# epoch:381  d_loss:0.3096  g_loss:1.8181
# epoch:382  d_loss:0.3100  g_loss:1.7060
# epoch:383  d_loss:0.2928  g_loss:2.2448
# epoch:384  d_loss:0.4002  g_loss:1.9996
# epoch:385  d_loss:0.3402  g_loss:2.5557
# epoch:386  d_loss:0.3803  g_loss:2.6237
# epoch:387  d_loss:0.4589  g_loss:2.0080
# epoch:388  d_loss:0.3298  g_loss:2.0245
# epoch:389  d_loss:0.3317  g_loss:2.3076
# epoch:390  d_loss:0.4582  g_loss:2.1040
# epoch:391  d_loss:0.3445  g_loss:2.3558
# epoch:392  d_loss:0.2746  g_loss:2.9366
# epoch:393  d_loss:0.3987  g_loss:2.5068
# epoch:394  d_loss:0.4991  g_loss:2.4972
# epoch:395  d_loss:0.4419  g_loss:1.8579
# epoch:396  d_loss:0.3904  g_loss:2.0823
# epoch:397  d_loss:0.5360  g_loss:1.5356
# epoch:398  d_loss:0.3773  g_loss:2.0607
# epoch:399  d_loss:0.4742  g_loss:2.2326
# epoch:400  d_loss:0.4432  g_loss:2.0192
# epoch:401  d_loss:0.3366  g_loss:2.3170
# epoch:402  d_loss:0.4577  g_loss:1.9679
# epoch:403  d_loss:0.4025  g_loss:1.9042
# epoch:404  d_loss:0.4374  g_loss:2.0007
# epoch:405  d_loss:0.4231  g_loss:1.5611
# epoch:406  d_loss:0.4587  g_loss:1.5573
# epoch:407  d_loss:0.3637  g_loss:2.0468
# epoch:408  d_loss:0.3247  g_loss:1.9899
# epoch:409  d_loss:0.3254  g_loss:2.5308
# epoch:410  d_loss:0.3558  g_loss:2.0214
# epoch:411  d_loss:0.3874  g_loss:2.0413
# epoch:412  d_loss:0.3946  g_loss:1.8603
# epoch:413  d_loss:0.3162  g_loss:1.7699
# epoch:414  d_loss:0.2990  g_loss:2.1722
# epoch:415  d_loss:0.2811  g_loss:2.2815
# epoch:416  d_loss:0.2478  g_loss:2.4419
# epoch:417  d_loss:0.2085  g_loss:2.8298
# epoch:418  d_loss:0.2322  g_loss:2.4071
# epoch:419  d_loss:0.2364  g_loss:2.5297
# epoch:420  d_loss:0.3306  g_loss:2.0451
# epoch:421  d_loss:0.2602  g_loss:2.4556
# epoch:422  d_loss:0.2351  g_loss:2.6846
# epoch:423  d_loss:0.3715  g_loss:2.8209
# epoch:424  d_loss:0.2801  g_loss:2.4618
# epoch:425  d_loss:0.2157  g_loss:2.8876
# epoch:426  d_loss:0.3567  g_loss:2.7992
# epoch:427  d_loss:0.2892  g_loss:2.5702
# epoch:428  d_loss:0.3413  g_loss:2.0654
# epoch:429  d_loss:0.4284  g_loss:2.3990
# epoch:430  d_loss:0.2956  g_loss:2.5912
# epoch:431  d_loss:0.3712  g_loss:2.6727
# epoch:432  d_loss:0.5758  g_loss:2.0059
# epoch:433  d_loss:0.4582  g_loss:1.7417
# epoch:434  d_loss:0.3379  g_loss:2.1514
# epoch:435  d_loss:0.4916  g_loss:2.0576
# epoch:436  d_loss:0.3921  g_loss:2.3865
# epoch:437  d_loss:0.6541  g_loss:1.7046
# epoch:438  d_loss:0.4726  g_loss:1.3969
# epoch:439  d_loss:0.3826  g_loss:2.0761
# epoch:440  d_loss:0.3795  g_loss:1.8731
# epoch:441  d_loss:0.4937  g_loss:2.4091
# epoch:442  d_loss:0.5347  g_loss:1.4191
# epoch:443  d_loss:0.5096  g_loss:1.8887
# epoch:444  d_loss:0.6178  g_loss:1.4945
# epoch:445  d_loss:0.4852  g_loss:1.8220
# epoch:446  d_loss:0.4089  g_loss:2.4963
# epoch:447  d_loss:0.4277  g_loss:2.5614
# epoch:448  d_loss:0.5757  g_loss:1.9552
# epoch:449  d_loss:0.3788  g_loss:1.7304
# epoch:450  d_loss:0.3605  g_loss:1.8443
# epoch:451  d_loss:0.3951  g_loss:2.2750
# epoch:452  d_loss:0.1898  g_loss:2.4447
# epoch:453  d_loss:0.3118  g_loss:2.6947
# epoch:454  d_loss:0.3255  g_loss:2.6204
# epoch:455  d_loss:0.4505  g_loss:1.8195
# epoch:456  d_loss:0.2859  g_loss:1.8646
# epoch:457  d_loss:0.2094  g_loss:2.3067
# epoch:458  d_loss:0.2573  g_loss:2.4153
# epoch:459  d_loss:0.2344  g_loss:3.1406
# epoch:460  d_loss:0.2608  g_loss:2.9195
# epoch:461  d_loss:0.2264  g_loss:3.0777
# epoch:462  d_loss:0.2461  g_loss:3.1517
# epoch:463  d_loss:0.2704  g_loss:2.1516
# epoch:464  d_loss:0.2159  g_loss:2.6506
# epoch:465  d_loss:0.2996  g_loss:2.4614
# epoch:466  d_loss:0.1918  g_loss:2.8104
# epoch:467  d_loss:0.1658  g_loss:2.9461
# epoch:468  d_loss:0.2964  g_loss:2.9051
# epoch:469  d_loss:0.2041  g_loss:2.7098
# epoch:470  d_loss:0.1981  g_loss:2.4180
# epoch:471  d_loss:0.2908  g_loss:2.4618
# epoch:472  d_loss:0.1902  g_loss:3.3240
# epoch:473  d_loss:0.2300  g_loss:3.4401
# epoch:474  d_loss:0.2746  g_loss:3.0118
# epoch:475  d_loss:0.4224  g_loss:1.9256
# epoch:476  d_loss:0.3503  g_loss:1.6996
# epoch:477  d_loss:0.2777  g_loss:2.7563
# epoch:478  d_loss:0.1514  g_loss:3.3841
# epoch:479  d_loss:0.3262  g_loss:3.1009
# epoch:480  d_loss:0.2910  g_loss:2.3234
# epoch:481  d_loss:0.3574  g_loss:2.3154
# epoch:482  d_loss:0.3422  g_loss:2.0192
# epoch:483  d_loss:0.2087  g_loss:2.6706
# epoch:484  d_loss:0.3003  g_loss:2.8865
# epoch:485  d_loss:0.2102  g_loss:2.5580
# epoch:486  d_loss:0.2329  g_loss:2.5230
# epoch:487  d_loss:0.2032  g_loss:2.2004
# epoch:488  d_loss:0.2304  g_loss:2.2615
# epoch:489  d_loss:0.2278  g_loss:2.7574
# epoch:490  d_loss:0.3101  g_loss:2.2913
# epoch:491  d_loss:0.2651  g_loss:1.9967
# epoch:492  d_loss:0.2244  g_loss:2.2122
# epoch:493  d_loss:0.2516  g_loss:2.5772
# epoch:494  d_loss:0.3177  g_loss:2.2348
# epoch:495  d_loss:0.2288  g_loss:2.8431
# epoch:496  d_loss:0.2909  g_loss:2.7106
# epoch:497  d_loss:0.2346  g_loss:2.5293
# epoch:498  d_loss:0.3340  g_loss:2.5009
# epoch:499  d_loss:0.1945  g_loss:2.7210
# epoch:500  d_loss:0.2057  g_loss:2.7314
# epoch:501  d_loss:0.2772  g_loss:2.6439
# epoch:502  d_loss:0.2421  g_loss:2.4235
# epoch:503  d_loss:0.2429  g_loss:2.6940
# epoch:504  d_loss:0.3108  g_loss:2.7286
# epoch:505  d_loss:0.2794  g_loss:2.4231
# epoch:506  d_loss:0.2161  g_loss:2.5660
# epoch:507  d_loss:0.2576  g_loss:2.6077
# epoch:508  d_loss:0.2019  g_loss:2.8545
# epoch:509  d_loss:0.2569  g_loss:2.3525
# epoch:510  d_loss:0.2545  g_loss:2.1415
# epoch:511  d_loss:0.3112  g_loss:2.3212
# epoch:512  d_loss:0.3438  g_loss:2.5211
# epoch:513  d_loss:0.1923  g_loss:2.8451
# epoch:514  d_loss:0.2441  g_loss:3.0995
# epoch:515  d_loss:0.3531  g_loss:2.3444
# epoch:516  d_loss:0.2079  g_loss:2.2793
# epoch:517  d_loss:0.2188  g_loss:2.6934
# epoch:518  d_loss:0.2865  g_loss:3.3448
# epoch:519  d_loss:0.2580  g_loss:3.2604
# epoch:520  d_loss:0.3293  g_loss:2.6243
# epoch:521  d_loss:0.2809  g_loss:2.3201
# epoch:522  d_loss:0.3477  g_loss:2.4981
# epoch:523  d_loss:0.3895  g_loss:2.8743
# epoch:524  d_loss:0.1657  g_loss:3.4368
# epoch:525  d_loss:0.1859  g_loss:3.4598
# epoch:526  d_loss:0.3072  g_loss:2.8142
# epoch:527  d_loss:0.3416  g_loss:2.0273
# epoch:528  d_loss:0.2059  g_loss:2.5895
# epoch:529  d_loss:0.1620  g_loss:3.0411
# epoch:530  d_loss:0.2039  g_loss:2.7488
# epoch:531  d_loss:0.2652  g_loss:2.6577
# epoch:532  d_loss:0.2399  g_loss:2.1971
# epoch:533  d_loss:0.1528  g_loss:2.1964
# epoch:534  d_loss:0.3121  g_loss:2.0474
# epoch:535  d_loss:0.2219  g_loss:3.0402
# epoch:536  d_loss:0.1638  g_loss:4.1504
# epoch:537  d_loss:0.2442  g_loss:3.3564
# epoch:538  d_loss:0.2269  g_loss:2.2026
# epoch:539  d_loss:0.1275  g_loss:2.2461
# epoch:540  d_loss:0.1635  g_loss:2.5602
# epoch:541  d_loss:0.1472  g_loss:2.8092
# epoch:542  d_loss:0.1507  g_loss:3.5637
# epoch:543  d_loss:0.1896  g_loss:3.5331
# epoch:544  d_loss:0.1589  g_loss:3.1793
# epoch:545  d_loss:0.1319  g_loss:3.0441
# epoch:546  d_loss:0.1303  g_loss:2.6637
# epoch:547  d_loss:0.1633  g_loss:2.6230
# epoch:548  d_loss:0.1411  g_loss:2.6278
# epoch:549  d_loss:0.1283  g_loss:2.8933
# epoch:550  d_loss:0.2054  g_loss:3.0678
# epoch:551  d_loss:0.1805  g_loss:2.7217
# epoch:552  d_loss:0.1472  g_loss:3.0102
# epoch:553  d_loss:0.1372  g_loss:2.8493
# epoch:554  d_loss:0.1459  g_loss:3.4017
# epoch:555  d_loss:0.1640  g_loss:2.9105
# epoch:556  d_loss:0.2007  g_loss:3.1265
# epoch:557  d_loss:0.1962  g_loss:3.1339
# epoch:558  d_loss:0.1918  g_loss:2.3432
# epoch:559  d_loss:0.1619  g_loss:2.5977
# epoch:560  d_loss:0.1494  g_loss:2.8805
# epoch:561  d_loss:0.1290  g_loss:2.8698
# epoch:562  d_loss:0.1065  g_loss:3.5326
# epoch:563  d_loss:0.2665  g_loss:2.7765
# epoch:564  d_loss:0.2949  g_loss:2.4520
# epoch:565  d_loss:0.2006  g_loss:2.3951
# epoch:566  d_loss:0.1596  g_loss:2.7150
# epoch:567  d_loss:0.2726  g_loss:3.1095
# epoch:568  d_loss:0.1435  g_loss:3.5087
# epoch:569  d_loss:0.1899  g_loss:3.3382
# epoch:570  d_loss:0.1962  g_loss:2.0605
# epoch:571  d_loss:0.2631  g_loss:2.2055
# epoch:572  d_loss:0.3097  g_loss:2.7538
# epoch:573  d_loss:0.1051  g_loss:3.7727
# epoch:574  d_loss:0.1401  g_loss:3.7264
# epoch:575  d_loss:0.2496  g_loss:2.8641
# epoch:576  d_loss:0.2022  g_loss:2.0757
# epoch:577  d_loss:0.2991  g_loss:2.3447
# epoch:578  d_loss:0.0950  g_loss:2.7898
# epoch:579  d_loss:0.1670  g_loss:3.4286
# epoch:580  d_loss:0.1776  g_loss:2.6357
# epoch:581  d_loss:0.2272  g_loss:2.5115
# epoch:582  d_loss:0.1984  g_loss:2.2579
# epoch:583  d_loss:0.2000  g_loss:2.9218
# epoch:584  d_loss:0.1441  g_loss:2.7016
# epoch:585  d_loss:0.2259  g_loss:2.8424
# epoch:586  d_loss:0.1386  g_loss:2.6632
# epoch:587  d_loss:0.1864  g_loss:2.7564
# epoch:588  d_loss:0.1440  g_loss:2.9392
# epoch:589  d_loss:0.2496  g_loss:2.4014
# epoch:590  d_loss:0.2174  g_loss:2.5679
# epoch:591  d_loss:0.1565  g_loss:2.9774
# epoch:592  d_loss:0.1974  g_loss:3.0488
# epoch:593  d_loss:0.2757  g_loss:2.7916
# epoch:594  d_loss:0.3274  g_loss:2.3207
# epoch:595  d_loss:0.2245  g_loss:1.9607
# epoch:596  d_loss:0.1480  g_loss:2.7989
# epoch:597  d_loss:0.1934  g_loss:2.9538
# epoch:598  d_loss:0.2067  g_loss:2.8326
# epoch:599  d_loss:0.1189  g_loss:3.0116
# epoch:600  d_loss:0.1811  g_loss:2.1885
# epoch:601  d_loss:0.1810  g_loss:2.4687
# epoch:602  d_loss:0.1565  g_loss:3.0088
# epoch:603  d_loss:0.1844  g_loss:2.8747
# epoch:604  d_loss:0.2121  g_loss:2.7451
# epoch:605  d_loss:0.2342  g_loss:2.0821
# epoch:606  d_loss:0.1395  g_loss:2.4947
# epoch:607  d_loss:0.1569  g_loss:3.5827
# epoch:608  d_loss:0.2114  g_loss:3.2507
# epoch:609  d_loss:0.2738  g_loss:2.4271
# epoch:610  d_loss:0.2280  g_loss:1.6263
# epoch:611  d_loss:0.2520  g_loss:2.4107
# epoch:612  d_loss:0.2490  g_loss:2.4787
# epoch:613  d_loss:0.1735  g_loss:3.3025
# epoch:614  d_loss:0.3281  g_loss:2.6374
# epoch:615  d_loss:0.2092  g_loss:2.4300
# epoch:616  d_loss:0.4135  g_loss:1.9672
# epoch:617  d_loss:0.2275  g_loss:1.9028
# epoch:618  d_loss:0.2062  g_loss:1.9937
# epoch:619  d_loss:0.2965  g_loss:2.2231
# epoch:620  d_loss:0.3567  g_loss:1.6531
# epoch:621  d_loss:0.2004  g_loss:2.2916
# epoch:622  d_loss:0.2554  g_loss:2.3132
# epoch:623  d_loss:0.2144  g_loss:2.6378
# epoch:624  d_loss:0.1934  g_loss:2.6777
# epoch:625  d_loss:0.2255  g_loss:2.1252
# epoch:626  d_loss:0.2999  g_loss:2.2934
# epoch:627  d_loss:0.1930  g_loss:2.6802
# epoch:628  d_loss:0.2109  g_loss:2.6780
# epoch:629  d_loss:0.3952  g_loss:1.9967
# epoch:630  d_loss:0.9497  g_loss:1.2100
# epoch:631  d_loss:0.2920  g_loss:1.8156
# epoch:632  d_loss:0.3867  g_loss:2.3914
# epoch:633  d_loss:0.3914  g_loss:2.5147
# epoch:634  d_loss:0.5524  g_loss:2.0374
# epoch:635  d_loss:0.7024  g_loss:1.0913
# epoch:636  d_loss:0.4912  g_loss:1.5323
# epoch:637  d_loss:0.3299  g_loss:2.4955
# epoch:638  d_loss:0.6949  g_loss:1.2863
# epoch:639  d_loss:1.0397  g_loss:0.6291
# epoch:640  d_loss:0.6640  g_loss:0.7595
# epoch:641  d_loss:0.4755  g_loss:2.2194
# epoch:642  d_loss:0.6469  g_loss:2.2237
# epoch:643  d_loss:1.0541  g_loss:1.2530
# epoch:644  d_loss:1.0625  g_loss:0.5740
# epoch:645  d_loss:0.9643  g_loss:0.9038
# epoch:646  d_loss:0.8642  g_loss:1.5640
# epoch:647  d_loss:1.0036  g_loss:1.4098
# epoch:648  d_loss:1.0494  g_loss:0.7311
# epoch:649  d_loss:0.5584  g_loss:0.9940
# epoch:650  d_loss:0.5482  g_loss:1.2836
# epoch:651  d_loss:0.5413  g_loss:1.2992
# epoch:652  d_loss:0.4935  g_loss:1.2570
# epoch:653  d_loss:0.7587  g_loss:1.0808
# epoch:654  d_loss:0.6048  g_loss:1.5730
# epoch:655  d_loss:0.5175  g_loss:1.8401
# epoch:656  d_loss:0.3575  g_loss:2.0610
# epoch:657  d_loss:0.5086  g_loss:1.5791
# epoch:658  d_loss:0.6172  g_loss:1.0886
# epoch:659  d_loss:0.6954  g_loss:0.7647
# epoch:660  d_loss:0.7749  g_loss:0.5094
# epoch:661  d_loss:0.5143  g_loss:1.1203
# epoch:662  d_loss:0.3273  g_loss:3.1437
# epoch:663  d_loss:0.2840  g_loss:3.8243
# epoch:664  d_loss:0.4861  g_loss:3.2572
# epoch:665  d_loss:0.5866  g_loss:1.8223
# epoch:666  d_loss:0.9284  g_loss:1.1974
# epoch:667  d_loss:1.0675  g_loss:1.4244
# epoch:668  d_loss:0.3711  g_loss:2.5483
# epoch:669  d_loss:0.4044  g_loss:3.8820
# epoch:670  d_loss:0.3196  g_loss:4.8368
# epoch:671  d_loss:0.2028  g_loss:5.0379
# epoch:672  d_loss:0.2341  g_loss:4.6377
# epoch:673  d_loss:0.4853  g_loss:3.7379
# epoch:674  d_loss:0.6706  g_loss:2.0955
# epoch:675  d_loss:1.1074  g_loss:0.7594
# epoch:676  d_loss:1.4241  g_loss:0.5577
# epoch:677  d_loss:1.3382  g_loss:1.0243
# epoch:678  d_loss:0.8114  g_loss:3.4285
# epoch:679  d_loss:0.8139  g_loss:4.8446
# epoch:680  d_loss:0.8634  g_loss:3.6991
# epoch:681  d_loss:0.5086  g_loss:3.2242
# epoch:682  d_loss:0.4899  g_loss:2.4399
# epoch:683  d_loss:0.5152  g_loss:2.2439
# epoch:684  d_loss:0.6540  g_loss:1.5052
# epoch:685  d_loss:0.8550  g_loss:1.2163
# epoch:686  d_loss:0.9012  g_loss:1.2594
# epoch:687  d_loss:0.6828  g_loss:1.4212
# epoch:688  d_loss:0.9532  g_loss:1.9343
# epoch:689  d_loss:1.1178  g_loss:2.1479
# epoch:690  d_loss:0.8871  g_loss:2.0524
# epoch:691  d_loss:0.6568  g_loss:2.3703
# epoch:692  d_loss:0.4900  g_loss:2.0954
# epoch:693  d_loss:0.4060  g_loss:2.4527
# epoch:694  d_loss:0.2797  g_loss:2.5368
# epoch:695  d_loss:0.3971  g_loss:2.6976
# epoch:696  d_loss:0.3418  g_loss:2.6213
# epoch:697  d_loss:0.2626  g_loss:2.4230
# epoch:698  d_loss:0.2072  g_loss:1.9952
# epoch:699  d_loss:0.2604  g_loss:2.2675
# epoch:700  d_loss:0.3355  g_loss:2.6272
# epoch:701  d_loss:0.2944  g_loss:2.6349
# epoch:702  d_loss:0.3538  g_loss:2.8115
# epoch:703  d_loss:0.4053  g_loss:3.0406
# epoch:704  d_loss:0.4255  g_loss:2.7887
# epoch:705  d_loss:0.3835  g_loss:2.3349
# epoch:706  d_loss:0.4672  g_loss:2.0818
# epoch:707  d_loss:0.7476  g_loss:1.2130
# epoch:708  d_loss:0.5813  g_loss:1.2364
# epoch:709  d_loss:0.6801  g_loss:1.0752
# epoch:710  d_loss:0.3624  g_loss:2.0547
# epoch:711  d_loss:0.6023  g_loss:2.1510
# epoch:712  d_loss:0.6213  g_loss:1.6657
# epoch:713  d_loss:0.3999  g_loss:1.2842
# epoch:714  d_loss:0.4585  g_loss:1.4545
# epoch:715  d_loss:0.3667  g_loss:1.2069
# epoch:716  d_loss:0.3768  g_loss:1.8322
# epoch:717  d_loss:0.2983  g_loss:2.5515
# epoch:718  d_loss:0.1912  g_loss:3.3617
# epoch:719  d_loss:0.2522  g_loss:3.2114
# epoch:720  d_loss:0.1556  g_loss:3.2645
# epoch:721  d_loss:0.1825  g_loss:3.2846
# epoch:722  d_loss:0.2720  g_loss:3.1324
# epoch:723  d_loss:0.2709  g_loss:2.7562
# epoch:724  d_loss:0.3509  g_loss:2.9185
# epoch:725  d_loss:0.3367  g_loss:3.2814
# epoch:726  d_loss:0.5334  g_loss:3.2415
# epoch:727  d_loss:0.3004  g_loss:2.8320
# epoch:728  d_loss:0.5346  g_loss:2.2929
# epoch:729  d_loss:0.4033  g_loss:2.1582
# epoch:730  d_loss:0.3261  g_loss:2.1888
# epoch:731  d_loss:0.3113  g_loss:2.4129
# epoch:732  d_loss:0.4618  g_loss:2.1362
# epoch:733  d_loss:0.3961  g_loss:2.0652
# epoch:734  d_loss:0.4976  g_loss:1.6984
# epoch:735  d_loss:0.3757  g_loss:2.1152
# epoch:736  d_loss:0.3355  g_loss:1.7966
# epoch:737  d_loss:0.3427  g_loss:2.0429
# epoch:738  d_loss:0.3843  g_loss:1.9139
# epoch:739  d_loss:0.4833  g_loss:2.1449
# epoch:740  d_loss:0.2940  g_loss:1.8094
# epoch:741  d_loss:0.2550  g_loss:2.0768
# epoch:742  d_loss:0.3255  g_loss:2.1994
# epoch:743  d_loss:0.3309  g_loss:2.5443
# epoch:744  d_loss:0.4000  g_loss:2.8585
# epoch:745  d_loss:0.4184  g_loss:2.7270
# epoch:746  d_loss:0.3455  g_loss:2.3808
# epoch:747  d_loss:0.5646  g_loss:1.8524
# epoch:748  d_loss:0.2519  g_loss:2.0350
# epoch:749  d_loss:0.2645  g_loss:1.6646
# epoch:750  d_loss:0.3974  g_loss:1.7548
# epoch:751  d_loss:0.3111  g_loss:2.3014
# epoch:752  d_loss:0.4429  g_loss:2.4094
# epoch:753  d_loss:0.2674  g_loss:2.4379
# epoch:754  d_loss:0.3391  g_loss:2.4137
# epoch:755  d_loss:0.4074  g_loss:1.6447
# epoch:756  d_loss:0.5038  g_loss:1.6494
# epoch:757  d_loss:0.4759  g_loss:1.3062
# epoch:758  d_loss:0.5153  g_loss:1.3200
# epoch:759  d_loss:0.4228  g_loss:1.3342
# epoch:760  d_loss:0.4627  g_loss:1.4450
# epoch:761  d_loss:0.4734  g_loss:1.5695
# epoch:762  d_loss:0.5385  g_loss:1.6063
# epoch:763  d_loss:0.4619  g_loss:1.4332
# epoch:764  d_loss:0.4365  g_loss:1.4799
# epoch:765  d_loss:0.3679  g_loss:1.9557
# epoch:766  d_loss:0.3521  g_loss:1.4470
# epoch:767  d_loss:0.4509  g_loss:1.4647
# epoch:768  d_loss:0.4046  g_loss:1.5466
# epoch:769  d_loss:0.2410  g_loss:1.8109
# epoch:770  d_loss:0.3853  g_loss:1.8041
# epoch:771  d_loss:0.2854  g_loss:2.4009
# epoch:772  d_loss:0.3696  g_loss:2.0453
# epoch:773  d_loss:0.3976  g_loss:1.8876
# epoch:774  d_loss:0.3611  g_loss:1.6578
# epoch:775  d_loss:0.4378  g_loss:1.7090
# epoch:776  d_loss:0.2801  g_loss:1.7478
# epoch:777  d_loss:0.3432  g_loss:1.8616
# epoch:778  d_loss:0.3479  g_loss:1.7549
# epoch:779  d_loss:0.5391  g_loss:1.7243
# epoch:780  d_loss:0.3649  g_loss:1.8518
# epoch:781  d_loss:0.4649  g_loss:1.6944
# epoch:782  d_loss:0.4998  g_loss:1.5206
# epoch:783  d_loss:0.4220  g_loss:1.7256
# epoch:784  d_loss:0.4067  g_loss:1.8356
# epoch:785  d_loss:0.4348  g_loss:1.7093
# epoch:786  d_loss:0.4757  g_loss:1.7843
# epoch:787  d_loss:0.4391  g_loss:1.4379
# epoch:788  d_loss:0.5097  g_loss:1.3663
# epoch:789  d_loss:0.4349  g_loss:1.4842
# epoch:790  d_loss:0.4945  g_loss:1.3904
# epoch:791  d_loss:0.3670  g_loss:1.5022
# epoch:792  d_loss:0.4492  g_loss:1.4070
# epoch:793  d_loss:0.5767  g_loss:1.2847
# epoch:794  d_loss:0.3551  g_loss:1.5887
# epoch:795  d_loss:0.4971  g_loss:1.2513
# epoch:796  d_loss:0.5429  g_loss:1.2094
# epoch:797  d_loss:0.4610  g_loss:1.0838
# epoch:798  d_loss:0.4477  g_loss:1.1440
# epoch:799  d_loss:0.4563  g_loss:1.2771
# epoch:800  d_loss:0.5636  g_loss:1.2585
# epoch:801  d_loss:0.5468  g_loss:1.2586
# epoch:802  d_loss:0.6102  g_loss:1.1328
# epoch:803  d_loss:0.5157  g_loss:1.1683
# epoch:804  d_loss:0.4495  g_loss:1.1864
# epoch:805  d_loss:0.4022  g_loss:1.5394
# epoch:806  d_loss:0.6343  g_loss:1.4154
# epoch:807  d_loss:0.4361  g_loss:1.5134
# epoch:808  d_loss:0.4844  g_loss:1.5302
# epoch:809  d_loss:0.4453  g_loss:2.0497
# epoch:810  d_loss:0.3540  g_loss:1.8672
# epoch:811  d_loss:0.3563  g_loss:2.0288
# epoch:812  d_loss:0.4052  g_loss:1.9780
# epoch:813  d_loss:0.6467  g_loss:1.9228
# epoch:814  d_loss:0.5697  g_loss:1.9249
# epoch:815  d_loss:0.4430  g_loss:1.6250
# epoch:816  d_loss:0.4902  g_loss:1.2149
# epoch:817  d_loss:0.5165  g_loss:1.3411
# epoch:818  d_loss:0.4393  g_loss:1.2745
# epoch:819  d_loss:0.4379  g_loss:1.5850
# epoch:820  d_loss:0.3815  g_loss:1.3828
# epoch:821  d_loss:0.5148  g_loss:1.8112
# epoch:822  d_loss:0.5117  g_loss:1.7325
# epoch:823  d_loss:0.5415  g_loss:1.4430
# epoch:824  d_loss:0.4608  g_loss:1.3999
# epoch:825  d_loss:0.5541  g_loss:1.0010
# epoch:826  d_loss:0.6159  g_loss:1.0568
# epoch:827  d_loss:0.5325  g_loss:1.0527
# epoch:828  d_loss:0.5246  g_loss:1.2465
# epoch:829  d_loss:0.6682  g_loss:1.1750
# epoch:830  d_loss:0.4838  g_loss:1.5559
# epoch:831  d_loss:0.6942  g_loss:1.5887
# epoch:832  d_loss:0.6413  g_loss:1.4286
# epoch:833  d_loss:0.4616  g_loss:1.3877
# epoch:834  d_loss:0.6301  g_loss:1.3647
# epoch:835  d_loss:0.6290  g_loss:1.2679
# epoch:836  d_loss:0.5098  g_loss:1.2496
# epoch:837  d_loss:0.5138  g_loss:1.3981
# epoch:838  d_loss:0.4353  g_loss:1.5927
# epoch:839  d_loss:0.3594  g_loss:2.0091
# epoch:840  d_loss:0.3657  g_loss:1.8827
# epoch:841  d_loss:0.4199  g_loss:1.9266
# epoch:842  d_loss:0.5553  g_loss:1.5727
# epoch:843  d_loss:0.3862  g_loss:1.8828
# epoch:844  d_loss:0.3703  g_loss:1.6366
# epoch:845  d_loss:0.4514  g_loss:1.5310
# epoch:846  d_loss:0.3322  g_loss:1.6236
# epoch:847  d_loss:0.4519  g_loss:1.8724
# epoch:848  d_loss:0.3732  g_loss:2.0877
# epoch:849  d_loss:0.5569  g_loss:2.1907
# epoch:850  d_loss:0.5496  g_loss:1.6415
# epoch:851  d_loss:0.5293  g_loss:1.7271
# epoch:852  d_loss:0.4643  g_loss:1.3662
# epoch:853  d_loss:0.4181  g_loss:1.7788
# epoch:854  d_loss:0.3514  g_loss:1.8733
# epoch:855  d_loss:0.4142  g_loss:2.1666
# epoch:856  d_loss:0.4279  g_loss:2.2266
# epoch:857  d_loss:0.4942  g_loss:2.0707
# epoch:858  d_loss:0.4323  g_loss:1.6364
# epoch:859  d_loss:0.3298  g_loss:2.0841
# epoch:860  d_loss:0.3203  g_loss:1.9258
# epoch:861  d_loss:0.3462  g_loss:2.0473
# epoch:862  d_loss:0.3188  g_loss:1.8224
# epoch:863  d_loss:0.1990  g_loss:2.0660
# epoch:864  d_loss:0.2091  g_loss:2.3400
# epoch:865  d_loss:0.3715  g_loss:2.2106
# epoch:866  d_loss:0.3007  g_loss:2.6338
# epoch:867  d_loss:0.2421  g_loss:2.4927
# epoch:868  d_loss:0.3021  g_loss:2.4333
# epoch:869  d_loss:0.3867  g_loss:2.2112
# epoch:870  d_loss:0.2648  g_loss:2.4696
# epoch:871  d_loss:0.3708  g_loss:2.1881
# epoch:872  d_loss:0.4027  g_loss:2.3830
# epoch:873  d_loss:0.3687  g_loss:2.0571
# epoch:874  d_loss:0.4797  g_loss:1.3834
# epoch:875  d_loss:0.4374  g_loss:1.7186
# epoch:876  d_loss:0.3772  g_loss:1.9679
# epoch:877  d_loss:0.4675  g_loss:2.6492
# epoch:878  d_loss:0.3851  g_loss:2.7363
# epoch:879  d_loss:0.3823  g_loss:2.2577
# epoch:880  d_loss:0.3588  g_loss:1.8329
# epoch:881  d_loss:0.5119  g_loss:1.6128
# epoch:882  d_loss:0.5292  g_loss:1.6341
# epoch:883  d_loss:0.4285  g_loss:1.5491
# epoch:884  d_loss:0.3626  g_loss:2.0717
# epoch:885  d_loss:0.4025  g_loss:1.8809
# epoch:886  d_loss:0.4475  g_loss:1.8039
# epoch:887  d_loss:0.6192  g_loss:1.4142
# epoch:888  d_loss:0.3907  g_loss:1.6193
# epoch:889  d_loss:0.5149  g_loss:1.8249
# epoch:890  d_loss:0.4633  g_loss:1.8293
# epoch:891  d_loss:0.5922  g_loss:1.3312
# epoch:892  d_loss:0.4274  g_loss:1.5155
# epoch:893  d_loss:0.6100  g_loss:1.4400
# epoch:894  d_loss:0.5528  g_loss:1.4697
# epoch:895  d_loss:0.4468  g_loss:1.5215
# epoch:896  d_loss:0.4437  g_loss:2.0072
# epoch:897  d_loss:0.4308  g_loss:1.8229
# epoch:898  d_loss:0.4159  g_loss:1.7847
# epoch:899  d_loss:0.5011  g_loss:1.7123
# epoch:900  d_loss:0.5176  g_loss:1.6454
# epoch:901  d_loss:0.5257  g_loss:1.4451
# epoch:902  d_loss:0.4356  g_loss:1.6087
# epoch:903  d_loss:0.3707  g_loss:2.0404
# epoch:904  d_loss:0.4834  g_loss:1.8124
# epoch:905  d_loss:0.3337  g_loss:2.1738
# epoch:906  d_loss:0.3863  g_loss:2.0965
# epoch:907  d_loss:0.2971  g_loss:2.1531
# epoch:908  d_loss:0.4671  g_loss:1.9535
# epoch:909  d_loss:0.3172  g_loss:2.0411
# epoch:910  d_loss:0.3649  g_loss:1.6047
# epoch:911  d_loss:0.3893  g_loss:2.0355
# epoch:912  d_loss:0.2586  g_loss:2.3761
# epoch:913  d_loss:0.3824  g_loss:2.3864
# epoch:914  d_loss:0.2689  g_loss:2.7312
# epoch:915  d_loss:0.2664  g_loss:2.7684
# epoch:916  d_loss:0.1914  g_loss:3.0479
# epoch:917  d_loss:0.3358  g_loss:2.4132
# epoch:918  d_loss:0.3219  g_loss:1.7903
# epoch:919  d_loss:0.2334  g_loss:1.9660
# epoch:920  d_loss:0.2342  g_loss:2.6801
# epoch:921  d_loss:0.1490  g_loss:2.6899
# epoch:922  d_loss:0.2225  g_loss:2.8700
# epoch:923  d_loss:0.2219  g_loss:2.4784
# epoch:924  d_loss:0.4106  g_loss:2.1743
# epoch:925  d_loss:0.1909  g_loss:2.3492
# epoch:926  d_loss:0.2570  g_loss:2.4349
# epoch:927  d_loss:0.3063  g_loss:2.0074
# epoch:928  d_loss:0.3240  g_loss:2.6626
# epoch:929  d_loss:0.2381  g_loss:2.4240
# epoch:930  d_loss:0.2113  g_loss:2.2162
# epoch:931  d_loss:0.3596  g_loss:2.3712
# epoch:932  d_loss:0.1845  g_loss:3.0453
# epoch:933  d_loss:0.2196  g_loss:2.9087
# epoch:934  d_loss:0.3010  g_loss:2.9471
# epoch:935  d_loss:0.3572  g_loss:2.3968
# epoch:936  d_loss:0.3372  g_loss:2.2163
# epoch:937  d_loss:0.2917  g_loss:2.1096
# epoch:938  d_loss:0.3912  g_loss:2.1140
# epoch:939  d_loss:0.3499  g_loss:1.9639
# epoch:940  d_loss:0.4247  g_loss:1.8720
# epoch:941  d_loss:0.4178  g_loss:2.3086
# epoch:942  d_loss:0.7312  g_loss:2.5203
# epoch:943  d_loss:0.4454  g_loss:1.8207
# epoch:944  d_loss:0.4917  g_loss:1.5297
# epoch:945  d_loss:0.4424  g_loss:1.9894
# epoch:946  d_loss:0.3464  g_loss:2.4123
# epoch:947  d_loss:0.3513  g_loss:2.5226
# epoch:948  d_loss:0.5080  g_loss:2.2147
# epoch:949  d_loss:0.5305  g_loss:2.2012
# epoch:950  d_loss:0.5826  g_loss:1.7282
# epoch:951  d_loss:0.5861  g_loss:1.3938
# epoch:952  d_loss:0.3895  g_loss:1.7906
# epoch:953  d_loss:0.3741  g_loss:1.8325
# epoch:954  d_loss:0.2947  g_loss:2.4410
# epoch:955  d_loss:0.2939  g_loss:2.4272
# epoch:956  d_loss:0.3488  g_loss:2.4725
# epoch:957  d_loss:0.4871  g_loss:2.5399
# epoch:958  d_loss:0.3761  g_loss:2.2624
# epoch:959  d_loss:0.3678  g_loss:2.1814
# epoch:960  d_loss:0.4132  g_loss:2.3956
# epoch:961  d_loss:0.2858  g_loss:3.0859
# epoch:962  d_loss:0.2602  g_loss:3.2616
# epoch:963  d_loss:0.3285  g_loss:3.4963
# epoch:964  d_loss:0.3063  g_loss:2.2342
# epoch:965  d_loss:0.4643  g_loss:1.9974
# epoch:966  d_loss:0.3158  g_loss:2.2843
# epoch:967  d_loss:0.4812  g_loss:2.1936
# epoch:968  d_loss:0.4772  g_loss:2.1940
# epoch:969  d_loss:0.5153  g_loss:2.2710
# epoch:970  d_loss:0.3852  g_loss:2.5810
# epoch:971  d_loss:0.4512  g_loss:1.8157
# epoch:972  d_loss:0.6089  g_loss:1.5807
# epoch:973  d_loss:0.3706  g_loss:1.5015
# epoch:974  d_loss:0.2715  g_loss:2.1412
# epoch:975  d_loss:0.3859  g_loss:2.3314
# epoch:976  d_loss:0.2790  g_loss:2.2983
# epoch:977  d_loss:0.3561  g_loss:2.1620
# epoch:978  d_loss:0.3831  g_loss:2.5911
# epoch:979  d_loss:0.2950  g_loss:2.7918
# epoch:980  d_loss:0.2274  g_loss:2.7054
# epoch:981  d_loss:0.3442  g_loss:2.6892
# epoch:982  d_loss:0.1552  g_loss:3.0187
# epoch:983  d_loss:0.2638  g_loss:2.5275
# epoch:984  d_loss:0.1558  g_loss:2.9054
# epoch:985  d_loss:0.1425  g_loss:2.9605
# epoch:986  d_loss:0.1772  g_loss:3.2736
# epoch:987  d_loss:0.1729  g_loss:4.3325
# epoch:988  d_loss:0.2528  g_loss:3.6442
# epoch:989  d_loss:0.2189  g_loss:2.9272
# epoch:990  d_loss:0.2484  g_loss:2.5116
# epoch:991  d_loss:0.2190  g_loss:2.7491
# epoch:992  d_loss:0.2557  g_loss:2.6759
# epoch:993  d_loss:0.2390  g_loss:3.0247
# epoch:994  d_loss:0.1857  g_loss:3.4757
# epoch:995  d_loss:0.2693  g_loss:3.2951
# epoch:996  d_loss:0.3020  g_loss:3.6236
# epoch:997  d_loss:0.3661  g_loss:3.1830
# epoch:998  d_loss:0.4279  g_loss:2.2339
# epoch:999  d_loss:0.6806  g_loss:1.7757
# epoch:1000  d_loss:0.4036  g_loss:2.2399
# epoch:1001  d_loss:0.3900  g_loss:2.2725
# epoch:1002  d_loss:0.7410  g_loss:2.8863
# epoch:1003  d_loss:0.7794  g_loss:2.4818
# epoch:1004  d_loss:0.5811  g_loss:2.2733
# epoch:1005  d_loss:0.4054  g_loss:2.4704
# epoch:1006  d_loss:0.4631  g_loss:2.0213
# epoch:1007  d_loss:0.6701  g_loss:2.0476
# epoch:1008  d_loss:0.4796  g_loss:2.0673
# epoch:1009  d_loss:0.3435  g_loss:2.8002
# epoch:1010  d_loss:0.3469  g_loss:2.9266
# epoch:1011  d_loss:0.4524  g_loss:2.4810
# epoch:1012  d_loss:0.4182  g_loss:2.3654
# epoch:1013  d_loss:0.5635  g_loss:2.6437
# epoch:1014  d_loss:0.4190  g_loss:2.0969
# epoch:1015  d_loss:0.4926  g_loss:1.9196
# epoch:1016  d_loss:0.3975  g_loss:1.8781
# epoch:1017  d_loss:0.3098  g_loss:2.1652
# epoch:1018  d_loss:0.4888  g_loss:2.3999
# epoch:1019  d_loss:0.2629  g_loss:2.9369
# epoch:1020  d_loss:0.2289  g_loss:3.2572
# epoch:1021  d_loss:0.5284  g_loss:2.4011
# epoch:1022  d_loss:0.3272  g_loss:2.4895
# epoch:1023  d_loss:0.2535  g_loss:2.7339
# epoch:1024  d_loss:0.2357  g_loss:2.9364
# epoch:1025  d_loss:0.3611  g_loss:2.8758
# epoch:1026  d_loss:0.3904  g_loss:2.4509
# epoch:1027  d_loss:0.2737  g_loss:2.1796
# epoch:1028  d_loss:0.3626  g_loss:2.6717
# epoch:1029  d_loss:0.2707  g_loss:3.2076
# epoch:1030  d_loss:0.2315  g_loss:3.2788
# epoch:1031  d_loss:0.2365  g_loss:2.8634
# epoch:1032  d_loss:0.2981  g_loss:3.0233
# epoch:1033  d_loss:0.2691  g_loss:2.8046
# epoch:1034  d_loss:0.3412  g_loss:2.2451
# epoch:1035  d_loss:0.1614  g_loss:2.2268
# epoch:1036  d_loss:0.3512  g_loss:2.1031
# epoch:1037  d_loss:0.2961  g_loss:2.1122
# epoch:1038  d_loss:0.4011  g_loss:2.2063
# epoch:1039  d_loss:0.2934  g_loss:1.9214
# epoch:1040  d_loss:0.2603  g_loss:2.3513
# epoch:1041  d_loss:0.3135  g_loss:1.9401
# epoch:1042  d_loss:0.4274  g_loss:1.9609
# epoch:1043  d_loss:0.2278  g_loss:2.5375
# epoch:1044  d_loss:0.3387  g_loss:2.6918
# epoch:1045  d_loss:0.3408  g_loss:2.5650
# epoch:1046  d_loss:0.2786  g_loss:2.3737
# epoch:1047  d_loss:0.3133  g_loss:1.8712
# epoch:1048  d_loss:0.4519  g_loss:1.6616
# epoch:1049  d_loss:0.3792  g_loss:1.9077
# epoch:1050  d_loss:0.2542  g_loss:2.9582
# epoch:1051  d_loss:0.5296  g_loss:2.6396
# epoch:1052  d_loss:0.2674  g_loss:2.2605
# epoch:1053  d_loss:0.4749  g_loss:1.6960
# epoch:1054  d_loss:0.4079  g_loss:1.9478
# epoch:1055  d_loss:0.2750  g_loss:1.8131
# epoch:1056  d_loss:0.3010  g_loss:2.0991
# epoch:1057  d_loss:0.2855  g_loss:2.6030
# epoch:1058  d_loss:0.1981  g_loss:2.5382
# epoch:1059  d_loss:0.2937  g_loss:2.1653
# epoch:1060  d_loss:0.3063  g_loss:2.2792
# epoch:1061  d_loss:0.2406  g_loss:2.3759
# epoch:1062  d_loss:0.1959  g_loss:2.5832
# epoch:1063  d_loss:0.2388  g_loss:2.8602
# epoch:1064  d_loss:0.2435  g_loss:2.3849
# epoch:1065  d_loss:0.3181  g_loss:2.5546
# epoch:1066  d_loss:0.4468  g_loss:2.2330
# epoch:1067  d_loss:0.2117  g_loss:2.2558
# epoch:1068  d_loss:0.3779  g_loss:2.2561
# epoch:1069  d_loss:0.2968  g_loss:2.1278
# epoch:1070  d_loss:0.4660  g_loss:2.4988
# epoch:1071  d_loss:0.2534  g_loss:2.6752
# epoch:1072  d_loss:0.3890  g_loss:2.4530
# epoch:1073  d_loss:0.4344  g_loss:2.5530
# epoch:1074  d_loss:0.2424  g_loss:2.4605
# epoch:1075  d_loss:0.4170  g_loss:2.3144
# epoch:1076  d_loss:0.4624  g_loss:2.1956
# epoch:1077  d_loss:0.4284  g_loss:2.0840
# epoch:1078  d_loss:0.3923  g_loss:1.8773
# epoch:1079  d_loss:0.3411  g_loss:2.5300
# epoch:1080  d_loss:0.4168  g_loss:2.0861
# epoch:1081  d_loss:0.6453  g_loss:1.8070
# epoch:1082  d_loss:0.3253  g_loss:2.0004
# epoch:1083  d_loss:0.4049  g_loss:2.5847
# epoch:1084  d_loss:0.5472  g_loss:2.1032
# epoch:1085  d_loss:0.3945  g_loss:1.8295
# epoch:1086  d_loss:0.4470  g_loss:1.9210
# epoch:1087  d_loss:0.2760  g_loss:1.7331
# epoch:1088  d_loss:0.4504  g_loss:1.8019
# epoch:1089  d_loss:0.3173  g_loss:2.0588
# epoch:1090  d_loss:0.5203  g_loss:1.9878
# epoch:1091  d_loss:0.4450  g_loss:1.8169
# epoch:1092  d_loss:0.4236  g_loss:1.9254
# epoch:1093  d_loss:0.4826  g_loss:1.8251
# epoch:1094  d_loss:0.3648  g_loss:2.0428
# epoch:1095  d_loss:0.4308  g_loss:2.0786
# epoch:1096  d_loss:0.3831  g_loss:1.9945
# epoch:1097  d_loss:0.3774  g_loss:1.8863
# epoch:1098  d_loss:0.3635  g_loss:2.4295
# epoch:1099  d_loss:0.3916  g_loss:2.3969
# epoch:1100  d_loss:0.6305  g_loss:2.0408
# epoch:1101  d_loss:0.5491  g_loss:1.6377
# epoch:1102  d_loss:0.3355  g_loss:1.9628
# epoch:1103  d_loss:0.3362  g_loss:2.1377
# epoch:1104  d_loss:0.4463  g_loss:2.0197
# epoch:1105  d_loss:0.3589  g_loss:1.8808
# epoch:1106  d_loss:0.3963  g_loss:1.6568
# epoch:1107  d_loss:0.2602  g_loss:1.9867
# epoch:1108  d_loss:0.3357  g_loss:1.9728
# epoch:1109  d_loss:0.2475  g_loss:2.5610
# epoch:1110  d_loss:0.2321  g_loss:2.6526
# epoch:1111  d_loss:0.2572  g_loss:2.4944
# epoch:1112  d_loss:0.2950  g_loss:2.5245
# epoch:1113  d_loss:0.3696  g_loss:2.0228
# epoch:1114  d_loss:0.2730  g_loss:1.9393
# epoch:1115  d_loss:0.2883  g_loss:2.1012
# epoch:1116  d_loss:0.2311  g_loss:2.6700
# epoch:1117  d_loss:0.2038  g_loss:2.9936
# epoch:1118  d_loss:0.3419  g_loss:2.6482
# epoch:1119  d_loss:0.4172  g_loss:2.6677
# epoch:1120  d_loss:0.5234  g_loss:2.0056
# epoch:1121  d_loss:0.3605  g_loss:1.6470
# epoch:1122  d_loss:0.4328  g_loss:1.9818
# epoch:1123  d_loss:0.2918  g_loss:2.0885
# epoch:1124  d_loss:0.1750  g_loss:2.9467
# epoch:1125  d_loss:0.2312  g_loss:3.2875
# epoch:1126  d_loss:0.3980  g_loss:2.5698
# epoch:1127  d_loss:0.2614  g_loss:2.6804
# epoch:1128  d_loss:0.4373  g_loss:2.1717
# epoch:1129  d_loss:0.3902  g_loss:2.0224
# epoch:1130  d_loss:0.3094  g_loss:2.1578
# epoch:1131  d_loss:0.4028  g_loss:2.2954
# epoch:1132  d_loss:0.5293  g_loss:2.4403
# epoch:1133  d_loss:0.3965  g_loss:2.1221
# epoch:1134  d_loss:0.4511  g_loss:1.7780
# epoch:1135  d_loss:0.4030  g_loss:2.2329
# epoch:1136  d_loss:0.4169  g_loss:2.0776
# epoch:1137  d_loss:0.5876  g_loss:1.9093
# epoch:1138  d_loss:0.5226  g_loss:2.4153
# epoch:1139  d_loss:0.5198  g_loss:2.0769
# epoch:1140  d_loss:0.5908  g_loss:2.1347
# epoch:1141  d_loss:0.5097  g_loss:2.1417
# epoch:1142  d_loss:0.4950  g_loss:1.9032
# epoch:1143  d_loss:0.4017  g_loss:1.8609
# epoch:1144  d_loss:0.3819  g_loss:1.9111
# epoch:1145  d_loss:0.6145  g_loss:2.0375
# epoch:1146  d_loss:0.5393  g_loss:2.0328
# epoch:1147  d_loss:0.4398  g_loss:1.8691
# epoch:1148  d_loss:0.5116  g_loss:2.1645
# epoch:1149  d_loss:0.3132  g_loss:2.0760
# epoch:1150  d_loss:0.3832  g_loss:2.1701
# epoch:1151  d_loss:0.3807  g_loss:1.8906
# epoch:1152  d_loss:0.4369  g_loss:1.8650
# epoch:1153  d_loss:0.4112  g_loss:2.2134
# epoch:1154  d_loss:0.2444  g_loss:2.7416
# epoch:1155  d_loss:0.3539  g_loss:2.4441
# epoch:1156  d_loss:0.3542  g_loss:1.9641
# epoch:1157  d_loss:0.2474  g_loss:2.3300
# epoch:1158  d_loss:0.3632  g_loss:2.2731
# epoch:1159  d_loss:0.3544  g_loss:1.9918
# epoch:1160  d_loss:0.2924  g_loss:2.5785
# epoch:1161  d_loss:0.2168  g_loss:2.3892
# epoch:1162  d_loss:0.2748  g_loss:2.2248
# epoch:1163  d_loss:0.2703  g_loss:2.3465
# epoch:1164  d_loss:0.1666  g_loss:3.0013
# epoch:1165  d_loss:0.2147  g_loss:3.4348
# epoch:1166  d_loss:0.3259  g_loss:2.9063
# epoch:1167  d_loss:0.4007  g_loss:1.9666
# epoch:1168  d_loss:0.1732  g_loss:2.2499
# epoch:1169  d_loss:0.2917  g_loss:2.2118
# epoch:1170  d_loss:0.1895  g_loss:2.9452
# epoch:1171  d_loss:0.2219  g_loss:3.2580
# epoch:1172  d_loss:0.3091  g_loss:2.5283
# epoch:1173  d_loss:0.3025  g_loss:2.3823
# epoch:1174  d_loss:0.4645  g_loss:2.1750
# epoch:1175  d_loss:0.3150  g_loss:2.0960
# epoch:1176  d_loss:0.4220  g_loss:2.4715
# epoch:1177  d_loss:0.4537  g_loss:2.9292
# epoch:1178  d_loss:0.3004  g_loss:2.7660
# ...
# epoch:3620  d_loss:0.4431  g_loss:1.6726
# epoch:3621  d_loss:0.3690  g_loss:1.8900
# epoch:3622  d_loss:0.4679  g_loss:1.6644
# epoch:3623  d_loss:0.4885  g_loss:1.5493
# epoch:3624  d_loss:0.4009  g_loss:2.0733
# epoch:3625  d_loss:0.4937  g_loss:1.6677
# epoch:3626  d_loss:0.5405  g_loss:1.3900
# epoch:3627  d_loss:0.4602  g_loss:1.7449
# epoch:3628  d_loss:0.4838  g_loss:1.7978
# epoch:3629  d_loss:0.5693  g_loss:1.5062
# epoch:3630  d_loss:0.6012  g_loss:1.4384
# epoch:3631  d_loss:0.3766  g_loss:2.0208
# epoch:3632  d_loss:0.4354  g_loss:2.3084
# epoch:3633  d_loss:0.4022  g_loss:1.9019
# epoch:3634  d_loss:0.5286  g_loss:1.7039
# epoch:3635  d_loss:0.4481  g_loss:1.4314
# epoch:3636  d_loss:0.5686  g_loss:1.3343
# epoch:3637  d_loss:0.4822  g_loss:1.3660
# epoch:3638  d_loss:0.4539  g_loss:1.3057
# epoch:3639  d_loss:0.4187  g_loss:1.7487
# epoch:3640  d_loss:0.5559  g_loss:1.4572
# epoch:3641  d_loss:0.5337  g_loss:1.3730
# epoch:3642  d_loss:0.4932  g_loss:1.4243
# epoch:3643  d_loss:0.5065  g_loss:1.4713
# epoch:3644  d_loss:0.4509  g_loss:1.5534
# epoch:3645  d_loss:0.5939  g_loss:1.3690
# epoch:3646  d_loss:0.5629  g_loss:1.6246
# epoch:3647  d_loss:0.4800  g_loss:1.6699
# epoch:3648  d_loss:0.4322  g_loss:1.5307
# epoch:3649  d_loss:0.6535  g_loss:1.6979
# epoch:3650  d_loss:0.5546  g_loss:1.3212
# epoch:3651  d_loss:0.7003  g_loss:1.4502
# epoch:3652  d_loss:0.4866  g_loss:1.6167
# epoch:3653  d_loss:0.6075  g_loss:1.4621
# epoch:3654  d_loss:0.4650  g_loss:1.4491
# epoch:3655  d_loss:0.4767  g_loss:2.0137
# epoch:3656  d_loss:0.5732  g_loss:1.5580
# epoch:3657  d_loss:0.4087  g_loss:1.3615
# epoch:3658  d_loss:0.5028  g_loss:1.5039
# epoch:3659  d_loss:0.5310  g_loss:1.1245
# epoch:3660  d_loss:0.4968  g_loss:1.6085
# epoch:3661  d_loss:0.4273  g_loss:1.9212
# epoch:3662  d_loss:0.4458  g_loss:2.0697
# epoch:3663  d_loss:0.6027  g_loss:1.6703
# epoch:3664  d_loss:0.4910  g_loss:1.6799
# epoch:3665  d_loss:0.5778  g_loss:1.3209
# epoch:3666  d_loss:0.4466  g_loss:2.0246
# epoch:3667  d_loss:0.6089  g_loss:1.4893
# epoch:3668  d_loss:0.5006  g_loss:1.5171
# epoch:3669  d_loss:0.5070  g_loss:1.6993
# epoch:3670  d_loss:0.4214  g_loss:1.5135
# epoch:3671  d_loss:0.5198  g_loss:1.3415
# epoch:3672  d_loss:0.4341  g_loss:1.3414
# epoch:3673  d_loss:0.4826  g_loss:1.7297
# epoch:3674  d_loss:0.4802  g_loss:1.8375
# epoch:3675  d_loss:0.4523  g_loss:1.7807
# epoch:3676  d_loss:0.5947  g_loss:1.6674
# epoch:3677  d_loss:0.5364  g_loss:1.3470
# epoch:3678  d_loss:0.4352  g_loss:1.1729
# epoch:3679  d_loss:0.4844  g_loss:1.1367
# epoch:3680  d_loss:0.5036  g_loss:1.8160
# epoch:3681  d_loss:0.4769  g_loss:1.5869
# epoch:3682  d_loss:0.4437  g_loss:1.8096
# epoch:3683  d_loss:0.4654  g_loss:1.4968
# epoch:3684  d_loss:0.5374  g_loss:1.5536
# epoch:3685  d_loss:0.4831  g_loss:1.5189
# epoch:3686  d_loss:0.5429  g_loss:1.3534
# epoch:3687  d_loss:0.6493  g_loss:1.5608
# epoch:3688  d_loss:0.3241  g_loss:2.1760
# epoch:3689  d_loss:0.5132  g_loss:1.7206
# epoch:3690  d_loss:0.4771  g_loss:1.7013
# epoch:3691  d_loss:0.6346  g_loss:1.2523
# epoch:3692  d_loss:0.5937  g_loss:1.3231
# epoch:3693  d_loss:0.5241  g_loss:1.4768
# epoch:3694  d_loss:0.4350  g_loss:1.3523
# epoch:3695  d_loss:0.4472  g_loss:1.3830
# epoch:3696  d_loss:0.4233  g_loss:1.7767
# epoch:3697  d_loss:0.4308  g_loss:2.0170
# epoch:3698  d_loss:0.5977  g_loss:1.6515
# epoch:3699  d_loss:0.6415  g_loss:1.1169
# epoch:3700  d_loss:0.5167  g_loss:0.7309
# epoch:3701  d_loss:0.4791  g_loss:1.2500
# epoch:3702  d_loss:0.6207  g_loss:1.5350
# epoch:3703  d_loss:0.4141  g_loss:2.1250
# epoch:3704  d_loss:0.6230  g_loss:1.5907
# epoch:3705  d_loss:0.4699  g_loss:1.8533
# epoch:3706  d_loss:0.6036  g_loss:1.2380
# epoch:3707  d_loss:0.4267  g_loss:1.5014
# epoch:3708  d_loss:0.4872  g_loss:1.3146
# epoch:3709  d_loss:0.4290  g_loss:1.6901
# epoch:3710  d_loss:0.4646  g_loss:1.6515
# epoch:3711  d_loss:0.4193  g_loss:1.9043
# epoch:3712  d_loss:0.5159  g_loss:1.6924
# epoch:3713  d_loss:0.4571  g_loss:1.6853
# epoch:3714  d_loss:0.5709  g_loss:1.6225
# epoch:3715  d_loss:0.5867  g_loss:1.4974
# epoch:3716  d_loss:0.5782  g_loss:1.5332
# epoch:3717  d_loss:0.5709  g_loss:1.5691
# epoch:3718  d_loss:0.5411  g_loss:1.5825
# epoch:3719  d_loss:0.5504  g_loss:1.5395
# epoch:3720  d_loss:0.3891  g_loss:1.7583
# epoch:3721  d_loss:0.4520  g_loss:1.8133
# epoch:3722  d_loss:0.5554  g_loss:1.8893
# epoch:3723  d_loss:0.5506  g_loss:1.3373
# epoch:3724  d_loss:0.5953  g_loss:1.0927
# epoch:3725  d_loss:0.5005  g_loss:1.3113
# epoch:3726  d_loss:0.4372  g_loss:1.6594
# epoch:3727  d_loss:0.3890  g_loss:1.8096
# epoch:3728  d_loss:0.6341  g_loss:2.0709
# epoch:3729  d_loss:0.4848  g_loss:1.7624
# epoch:3730  d_loss:0.5564  g_loss:1.5558
# epoch:3731  d_loss:0.4703  g_loss:1.4635
# epoch:3732  d_loss:0.4495  g_loss:1.6303
# epoch:3733  d_loss:0.4756  g_loss:1.6369
# epoch:3734  d_loss:0.6249  g_loss:1.8166
# epoch:3735  d_loss:0.5436  g_loss:1.5896
# epoch:3736  d_loss:0.5642  g_loss:2.0743
# epoch:3737  d_loss:0.4652  g_loss:1.3041
# epoch:3738  d_loss:0.5107  g_loss:1.6341
# epoch:3739  d_loss:0.5020  g_loss:1.5599
# epoch:3740  d_loss:0.4631  g_loss:1.5627
# epoch:3741  d_loss:0.4934  g_loss:1.7566
# epoch:3742  d_loss:0.5229  g_loss:1.6832
# epoch:3743  d_loss:0.4384  g_loss:1.7139
# epoch:3744  d_loss:0.4305  g_loss:1.7393
# epoch:3745  d_loss:0.4864  g_loss:1.4195
# epoch:3746  d_loss:0.4364  g_loss:1.8469
# epoch:3747  d_loss:0.4760  g_loss:1.4999
# epoch:3748  d_loss:0.6269  g_loss:1.4933
# epoch:3749  d_loss:0.4328  g_loss:2.1355
# epoch:3750  d_loss:0.8549  g_loss:1.5543
# epoch:3751  d_loss:0.6035  g_loss:1.3656
# epoch:3752  d_loss:0.5034  g_loss:1.2664
# epoch:3753  d_loss:0.5120  g_loss:1.4909
# epoch:3754  d_loss:0.5915  g_loss:1.5102
# epoch:3755  d_loss:0.6570  g_loss:1.4310
# epoch:3756  d_loss:0.5294  g_loss:1.5347
# epoch:3757  d_loss:0.6120  g_loss:1.3167
# epoch:3758  d_loss:0.6337  g_loss:1.4206
# epoch:3759  d_loss:0.5243  g_loss:1.2208
# epoch:3760  d_loss:0.4957  g_loss:1.3755
# epoch:3761  d_loss:0.6314  g_loss:1.4074
# epoch:3762  d_loss:0.4109  g_loss:1.5827
# epoch:3763  d_loss:0.4334  g_loss:1.6928
# epoch:3764  d_loss:0.6215  g_loss:1.8291
# epoch:3765  d_loss:0.5922  g_loss:1.4758
# epoch:3766  d_loss:0.6165  g_loss:1.3904
# epoch:3767  d_loss:0.5075  g_loss:1.6236
# epoch:3768  d_loss:0.5212  g_loss:1.6464
# epoch:3769  d_loss:0.3646  g_loss:1.8186
# epoch:3770  d_loss:0.4490  g_loss:1.9426
# epoch:3771  d_loss:0.4403  g_loss:1.5476
# epoch:3772  d_loss:0.5715  g_loss:1.5144
# epoch:3773  d_loss:0.3905  g_loss:1.6183
# epoch:3774  d_loss:0.5714  g_loss:1.3547
# epoch:3775  d_loss:0.4922  g_loss:1.5877
# epoch:3776  d_loss:0.5147  g_loss:1.6908
# epoch:3777  d_loss:0.3498  g_loss:1.5135
# epoch:3778  d_loss:0.4277  g_loss:1.5578
# epoch:3779  d_loss:0.4015  g_loss:1.7431
# epoch:3780  d_loss:0.4362  g_loss:1.5840
# epoch:3781  d_loss:0.5923  g_loss:1.4437
# epoch:3782  d_loss:0.6072  g_loss:1.6984
# epoch:3783  d_loss:0.4519  g_loss:1.9009
# epoch:3784  d_loss:0.4024  g_loss:1.5781
# epoch:3785  d_loss:0.5152  g_loss:1.8958
# epoch:3786  d_loss:0.4252  g_loss:1.7302
# epoch:3787  d_loss:0.4114  g_loss:1.4183
# epoch:3788  d_loss:0.5233  g_loss:1.8428
# epoch:3789  d_loss:0.4198  g_loss:1.9163
# epoch:3790  d_loss:0.4281  g_loss:1.8655
# epoch:3791  d_loss:0.5632  g_loss:1.4645
# epoch:3792  d_loss:0.5642  g_loss:1.8995
# epoch:3793  d_loss:0.4842  g_loss:2.0970
# epoch:3794  d_loss:0.6688  g_loss:1.5770
# epoch:3795  d_loss:0.6022  g_loss:1.2574
# epoch:3796  d_loss:0.4448  g_loss:1.7305
# epoch:3797  d_loss:0.5543  g_loss:1.6862
# epoch:3798  d_loss:0.3856  g_loss:1.9956
# epoch:3799  d_loss:0.4657  g_loss:1.7722
# epoch:3800  d_loss:0.4314  g_loss:1.7996
# epoch:3801  d_loss:0.4347  g_loss:1.5440
# epoch:3802  d_loss:0.4607  g_loss:1.8860
# epoch:3803  d_loss:0.3735  g_loss:1.6138
# epoch:3804  d_loss:0.5096  g_loss:2.0102
# epoch:3805  d_loss:0.5403  g_loss:1.8459
# epoch:3806  d_loss:0.5854  g_loss:1.4044
# epoch:3807  d_loss:0.4876  g_loss:1.5473
# epoch:3808  d_loss:0.4951  g_loss:1.5242
# epoch:3809  d_loss:0.4512  g_loss:1.5509
# epoch:3810  d_loss:0.3935  g_loss:1.5274
# epoch:3811  d_loss:0.6331  g_loss:1.6806
# epoch:3812  d_loss:0.4925  g_loss:1.3482
# epoch:3813  d_loss:0.5045  g_loss:1.6344
# epoch:3814  d_loss:0.4635  g_loss:1.5884
# epoch:3815  d_loss:0.4885  g_loss:1.6708
# epoch:3816  d_loss:0.5236  g_loss:1.7623
# epoch:3817  d_loss:0.4155  g_loss:2.1527
# epoch:3818  d_loss:0.4545  g_loss:1.6999
# epoch:3819  d_loss:0.5993  g_loss:1.6753
# epoch:3820  d_loss:0.4839  g_loss:1.7854
# epoch:3821  d_loss:0.5284  g_loss:1.7676
# epoch:3822  d_loss:0.5201  g_loss:1.9255
# epoch:3823  d_loss:0.6801  g_loss:1.3567
# epoch:3824  d_loss:0.3770  g_loss:1.6332
# epoch:3825  d_loss:0.5332  g_loss:1.2719
# epoch:3826  d_loss:0.4731  g_loss:1.5545
# epoch:3827  d_loss:0.4193  g_loss:1.6566
# epoch:3828  d_loss:0.5464  g_loss:1.9673
# epoch:3829  d_loss:0.5290  g_loss:1.7948
# epoch:3830  d_loss:0.3863  g_loss:1.8885
# epoch:3831  d_loss:0.4545  g_loss:1.8994
# epoch:3832  d_loss:0.6300  g_loss:1.4956
# epoch:3833  d_loss:0.3888  g_loss:1.5340
# epoch:3834  d_loss:0.5114  g_loss:1.6150
# epoch:3835  d_loss:0.5511  g_loss:2.1813
# epoch:3836  d_loss:0.4013  g_loss:2.0402
# epoch:3837  d_loss:0.5190  g_loss:1.8817
# epoch:3838  d_loss:0.4027  g_loss:1.5774
# epoch:3839  d_loss:0.5730  g_loss:1.5650
# epoch:3840  d_loss:0.4981  g_loss:1.7518
# epoch:3841  d_loss:0.4980  g_loss:1.7742
# epoch:3842  d_loss:0.5564  g_loss:1.5150
# epoch:3843  d_loss:0.4899  g_loss:1.8349
# epoch:3844  d_loss:0.4902  g_loss:1.6061
# epoch:3845  d_loss:0.4733  g_loss:1.3253
# epoch:3846  d_loss:0.4494  g_loss:1.4519
# epoch:3847  d_loss:0.4461  g_loss:1.8300
# epoch:3848  d_loss:0.5000  g_loss:2.3331
# epoch:3849  d_loss:0.4526  g_loss:2.1927
# epoch:3850  d_loss:0.6229  g_loss:2.4103
# epoch:3851  d_loss:0.4833  g_loss:1.6878
# epoch:3852  d_loss:0.4847  g_loss:1.1789
# epoch:3853  d_loss:0.5425  g_loss:1.3048
# epoch:3854  d_loss:0.3427  g_loss:1.7709
# epoch:3855  d_loss:0.5730  g_loss:1.8205
# epoch:3856  d_loss:0.5462  g_loss:1.8082
# epoch:3857  d_loss:0.5406  g_loss:1.4657
# epoch:3858  d_loss:0.5052  g_loss:1.5555
# epoch:3859  d_loss:0.4579  g_loss:1.8459
# epoch:3860  d_loss:0.4377  g_loss:1.7337
# epoch:3861  d_loss:0.4636  g_loss:1.4801
# epoch:3862  d_loss:0.4766  g_loss:1.6180
# epoch:3863  d_loss:0.5841  g_loss:1.7900
# epoch:3864  d_loss:0.4736  g_loss:1.4234
# epoch:3865  d_loss:0.3702  g_loss:2.1161
# epoch:3866  d_loss:0.5708  g_loss:1.5800
# epoch:3867  d_loss:0.3803  g_loss:1.9177
# epoch:3868  d_loss:0.4372  g_loss:1.7758
# epoch:3869  d_loss:0.5094  g_loss:1.7386
# epoch:3870  d_loss:0.4116  g_loss:1.8034
# epoch:3871  d_loss:0.6202  g_loss:1.6428
# epoch:3872  d_loss:0.4449  g_loss:1.9710
# epoch:3873  d_loss:0.4278  g_loss:2.3486
# epoch:3874  d_loss:0.5053  g_loss:2.0816
# epoch:3875  d_loss:0.5260  g_loss:1.7924
# epoch:3876  d_loss:0.5285  g_loss:1.6644
# epoch:3877  d_loss:0.4445  g_loss:1.4148
# epoch:3878  d_loss:0.3605  g_loss:1.7331
# epoch:3879  d_loss:0.5105  g_loss:1.6663
# epoch:3880  d_loss:0.3124  g_loss:1.8369
# epoch:3881  d_loss:0.4964  g_loss:1.6661
# epoch:3882  d_loss:0.6361  g_loss:1.4564
# epoch:3883  d_loss:0.3764  g_loss:1.6888
# epoch:3884  d_loss:0.4727  g_loss:1.6848
# epoch:3885  d_loss:0.6970  g_loss:1.4476
# epoch:3886  d_loss:0.4281  g_loss:1.5596
# epoch:3887  d_loss:0.5201  g_loss:1.5334
# epoch:3888  d_loss:0.3900  g_loss:1.9088
# epoch:3889  d_loss:0.4172  g_loss:2.1350
# epoch:3890  d_loss:0.5168  g_loss:1.4588
# epoch:3891  d_loss:0.4022  g_loss:1.7108
# epoch:3892  d_loss:0.3351  g_loss:1.3540
# epoch:3893  d_loss:0.5445  g_loss:1.8133
# epoch:3894  d_loss:0.5224  g_loss:1.7440
# epoch:3895  d_loss:0.5753  g_loss:1.5108
# epoch:3896  d_loss:0.4462  g_loss:1.8820
# epoch:3897  d_loss:0.4016  g_loss:1.9655
# epoch:3898  d_loss:0.6407  g_loss:1.5418
# epoch:3899  d_loss:0.3500  g_loss:2.0662
# epoch:3900  d_loss:0.4661  g_loss:2.0938
# epoch:3901  d_loss:0.4218  g_loss:2.3745
# epoch:3902  d_loss:0.5853  g_loss:2.1151
# epoch:3903  d_loss:0.3561  g_loss:1.9517
# epoch:3904  d_loss:0.3305  g_loss:2.2197
# epoch:3905  d_loss:0.3516  g_loss:1.9765
# epoch:3906  d_loss:0.4936  g_loss:1.7787
# epoch:3907  d_loss:0.4716  g_loss:1.7991
# epoch:3908  d_loss:0.5083  g_loss:1.4627
# epoch:3909  d_loss:0.4774  g_loss:1.7000
# epoch:3910  d_loss:0.4352  g_loss:1.8413
# epoch:3911  d_loss:0.4582  g_loss:1.8958
# epoch:3912  d_loss:0.2526  g_loss:2.2657
# epoch:3913  d_loss:0.4845  g_loss:1.8128
# epoch:3914  d_loss:0.3550  g_loss:1.6051
# epoch:3915  d_loss:0.3745  g_loss:1.7542
# epoch:3916  d_loss:0.4805  g_loss:1.5764
# epoch:3917  d_loss:0.4851  g_loss:1.4822
# epoch:3918  d_loss:0.4549  g_loss:1.5329
# epoch:3919  d_loss:0.3617  g_loss:1.5827
# epoch:3920  d_loss:0.4773  g_loss:2.0355
# epoch:3921  d_loss:0.5544  g_loss:1.9825
# epoch:3922  d_loss:0.5432  g_loss:1.7393
# epoch:3923  d_loss:0.3963  g_loss:1.3922
# epoch:3924  d_loss:0.4082  g_loss:1.4984
# epoch:3925  d_loss:0.4315  g_loss:1.3765
# epoch:3926  d_loss:0.3708  g_loss:1.4523
# epoch:3927  d_loss:0.5160  g_loss:1.9446
# epoch:3928  d_loss:0.4363  g_loss:1.8978
# epoch:3929  d_loss:0.4710  g_loss:1.7518
# epoch:3930  d_loss:0.4061  g_loss:1.8599
# epoch:3931  d_loss:0.3459  g_loss:1.4580
# epoch:3932  d_loss:0.5140  g_loss:1.6993
# epoch:3933  d_loss:0.5284  g_loss:1.9650
# epoch:3934  d_loss:0.5743  g_loss:1.5994
# epoch:3935  d_loss:0.4405  g_loss:1.3714
# epoch:3936  d_loss:0.3904  g_loss:1.5614
# epoch:3937  d_loss:0.6132  g_loss:1.5844
# epoch:3938  d_loss:0.4559  g_loss:1.7628
# epoch:3939  d_loss:0.4244  g_loss:1.9376
# epoch:3940  d_loss:0.5613  g_loss:1.6862
# epoch:3941  d_loss:0.6380  g_loss:1.6380
# epoch:3942  d_loss:0.4956  g_loss:1.4080
# epoch:3943  d_loss:0.5806  g_loss:1.8296
# epoch:3944  d_loss:0.4008  g_loss:1.9868
# epoch:3945  d_loss:0.4858  g_loss:2.1928
# epoch:3946  d_loss:0.6190  g_loss:2.2219
# epoch:3947  d_loss:0.5256  g_loss:1.6658
# epoch:3948  d_loss:0.5447  g_loss:1.8131
# epoch:3949  d_loss:0.4403  g_loss:2.0041
# epoch:3950  d_loss:0.5236  g_loss:1.8710
# epoch:3951  d_loss:0.3958  g_loss:1.8271
# epoch:3952  d_loss:0.6487  g_loss:1.6014
# epoch:3953  d_loss:0.5102  g_loss:1.8051
# epoch:3954  d_loss:0.3502  g_loss:1.9970
# epoch:3955  d_loss:0.5087  g_loss:2.1088
# epoch:3956  d_loss:0.4290  g_loss:2.2228
# epoch:3957  d_loss:0.4543  g_loss:1.5157
# epoch:3958  d_loss:0.4070  g_loss:1.6594
# epoch:3959  d_loss:0.6716  g_loss:1.4156
# epoch:3960  d_loss:0.4750  g_loss:2.1979
# epoch:3961  d_loss:0.3380  g_loss:2.3582
# epoch:3962  d_loss:0.5513  g_loss:2.2193
# epoch:3963  d_loss:0.5366  g_loss:1.9936
# epoch:3964  d_loss:0.5170  g_loss:1.6575
# epoch:3965  d_loss:0.4590  g_loss:1.6317
# epoch:3966  d_loss:0.3920  g_loss:2.2262
# epoch:3967  d_loss:0.6209  g_loss:1.7541
# epoch:3968  d_loss:0.4316  g_loss:1.7209
# epoch:3969  d_loss:0.3710  g_loss:1.7700
# epoch:3970  d_loss:0.4745  g_loss:2.2344
# epoch:3971  d_loss:0.3513  g_loss:2.0430
# epoch:3972  d_loss:0.4595  g_loss:1.9841
# epoch:3973  d_loss:0.4232  g_loss:2.1198
# epoch:3974  d_loss:0.3749  g_loss:1.7161
# epoch:3975  d_loss:0.3030  g_loss:2.4408
# epoch:3976  d_loss:0.3927  g_loss:2.0017
# epoch:3977  d_loss:0.4918  g_loss:1.6341
# epoch:3978  d_loss:0.6108  g_loss:1.7978
# epoch:3979  d_loss:0.4795  g_loss:2.1883
# epoch:3980  d_loss:0.4994  g_loss:2.0621
# epoch:3981  d_loss:0.4302  g_loss:1.7338
# epoch:3982  d_loss:0.4612  g_loss:2.0719
# epoch:3983  d_loss:0.5009  g_loss:1.9587
# epoch:3984  d_loss:0.4225  g_loss:1.7139
# epoch:3985  d_loss:0.3542  g_loss:1.8989
# epoch:3986  d_loss:0.4496  g_loss:1.6781
# epoch:3987  d_loss:0.5933  g_loss:1.8594
# epoch:3988  d_loss:0.5974  g_loss:1.4001
# epoch:3989  d_loss:0.4788  g_loss:1.3307
# epoch:3990  d_loss:0.6357  g_loss:1.6937
# epoch:3991  d_loss:0.4758  g_loss:1.5589
# epoch:3992  d_loss:0.5767  g_loss:1.5596
# epoch:3993  d_loss:0.5736  g_loss:1.3063
# epoch:3994  d_loss:0.5929  g_loss:1.6496
# epoch:3995  d_loss:0.4829  g_loss:1.9645
# epoch:3996  d_loss:0.4877  g_loss:1.8541
# epoch:3997  d_loss:0.4648  g_loss:1.6245
# epoch:3998  d_loss:0.5846  g_loss:1.7023
# epoch:3999  d_loss:0.3222  g_loss:1.8707
# epoch:4000  d_loss:0.4898  g_loss:1.8816
# C:\Users\taehj\AppData\Local\Temp/ipykernel_6636/804587751.py:86: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, axs = plt.subplots(5, 5)
