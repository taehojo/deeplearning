# %% [markdown]
# # 19장 세상에 없는 얼굴 GAN, 오토인코더

# %% [markdown]
# [<img src="https://raw.githubusercontent.com/taehojo/taehojo.github.io/master/assets/images/linktocolab.png" align="left"/> ](https://colab.research.google.com/github/taehojo/deeplearning_for_everyone_3rd/blob/master/colab/ch19-colab.ipynb)

# %% [markdown]
# ## 3. 적대적 신경망 실행하기

# %% [markdown]
# ### 실습: GAN 모델 만들기

# %%
from tensorflow.keras.datasets import mnist
from tensorflow.keras.layers import Input, Dense, Reshape, Flatten, Dropout
from tensorflow.keras.layers import BatchNormalization, Activation, LeakyReLU, UpSampling2D, Conv2D
from tensorflow.keras.models import Sequential, Model

import numpy as np
import matplotlib.pyplot as plt

# 예제 파일에서 data 폴더 아래에 이미지가 저장될 gan_images 폴더가 함께 제공됩니다.
# 만약 이미지가 저장될 폴더가 없다면 아래 코드의 주석을 해제해 gan_images 폴더를 만듭니다.
# import os
# if not os.path.exists("./data/gan_images"):
#    os.makedirs("./data/gan_images")

# 생성자 모델을 만듭니다.
generator = Sequential()
generator.add(Dense(128*7*7, input_dim=100, activation=LeakyReLU(0.2)))
generator.add(BatchNormalization())
generator.add(Reshape((7, 7, 128)))
generator.add(UpSampling2D())
generator.add(Conv2D(64, kernel_size=5, padding='same'))
generator.add(BatchNormalization())
generator.add(Activation(LeakyReLU(0.2)))
generator.add(UpSampling2D())
generator.add(Conv2D(1, kernel_size=5, padding='same', activation='tanh'))

# 판별자 모델을 만듭니다.
discriminator = Sequential()
discriminator.add(Conv2D(64, kernel_size=5, strides=2, input_shape=(28,28,1), padding="same"))
discriminator.add(Activation(LeakyReLU(0.2)))
discriminator.add(Dropout(0.3))
discriminator.add(Conv2D(128, kernel_size=5, strides=2, padding="same"))
discriminator.add(Activation(LeakyReLU(0.2)))
discriminator.add(Dropout(0.3))
discriminator.add(Flatten())
discriminator.add(Dense(1, activation='sigmoid'))
discriminator.compile(loss='binary_crossentropy', optimizer='adam')
discriminator.trainable = False

# 생성자와 판별자 모델을 연결시키는 gan 모델을 만듭니다.
ginput = Input(shape=(100,))
dis_output = discriminator(generator(ginput))
gan = Model(ginput, dis_output)
gan.compile(loss='binary_crossentropy', optimizer='adam')
gan.summary()

# 신경망을 실행시키는 함수를 만듭니다.
def gan_train(epoch, batch_size, saving_interval):

  # MNIST 데이터를 불러옵니다.

  (X_train, _), (_, _) = mnist.load_data()  # 앞서 불러온 적 있는 MNIST를 다시 이용합니다. 단, 테스트 과정은 필요 없고 이미지만 사용할 것이기 때문에 X_train만 불러왔습니다.
  X_train = X_train.reshape(X_train.shape[0], 28, 28, 1).astype('float32')
  X_train = (X_train - 127.5) / 127.5  # 픽셀 값은 0에서 255 사이의 값입니다. 이전에 255로 나누어 줄때는 이를 0~1 사이의 값으로 바꾸었던 것인데, 여기서는 127.5를 빼준 뒤 127.5로 나누어 줌으로 인해 -1에서 1사이의 값으로 바뀌게 됩니다.
  # X_train.shape, Y_train.shape, X_test.shape, Y_test.shape

  true = np.ones((batch_size, 1))
  fake = np.zeros((batch_size, 1))

  for i in range(epoch):
          # 실제 데이터를 판별자에 입력하는 부분입니다.
          idx = np.random.randint(0, X_train.shape[0], batch_size)
          imgs = X_train[idx]
          d_loss_real = discriminator.train_on_batch(imgs, true)

          # 가상 이미지를 판별자에 입력하는 부분입니다.
          noise = np.random.normal(0, 1, (batch_size, 100))
          gen_imgs = generator.predict(noise)
          d_loss_fake = discriminator.train_on_batch(gen_imgs, fake)

          # 판별자와 생성자의 오차를 계산합니다.
          d_loss = 0.5 * np.add(d_loss_real, d_loss_fake)
          g_loss = gan.train_on_batch(noise, true)

          print('epoch:%d' % i, ' d_loss:%.4f' % d_loss, ' g_loss:%.4f' % g_loss)

        # 이 부분은 중간 과정을 이미지로 저장해 주는 부분입니다. 본 장의 주요 내용과 관련이 없어
        # 소스 코드만 첨부합니다. 만들어진 이미지들은 gan_images 폴더에 저장됩니다.
          if i % saving_interval == 0:
              #r, c = 5, 5
              noise = np.random.normal(0, 1, (25, 100))
              gen_imgs = generator.predict(noise)

              # Rescale images 0 - 1
              gen_imgs = 0.5 * gen_imgs + 0.5

              fig, axs = plt.subplots(5, 5)
              count = 0
              for j in range(5):
                  for k in range(5):
                      axs[j, k].imshow(gen_imgs[count, :, :, 0], cmap='gray')
                      axs[j, k].axis('off')
                      count += 1
              fig.savefig("../data/gan_images/gan_mnist_%d.png" % i)

gan_train(4001, 32, 200)  # 4000번 반복되고(+1을 해 주는 것에 주의), 배치 사이즈는 32,  200번마다 결과가 저장되게 하였습니다.
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 100)]             0
# _________________________________________________________________
# sequential (Sequential)      (None, 28, 28, 1)         865281
# _________________________________________________________________
# sequential_1 (Sequential)    (None, 1)                 212865
# =================================================================
# Total params: 1,078,146
# Trainable params: 852,609
# Non-trainable params: 225,537
# _________________________________________________________________
# epoch:0  d_loss:0.7411  g_loss:0.4295
# epoch:1  d_loss:0.5209  g_loss:0.1779
# epoch:2  d_loss:0.4702  g_loss:0.0739
# epoch:3  d_loss:0.4565  g_loss:0.0520
# epoch:4  d_loss:0.4474  g_loss:0.0538
# epoch:5  d_loss:0.4358  g_loss:0.0752
# epoch:6  d_loss:0.4300  g_loss:0.1154
# epoch:7  d_loss:0.4343  g_loss:0.1479
# epoch:8  d_loss:0.4190  g_loss:0.1632
# epoch:9  d_loss:0.4125  g_loss:0.1374
# epoch:10  d_loss:0.4046  g_loss:0.1005
# epoch:11  d_loss:0.3982  g_loss:0.0712
# epoch:12  d_loss:0.3755  g_loss:0.0695
# epoch:13  d_loss:0.3287  g_loss:0.0880
# epoch:14  d_loss:0.3048  g_loss:0.0766
# epoch:15  d_loss:0.2568  g_loss:0.0772
# epoch:16  d_loss:0.2248  g_loss:0.0582
# epoch:17  d_loss:0.1864  g_loss:0.0366
# epoch:18  d_loss:0.1523  g_loss:0.0333
# epoch:19  d_loss:0.0985  g_loss:0.0567
# epoch:20  d_loss:0.0875  g_loss:0.0228
# epoch:21  d_loss:0.0528  g_loss:0.0194
# epoch:22  d_loss:0.0371  g_loss:0.0212
# epoch:23  d_loss:0.0289  g_loss:0.0159
# epoch:24  d_loss:0.0228  g_loss:0.0135
# epoch:25  d_loss:0.0141  g_loss:0.0116
# epoch:26  d_loss:0.0111  g_loss:0.0209
# epoch:27  d_loss:0.0068  g_loss:0.0776
# epoch:28  d_loss:0.0129  g_loss:0.0013
# epoch:29  d_loss:0.0092  g_loss:0.0002
# epoch:30  d_loss:0.0052  g_loss:0.0006
# epoch:31  d_loss:0.0029  g_loss:0.0041
# epoch:32  d_loss:0.0025  g_loss:0.0453
# epoch:33  d_loss:0.0065  g_loss:0.0025
# epoch:34  d_loss:0.0018  g_loss:0.0004
# epoch:35  d_loss:0.0028  g_loss:0.0001
# epoch:36  d_loss:0.0021  g_loss:0.0001
# epoch:37  d_loss:0.0020  g_loss:0.0001
# epoch:38  d_loss:0.0022  g_loss:0.0002
# epoch:39  d_loss:0.0016  g_loss:0.0005
# epoch:40  d_loss:0.0012  g_loss:0.0019
# epoch:41  d_loss:0.0012  g_loss:0.0043
# epoch:42  d_loss:0.0011  g_loss:0.0049
# epoch:43  d_loss:0.0019  g_loss:0.0025
# epoch:44  d_loss:0.0024  g_loss:0.0009
# epoch:45  d_loss:0.0014  g_loss:0.0002
# epoch:46  d_loss:0.0015  g_loss:0.0002
# epoch:47  d_loss:0.0011  g_loss:0.0002
# epoch:48  d_loss:0.0016  g_loss:0.0002
# epoch:49  d_loss:0.0010  g_loss:0.0002
# epoch:50  d_loss:0.0013  g_loss:0.0003
# epoch:51  d_loss:0.0007  g_loss:0.0007
# epoch:52  d_loss:0.0010  g_loss:0.0012
# epoch:53  d_loss:0.0010  g_loss:0.0014
# epoch:54  d_loss:0.0010  g_loss:0.0013
# epoch:55  d_loss:0.0011  g_loss:0.0002
# epoch:56  d_loss:0.0008  g_loss:0.0002
# epoch:57  d_loss:0.0009  g_loss:0.0001
# epoch:58  d_loss:0.0008  g_loss:0.0001
# epoch:59  d_loss:0.0008  g_loss:0.0002
# epoch:60  d_loss:0.0009  g_loss:0.0003
# epoch:61  d_loss:0.0009  g_loss:0.0005
# epoch:62  d_loss:0.0007  g_loss:0.0010
# epoch:63  d_loss:0.0010  g_loss:0.0008
# epoch:64  d_loss:0.0008  g_loss:0.0008
# epoch:65  d_loss:0.0012  g_loss:0.0004
# epoch:66  d_loss:0.0017  g_loss:0.0005
# epoch:67  d_loss:0.0009  g_loss:0.0007
# epoch:68  d_loss:0.0009  g_loss:0.0009
# epoch:69  d_loss:0.0015  g_loss:0.0005
# epoch:70  d_loss:0.0013  g_loss:0.0004
# epoch:71  d_loss:0.0014  g_loss:0.0003
# epoch:72  d_loss:0.0008  g_loss:0.0005
# epoch:73  d_loss:0.0013  g_loss:0.0009
# epoch:74  d_loss:0.0023  g_loss:0.0048
# epoch:75  d_loss:0.0026  g_loss:0.0008
# epoch:76  d_loss:0.0022  g_loss:0.0004
# epoch:77  d_loss:0.0020  g_loss:0.0008
# epoch:78  d_loss:0.0015  g_loss:0.0055
# epoch:79  d_loss:0.0024  g_loss:0.0076
# epoch:80  d_loss:0.0080  g_loss:0.0002
# epoch:81  d_loss:0.0036  g_loss:0.0058
# epoch:82  d_loss:0.0015  g_loss:0.1735
# epoch:83  d_loss:2.0250  g_loss:9.4475
# epoch:84  d_loss:2.5435  g_loss:0.0004
# epoch:85  d_loss:0.3648  g_loss:0.0000
# epoch:86  d_loss:0.4973  g_loss:0.0043
# epoch:87  d_loss:0.0085  g_loss:2.6192
# epoch:88  d_loss:0.2622  g_loss:1.3893
# epoch:89  d_loss:0.1568  g_loss:0.0901
# epoch:90  d_loss:0.2825  g_loss:0.2347
# epoch:91  d_loss:0.1461  g_loss:1.1272
# epoch:92  d_loss:0.0318  g_loss:3.1009
# epoch:93  d_loss:0.3553  g_loss:0.4435
# epoch:94  d_loss:0.7561  g_loss:1.2565
# epoch:95  d_loss:0.0594  g_loss:4.0164
# epoch:96  d_loss:1.0828  g_loss:0.5596
# epoch:97  d_loss:1.6766  g_loss:1.4475
# epoch:98  d_loss:0.2809  g_loss:4.5588
# epoch:99  d_loss:1.7806  g_loss:0.8133
# epoch:100  d_loss:1.6161  g_loss:0.8395
# epoch:101  d_loss:0.2224  g_loss:3.4677
# epoch:102  d_loss:0.5932  g_loss:2.2145
# epoch:103  d_loss:0.2521  g_loss:0.9625
# epoch:104  d_loss:0.2248  g_loss:1.0686
# epoch:105  d_loss:0.0971  g_loss:1.8040
# epoch:106  d_loss:0.0707  g_loss:2.5400
# epoch:107  d_loss:0.1684  g_loss:2.4284
# epoch:108  d_loss:0.1419  g_loss:2.9967
# epoch:109  d_loss:0.2083  g_loss:2.8258
# epoch:110  d_loss:0.4096  g_loss:2.7082
# epoch:111  d_loss:0.7002  g_loss:2.2111
# epoch:112  d_loss:0.8677  g_loss:2.2700
# epoch:113  d_loss:0.8740  g_loss:2.5068
# epoch:114  d_loss:1.1608  g_loss:2.5387
# epoch:115  d_loss:1.1417  g_loss:2.7196
# epoch:116  d_loss:0.6802  g_loss:2.8631
# epoch:117  d_loss:0.5040  g_loss:3.2262
# epoch:118  d_loss:0.4080  g_loss:3.3702
# epoch:119  d_loss:0.4196  g_loss:3.2306
# epoch:120  d_loss:0.3633  g_loss:3.6056
# epoch:121  d_loss:0.3039  g_loss:4.0802
# epoch:122  d_loss:0.4088  g_loss:4.3688
# epoch:123  d_loss:0.4443  g_loss:3.6535
# epoch:124  d_loss:0.6176  g_loss:2.8699
# epoch:125  d_loss:0.6223  g_loss:2.6491
# epoch:126  d_loss:0.7103  g_loss:3.2126
# epoch:127  d_loss:0.4735  g_loss:3.2120
# epoch:128  d_loss:0.5685  g_loss:2.6411
# epoch:129  d_loss:0.8716  g_loss:2.1204
# epoch:130  d_loss:0.9424  g_loss:1.4284
# epoch:131  d_loss:0.8679  g_loss:1.1456
# epoch:132  d_loss:0.7692  g_loss:1.4475
# epoch:133  d_loss:0.6751  g_loss:1.9157
# epoch:134  d_loss:0.7822  g_loss:2.0668
# epoch:135  d_loss:0.8087  g_loss:1.7472
# epoch:136  d_loss:0.4042  g_loss:2.1157
# epoch:137  d_loss:0.3987  g_loss:2.2678
# epoch:138  d_loss:0.2508  g_loss:2.7931
# epoch:139  d_loss:0.1499  g_loss:3.2425
# epoch:140  d_loss:0.1893  g_loss:3.3927
# epoch:141  d_loss:0.3359  g_loss:3.6299
# epoch:142  d_loss:0.2379  g_loss:3.9830
# epoch:143  d_loss:0.4050  g_loss:4.3117
# epoch:144  d_loss:0.7732  g_loss:4.2034
# epoch:145  d_loss:0.6024  g_loss:4.4686
# epoch:146  d_loss:0.8759  g_loss:4.4011
# epoch:147  d_loss:0.9644  g_loss:3.8228
# epoch:148  d_loss:1.0714  g_loss:3.1633
# epoch:149  d_loss:1.0268  g_loss:2.7902
# epoch:150  d_loss:0.9514  g_loss:1.8275
# epoch:151  d_loss:0.8558  g_loss:1.6782
# epoch:152  d_loss:0.7925  g_loss:1.7512
# epoch:153  d_loss:0.6609  g_loss:1.8991
# epoch:154  d_loss:0.5947  g_loss:1.8572
# epoch:155  d_loss:0.5590  g_loss:1.6567
# epoch:156  d_loss:0.5745  g_loss:1.5991
# epoch:157  d_loss:0.5252  g_loss:1.1543
# epoch:158  d_loss:0.3907  g_loss:1.2754
# epoch:159  d_loss:0.4723  g_loss:1.5540
# epoch:160  d_loss:0.4208  g_loss:1.5296
# epoch:161  d_loss:0.3834  g_loss:1.3929
# epoch:162  d_loss:0.4721  g_loss:1.2785
# epoch:163  d_loss:0.4286  g_loss:1.6720
# epoch:164  d_loss:0.3709  g_loss:1.4706
# epoch:165  d_loss:0.5394  g_loss:1.3856
# epoch:166  d_loss:0.3563  g_loss:1.2240
# epoch:167  d_loss:0.4331  g_loss:1.0723
# epoch:168  d_loss:0.3732  g_loss:1.0649
# epoch:169  d_loss:0.3947  g_loss:1.0415
# epoch:170  d_loss:0.5871  g_loss:0.8915
# epoch:171  d_loss:0.4567  g_loss:1.1217
# epoch:172  d_loss:0.6374  g_loss:0.9595
# epoch:173  d_loss:0.4322  g_loss:1.3735
# epoch:174  d_loss:0.5510  g_loss:1.1534
# epoch:175  d_loss:0.5308  g_loss:1.2565
# epoch:176  d_loss:0.7041  g_loss:1.1575
# epoch:177  d_loss:0.5107  g_loss:1.1352
# epoch:178  d_loss:0.9297  g_loss:1.0058
# epoch:179  d_loss:0.6375  g_loss:0.8739
# epoch:180  d_loss:0.9295  g_loss:0.9030
# epoch:181  d_loss:0.5614  g_loss:1.0106
# epoch:182  d_loss:0.6356  g_loss:1.0566
# epoch:183  d_loss:0.6123  g_loss:1.1564
# epoch:184  d_loss:0.5953  g_loss:1.4036
# epoch:185  d_loss:0.5105  g_loss:1.6004
# epoch:186  d_loss:0.4027  g_loss:1.5770
# epoch:187  d_loss:0.4662  g_loss:1.5835
# epoch:188  d_loss:0.4175  g_loss:1.4951
# epoch:189  d_loss:0.3680  g_loss:1.6512
# epoch:190  d_loss:0.3738  g_loss:1.5640
# epoch:191  d_loss:0.2671  g_loss:1.5979
# epoch:192  d_loss:0.3103  g_loss:1.6268
# epoch:193  d_loss:0.2362  g_loss:1.8684
# epoch:194  d_loss:0.2714  g_loss:1.9274
# epoch:195  d_loss:0.2757  g_loss:1.8713
# epoch:196  d_loss:0.2935  g_loss:2.0117
# epoch:197  d_loss:0.3334  g_loss:1.8572
# epoch:198  d_loss:0.3819  g_loss:2.0771
# epoch:199  d_loss:0.3566  g_loss:1.8578
# epoch:200  d_loss:0.3757  g_loss:2.1032
# epoch:201  d_loss:0.3339  g_loss:2.2508
# epoch:202  d_loss:0.5942  g_loss:2.4293
# epoch:203  d_loss:0.6323  g_loss:1.7135
# epoch:204  d_loss:0.7256  g_loss:1.8557
# epoch:205  d_loss:0.5585  g_loss:2.0006
# epoch:206  d_loss:0.6182  g_loss:2.0707
# epoch:207  d_loss:0.8583  g_loss:1.9973
# epoch:208  d_loss:0.9046  g_loss:1.8444
# epoch:209  d_loss:1.0431  g_loss:1.3959
# epoch:210  d_loss:0.8778  g_loss:1.3636
# epoch:211  d_loss:0.7929  g_loss:1.5508
# epoch:212  d_loss:0.8323  g_loss:1.2414
# epoch:213  d_loss:0.6376  g_loss:1.3655
# epoch:214  d_loss:0.5116  g_loss:1.5457
# epoch:215  d_loss:0.5776  g_loss:1.4515
# epoch:216  d_loss:0.5206  g_loss:1.5135
# epoch:217  d_loss:0.5263  g_loss:1.6478
# epoch:218  d_loss:0.4020  g_loss:1.7063
# epoch:219  d_loss:0.3524  g_loss:1.5156
# epoch:220  d_loss:0.3968  g_loss:1.5371
# epoch:221  d_loss:0.3746  g_loss:1.8186
# epoch:222  d_loss:0.5080  g_loss:1.4419
# epoch:223  d_loss:0.3519  g_loss:1.6112
# epoch:224  d_loss:0.4008  g_loss:1.6559
# epoch:225  d_loss:0.3009  g_loss:2.0001
# epoch:226  d_loss:0.3679  g_loss:1.7358
# epoch:227  d_loss:0.3570  g_loss:1.9799
# epoch:228  d_loss:0.3355  g_loss:1.8163
# epoch:229  d_loss:0.3823  g_loss:1.8151
# epoch:230  d_loss:0.3155  g_loss:1.6608
# epoch:231  d_loss:0.2986  g_loss:2.2713
# epoch:232  d_loss:0.3525  g_loss:1.8826
# epoch:233  d_loss:0.4118  g_loss:1.7882
# epoch:234  d_loss:0.3366  g_loss:1.6488
# epoch:235  d_loss:0.3036  g_loss:1.6958
# epoch:236  d_loss:0.2475  g_loss:1.8283
# epoch:237  d_loss:0.4245  g_loss:1.8072
# epoch:238  d_loss:0.2691  g_loss:2.0340
# epoch:239  d_loss:0.5116  g_loss:1.3748
# epoch:240  d_loss:0.3786  g_loss:1.7697
# epoch:241  d_loss:0.3017  g_loss:1.9750
# epoch:242  d_loss:0.3450  g_loss:1.6808
# epoch:243  d_loss:0.4225  g_loss:1.5712
# epoch:244  d_loss:0.3606  g_loss:1.9752
# epoch:245  d_loss:0.3107  g_loss:2.1565
# epoch:246  d_loss:0.4913  g_loss:2.1407
# epoch:247  d_loss:0.5288  g_loss:1.6795
# epoch:248  d_loss:0.3517  g_loss:1.8070
# epoch:249  d_loss:0.4637  g_loss:1.7237
# epoch:250  d_loss:0.4098  g_loss:2.0252
# epoch:251  d_loss:0.4148  g_loss:1.7417
# epoch:252  d_loss:0.4665  g_loss:1.5975
# epoch:253  d_loss:0.4887  g_loss:1.5970
# epoch:254  d_loss:0.5286  g_loss:1.6975
# epoch:255  d_loss:0.4555  g_loss:1.7484
# epoch:256  d_loss:0.5192  g_loss:1.7186
# epoch:257  d_loss:0.5697  g_loss:1.6875
# epoch:258  d_loss:0.4506  g_loss:1.7777
# epoch:259  d_loss:0.4775  g_loss:1.8559
# epoch:260  d_loss:0.4420  g_loss:1.7576
# epoch:261  d_loss:0.4868  g_loss:1.5088
# epoch:262  d_loss:0.4798  g_loss:1.7759
# epoch:263  d_loss:0.4659  g_loss:1.6700
# epoch:264  d_loss:0.4022  g_loss:1.8190
# epoch:265  d_loss:0.4088  g_loss:2.1026
# epoch:266  d_loss:0.4013  g_loss:2.1913
# epoch:267  d_loss:0.5125  g_loss:2.0829
# epoch:268  d_loss:0.3777  g_loss:1.7286
# epoch:269  d_loss:0.3672  g_loss:1.9009
# epoch:270  d_loss:0.5276  g_loss:1.8634
# epoch:271  d_loss:0.4038  g_loss:2.0800
# epoch:272  d_loss:0.3178  g_loss:2.3464
# epoch:273  d_loss:0.3993  g_loss:2.4982
# epoch:274  d_loss:0.4113  g_loss:2.5518
# epoch:275  d_loss:0.4259  g_loss:2.0467
# epoch:276  d_loss:0.4759  g_loss:2.0285
# epoch:277  d_loss:0.5087  g_loss:1.7415
# epoch:278  d_loss:0.4231  g_loss:2.2268
# epoch:279  d_loss:0.3951  g_loss:2.0342
# epoch:280  d_loss:0.3860  g_loss:2.2145
# epoch:281  d_loss:0.4070  g_loss:1.9712
# epoch:282  d_loss:0.4153  g_loss:2.0756
# epoch:283  d_loss:0.4204  g_loss:1.8153
# epoch:284  d_loss:0.4629  g_loss:1.8346
# epoch:285  d_loss:0.4598  g_loss:1.7492
# epoch:286  d_loss:0.5078  g_loss:1.7958
# epoch:287  d_loss:0.5060  g_loss:1.9655
# epoch:288  d_loss:0.3830  g_loss:1.9370
# epoch:289  d_loss:0.4517  g_loss:1.9471
# epoch:290  d_loss:0.4985  g_loss:1.7325
# epoch:291  d_loss:0.5255  g_loss:1.7351
# epoch:292  d_loss:0.3833  g_loss:1.7808
# epoch:293  d_loss:0.4814  g_loss:1.3423
# epoch:294  d_loss:0.5285  g_loss:1.6696
# epoch:295  d_loss:0.4014  g_loss:1.5498
# epoch:296  d_loss:0.4637  g_loss:1.7816
# epoch:297  d_loss:0.4922  g_loss:1.9558
# epoch:298  d_loss:0.3645  g_loss:1.8304
# epoch:299  d_loss:0.4872  g_loss:1.9977
# epoch:300  d_loss:0.4393  g_loss:1.7213
# epoch:301  d_loss:0.4036  g_loss:1.9285
# epoch:302  d_loss:0.4106  g_loss:1.5787
# epoch:303  d_loss:0.3702  g_loss:1.5344
# epoch:304  d_loss:0.4036  g_loss:1.6310
# epoch:305  d_loss:0.4890  g_loss:1.8645
# epoch:306  d_loss:0.4666  g_loss:1.7030
# epoch:307  d_loss:0.4324  g_loss:1.8368
# epoch:308  d_loss:0.3912  g_loss:2.0064
# epoch:309  d_loss:0.4036  g_loss:1.6876
# epoch:310  d_loss:0.4225  g_loss:1.5599
# epoch:311  d_loss:0.2574  g_loss:2.1416
# epoch:312  d_loss:0.5277  g_loss:1.9130
# epoch:313  d_loss:0.3555  g_loss:1.8926
# epoch:314  d_loss:0.3942  g_loss:2.3595
# epoch:315  d_loss:0.4263  g_loss:2.2191
# epoch:316  d_loss:0.4063  g_loss:2.2643
# epoch:317  d_loss:0.5533  g_loss:1.7594
# epoch:318  d_loss:0.4513  g_loss:1.6683
# epoch:319  d_loss:0.3675  g_loss:1.3569
# epoch:320  d_loss:0.4156  g_loss:1.6051
# epoch:321  d_loss:0.4105  g_loss:1.9642
# epoch:322  d_loss:0.3625  g_loss:2.8313
# epoch:323  d_loss:0.4662  g_loss:2.0120
# epoch:324  d_loss:0.3290  g_loss:1.9725
# epoch:325  d_loss:0.3658  g_loss:1.5477
# epoch:326  d_loss:0.3899  g_loss:1.4488
# epoch:327  d_loss:0.3985  g_loss:1.9361
# epoch:328  d_loss:0.3099  g_loss:2.1015
# epoch:329  d_loss:0.4123  g_loss:2.3899
# epoch:330  d_loss:0.3652  g_loss:2.3024
# epoch:331  d_loss:0.3779  g_loss:2.0562
# epoch:332  d_loss:0.3344  g_loss:1.9051
# epoch:333  d_loss:0.3453  g_loss:2.0340
# epoch:334  d_loss:0.4713  g_loss:2.1212
# epoch:335  d_loss:0.2617  g_loss:2.3641
# epoch:336  d_loss:0.3708  g_loss:2.2913
# epoch:337  d_loss:0.3255  g_loss:1.9871
# epoch:338  d_loss:0.3453  g_loss:1.7365
# epoch:339  d_loss:0.3474  g_loss:1.9206
# epoch:340  d_loss:0.3830  g_loss:1.6626
# epoch:341  d_loss:0.3361  g_loss:1.8256
# epoch:342  d_loss:0.3934  g_loss:2.4754
# epoch:343  d_loss:0.3138  g_loss:2.2825
# epoch:344  d_loss:0.4270  g_loss:2.1172
# epoch:345  d_loss:0.3825  g_loss:1.6996
# epoch:346  d_loss:0.5266  g_loss:1.6952
# epoch:347  d_loss:0.4078  g_loss:1.7490
# epoch:348  d_loss:0.3958  g_loss:2.2030
# epoch:349  d_loss:0.3678  g_loss:2.3633
# epoch:350  d_loss:0.5080  g_loss:2.1677
# epoch:351  d_loss:0.3736  g_loss:2.1119
# epoch:352  d_loss:0.4481  g_loss:1.6904
# epoch:353  d_loss:0.4685  g_loss:1.5239
# epoch:354  d_loss:0.3273  g_loss:1.7293
# epoch:355  d_loss:0.3638  g_loss:2.1004
# epoch:356  d_loss:0.4067  g_loss:2.3736
# epoch:357  d_loss:0.4368  g_loss:1.9533
# epoch:358  d_loss:0.3627  g_loss:2.5234
# epoch:359  d_loss:0.3366  g_loss:1.9228
# epoch:360  d_loss:0.3794  g_loss:2.1119
# epoch:361  d_loss:0.3180  g_loss:2.0842
# epoch:362  d_loss:0.3361  g_loss:2.1544
# epoch:363  d_loss:0.3937  g_loss:2.4093
# epoch:364  d_loss:0.3286  g_loss:2.1656
# epoch:365  d_loss:0.2454  g_loss:2.6490
# epoch:366  d_loss:0.3494  g_loss:2.9289
# epoch:367  d_loss:0.3341  g_loss:2.5609
# epoch:368  d_loss:0.3337  g_loss:1.9089
# epoch:369  d_loss:0.3526  g_loss:2.0456
# epoch:370  d_loss:0.2706  g_loss:2.0857
# epoch:371  d_loss:0.2249  g_loss:2.5490
# epoch:372  d_loss:0.2763  g_loss:2.6353
# epoch:373  d_loss:0.2699  g_loss:2.6467
# epoch:374  d_loss:0.3441  g_loss:2.2079
# epoch:375  d_loss:0.2826  g_loss:1.9027
# epoch:376  d_loss:0.4136  g_loss:2.2885
# epoch:377  d_loss:0.3586  g_loss:2.7965
# epoch:378  d_loss:0.3311  g_loss:2.9293
# epoch:379  d_loss:0.4270  g_loss:2.8728
# epoch:380  d_loss:0.4296  g_loss:2.0274
# epoch:381  d_loss:0.3104  g_loss:1.8668
# epoch:382  d_loss:0.3776  g_loss:2.3523
# epoch:383  d_loss:0.3484  g_loss:2.5350
# epoch:384  d_loss:0.2671  g_loss:3.1800
# epoch:385  d_loss:0.2667  g_loss:2.9807
# epoch:386  d_loss:0.3957  g_loss:2.3327
# epoch:387  d_loss:0.2539  g_loss:2.2708
# epoch:388  d_loss:0.3186  g_loss:2.1625
# epoch:389  d_loss:0.2996  g_loss:2.7650
# epoch:390  d_loss:0.2223  g_loss:3.0482
# epoch:391  d_loss:0.4664  g_loss:2.9487
# epoch:392  d_loss:0.3237  g_loss:2.5006
# epoch:393  d_loss:0.4707  g_loss:2.0921
# epoch:394  d_loss:0.2842  g_loss:2.4178
# epoch:395  d_loss:0.3073  g_loss:2.6634
# epoch:396  d_loss:0.3325  g_loss:2.4342
# epoch:397  d_loss:0.4069  g_loss:2.3454
# epoch:398  d_loss:0.3125  g_loss:2.3822
# epoch:399  d_loss:0.4201  g_loss:1.7782
# epoch:400  d_loss:0.3017  g_loss:1.9140
# epoch:401  d_loss:0.3740  g_loss:2.1807
# epoch:402  d_loss:0.1963  g_loss:2.7258
# epoch:403  d_loss:0.2428  g_loss:3.2321
# epoch:404  d_loss:0.3449  g_loss:2.4789
# epoch:405  d_loss:0.2728  g_loss:2.1426
# epoch:406  d_loss:0.3371  g_loss:2.1326
# epoch:407  d_loss:0.2741  g_loss:2.0518
# epoch:408  d_loss:0.2027  g_loss:2.1930
# epoch:409  d_loss:0.2942  g_loss:2.4122
# epoch:410  d_loss:0.2197  g_loss:2.8215
# epoch:411  d_loss:0.1669  g_loss:3.1318
# epoch:412  d_loss:0.1986  g_loss:3.1873
# epoch:413  d_loss:0.1570  g_loss:2.7066
# epoch:414  d_loss:0.2346  g_loss:2.0918
# epoch:415  d_loss:0.1656  g_loss:2.3490
# epoch:416  d_loss:0.1764  g_loss:2.5093
# epoch:417  d_loss:0.2193  g_loss:2.4025
# epoch:418  d_loss:0.2089  g_loss:2.7474
# epoch:419  d_loss:0.1816  g_loss:2.4171
# epoch:420  d_loss:0.3254  g_loss:2.5570
# epoch:421  d_loss:0.2297  g_loss:2.1083
# epoch:422  d_loss:0.1966  g_loss:2.2110
# epoch:423  d_loss:0.1496  g_loss:2.6063
# epoch:424  d_loss:0.1949  g_loss:2.4542
# epoch:425  d_loss:0.2776  g_loss:2.4622
# epoch:426  d_loss:0.1922  g_loss:3.2105
# epoch:427  d_loss:0.2622  g_loss:2.4351
# epoch:428  d_loss:0.2227  g_loss:2.5318
# epoch:429  d_loss:0.2669  g_loss:2.7085
# epoch:430  d_loss:0.1737  g_loss:3.3422
# epoch:431  d_loss:0.4100  g_loss:2.4823
# epoch:432  d_loss:0.2152  g_loss:2.2473
# epoch:433  d_loss:0.3048  g_loss:1.8506
# epoch:434  d_loss:0.3949  g_loss:2.4918
# epoch:435  d_loss:0.1878  g_loss:3.6299
# epoch:436  d_loss:0.4687  g_loss:3.6633
# epoch:437  d_loss:0.3437  g_loss:2.4142
# epoch:438  d_loss:0.2734  g_loss:2.2583
# epoch:439  d_loss:0.3141  g_loss:2.2464
# epoch:440  d_loss:0.2095  g_loss:2.8249
# epoch:441  d_loss:0.3415  g_loss:3.4942
# epoch:442  d_loss:0.2401  g_loss:3.6370
# epoch:443  d_loss:0.2417  g_loss:2.9225
# epoch:444  d_loss:0.2549  g_loss:2.3612
# epoch:445  d_loss:0.2540  g_loss:2.7823
# epoch:446  d_loss:0.1865  g_loss:3.0679
# epoch:447  d_loss:0.1163  g_loss:4.2511
# epoch:448  d_loss:0.1965  g_loss:4.1819
# epoch:449  d_loss:0.2721  g_loss:4.7096
# epoch:450  d_loss:0.2244  g_loss:3.6317
# epoch:451  d_loss:0.2113  g_loss:3.3466
# epoch:452  d_loss:0.3418  g_loss:3.0763
# epoch:453  d_loss:0.1480  g_loss:3.3355
# epoch:454  d_loss:0.1815  g_loss:3.4845
# epoch:455  d_loss:0.1270  g_loss:4.2061
# epoch:456  d_loss:0.2060  g_loss:3.9995
# epoch:457  d_loss:0.1579  g_loss:4.3352
# epoch:458  d_loss:0.1707  g_loss:3.8076
# epoch:459  d_loss:0.1427  g_loss:3.4969
# epoch:460  d_loss:0.0836  g_loss:3.5886
# epoch:461  d_loss:0.1827  g_loss:3.2087
# epoch:462  d_loss:0.1539  g_loss:3.3758
# epoch:463  d_loss:0.1094  g_loss:3.3414
# epoch:464  d_loss:0.1050  g_loss:3.1692
# epoch:465  d_loss:0.1823  g_loss:4.1494
# epoch:466  d_loss:0.1244  g_loss:4.0715
# epoch:467  d_loss:0.2299  g_loss:3.6810
# epoch:468  d_loss:0.1863  g_loss:3.0153
# epoch:469  d_loss:0.1324  g_loss:2.7607
# epoch:470  d_loss:0.2755  g_loss:2.7815
# epoch:471  d_loss:0.1658  g_loss:2.9273
# epoch:472  d_loss:0.2744  g_loss:3.0300
# epoch:473  d_loss:0.1547  g_loss:3.5075
# epoch:474  d_loss:0.1658  g_loss:3.7779
# epoch:475  d_loss:0.1570  g_loss:3.7091
# epoch:476  d_loss:0.0761  g_loss:3.8441
# epoch:477  d_loss:0.1765  g_loss:3.1013
# epoch:478  d_loss:0.2125  g_loss:4.1905
# epoch:479  d_loss:0.2082  g_loss:3.4201
# epoch:480  d_loss:0.3475  g_loss:2.3659
# epoch:481  d_loss:0.1998  g_loss:3.0694
# epoch:482  d_loss:0.1478  g_loss:3.0077
# epoch:483  d_loss:0.1887  g_loss:3.1019
# epoch:484  d_loss:0.2242  g_loss:2.2781
# epoch:485  d_loss:0.2735  g_loss:1.7106
# epoch:486  d_loss:0.1847  g_loss:2.8088
# epoch:487  d_loss:0.1733  g_loss:3.1511
# epoch:488  d_loss:0.3057  g_loss:2.7849
# epoch:489  d_loss:0.1620  g_loss:2.7571
# epoch:490  d_loss:0.2446  g_loss:2.8701
# epoch:491  d_loss:0.2450  g_loss:2.1341
# epoch:492  d_loss:0.2700  g_loss:2.9458
# epoch:493  d_loss:0.1731  g_loss:3.5111
# epoch:494  d_loss:0.1898  g_loss:3.2893
# epoch:495  d_loss:0.1775  g_loss:3.4868
# epoch:496  d_loss:0.2292  g_loss:2.6673
# epoch:497  d_loss:0.3200  g_loss:2.7228
# epoch:498  d_loss:0.1052  g_loss:3.6493
# epoch:499  d_loss:0.1812  g_loss:4.0092
# epoch:500  d_loss:0.2539  g_loss:3.1924
# epoch:501  d_loss:0.2297  g_loss:2.0909
# epoch:502  d_loss:0.1119  g_loss:2.5987
# epoch:503  d_loss:0.0854  g_loss:3.3922
# epoch:504  d_loss:0.1510  g_loss:4.2360
# epoch:505  d_loss:0.0669  g_loss:5.5317
# epoch:506  d_loss:0.2655  g_loss:3.3392
# epoch:507  d_loss:0.1405  g_loss:2.1531
# epoch:508  d_loss:0.2230  g_loss:2.6813
# epoch:509  d_loss:0.1185  g_loss:3.4662
# epoch:510  d_loss:0.1182  g_loss:4.9962
# epoch:511  d_loss:0.1780  g_loss:4.5984
# epoch:512  d_loss:0.1747  g_loss:3.6879
# epoch:513  d_loss:0.2607  g_loss:2.6052
# epoch:514  d_loss:0.2163  g_loss:2.3410
# epoch:515  d_loss:0.1428  g_loss:3.2865
# epoch:516  d_loss:0.1683  g_loss:3.2542
# epoch:517  d_loss:0.1437  g_loss:3.4574
# epoch:518  d_loss:0.2525  g_loss:2.8607
# epoch:519  d_loss:0.2082  g_loss:2.3881
# epoch:520  d_loss:0.1562  g_loss:2.9722
# epoch:521  d_loss:0.1449  g_loss:3.4113
# epoch:522  d_loss:0.2814  g_loss:3.1427
# epoch:523  d_loss:0.2648  g_loss:1.9683
# epoch:524  d_loss:0.1879  g_loss:1.9835
# epoch:525  d_loss:0.2183  g_loss:1.7519
# epoch:526  d_loss:0.2662  g_loss:2.5993
# epoch:527  d_loss:0.2469  g_loss:3.9451
# epoch:528  d_loss:0.3479  g_loss:2.9173
# epoch:529  d_loss:0.3688  g_loss:2.4624
# epoch:530  d_loss:0.2278  g_loss:2.5652
# epoch:531  d_loss:0.2770  g_loss:2.9697
# epoch:532  d_loss:0.2362  g_loss:3.5583
# epoch:533  d_loss:0.2941  g_loss:3.2702
# epoch:534  d_loss:0.1832  g_loss:3.0180
# epoch:535  d_loss:0.1310  g_loss:2.9043
# epoch:536  d_loss:0.1926  g_loss:2.2729
# epoch:537  d_loss:0.2486  g_loss:2.0628
# epoch:538  d_loss:0.1829  g_loss:3.0987
# epoch:539  d_loss:0.1878  g_loss:3.1203
# epoch:540  d_loss:0.1852  g_loss:2.9031
# epoch:541  d_loss:0.1615  g_loss:3.3497
# epoch:542  d_loss:0.1951  g_loss:3.0009
# epoch:543  d_loss:0.1125  g_loss:3.0968
# epoch:544  d_loss:0.1348  g_loss:2.4282
# epoch:545  d_loss:0.1456  g_loss:2.9092
# epoch:546  d_loss:0.1536  g_loss:2.7047
# epoch:547  d_loss:0.1205  g_loss:3.0194
# epoch:548  d_loss:0.1984  g_loss:2.6559
# epoch:549  d_loss:0.1165  g_loss:3.0497
# epoch:550  d_loss:0.1805  g_loss:3.0110
# epoch:551  d_loss:0.1002  g_loss:2.7706
# epoch:552  d_loss:0.2163  g_loss:2.7150
# epoch:553  d_loss:0.3435  g_loss:2.9913
# epoch:554  d_loss:0.2677  g_loss:2.6988
# epoch:555  d_loss:0.3212  g_loss:2.5317
# epoch:556  d_loss:0.4387  g_loss:2.1473
# epoch:557  d_loss:0.4454  g_loss:1.6800
# epoch:558  d_loss:0.4218  g_loss:2.4736
# epoch:559  d_loss:0.4949  g_loss:1.9074
# epoch:560  d_loss:0.5492  g_loss:1.8354
# epoch:561  d_loss:0.2167  g_loss:4.0080
# epoch:562  d_loss:0.4780  g_loss:2.8513
# epoch:563  d_loss:0.9007  g_loss:1.5109
# epoch:564  d_loss:0.9114  g_loss:0.9928
# epoch:565  d_loss:0.8537  g_loss:1.2602
# epoch:566  d_loss:0.5470  g_loss:1.7639
# epoch:567  d_loss:0.6651  g_loss:2.5847
# epoch:568  d_loss:0.6310  g_loss:2.4795
# epoch:569  d_loss:0.6122  g_loss:1.7129
# epoch:570  d_loss:0.6049  g_loss:2.1495
# epoch:571  d_loss:0.7741  g_loss:1.7046
# epoch:572  d_loss:0.8060  g_loss:1.1827
# epoch:573  d_loss:0.7626  g_loss:1.3225
# epoch:574  d_loss:0.4569  g_loss:3.0497
# epoch:575  d_loss:0.7085  g_loss:3.3246
# epoch:576  d_loss:0.9185  g_loss:1.5984
# epoch:577  d_loss:0.7311  g_loss:0.8224
# epoch:578  d_loss:0.3862  g_loss:1.4853
# epoch:579  d_loss:0.2001  g_loss:3.4117
# epoch:580  d_loss:0.3461  g_loss:3.3750
# epoch:581  d_loss:0.8222  g_loss:2.8203
# epoch:582  d_loss:0.9577  g_loss:2.2453
# epoch:583  d_loss:0.9681  g_loss:1.6299
# epoch:584  d_loss:0.9193  g_loss:1.5415
# epoch:585  d_loss:0.7481  g_loss:2.0663
# epoch:586  d_loss:0.8919  g_loss:3.0409
# epoch:587  d_loss:0.4520  g_loss:3.6194
# epoch:588  d_loss:0.4545  g_loss:3.6029
# epoch:589  d_loss:0.2725  g_loss:4.3780
# epoch:590  d_loss:0.6284  g_loss:4.0358
# epoch:591  d_loss:0.5132  g_loss:3.7154
# epoch:592  d_loss:0.1987  g_loss:2.8990
# epoch:593  d_loss:0.3527  g_loss:2.6583
# epoch:594  d_loss:0.4112  g_loss:2.5033
# epoch:595  d_loss:0.2922  g_loss:2.9344
# epoch:596  d_loss:0.3211  g_loss:2.5914
# epoch:597  d_loss:0.2996  g_loss:3.3874
# epoch:598  d_loss:0.1612  g_loss:3.4532
# epoch:599  d_loss:0.2263  g_loss:3.1759
# epoch:600  d_loss:0.4598  g_loss:2.8042
# epoch:601  d_loss:0.2853  g_loss:2.4467
# epoch:602  d_loss:0.3699  g_loss:1.5713
# epoch:603  d_loss:0.4702  g_loss:1.5746
# epoch:604  d_loss:0.4074  g_loss:1.9661
# epoch:605  d_loss:0.2947  g_loss:2.3357
# epoch:606  d_loss:0.5296  g_loss:2.2138
# epoch:607  d_loss:0.4878  g_loss:1.6937
# epoch:608  d_loss:0.6324  g_loss:1.6183
# epoch:609  d_loss:0.4511  g_loss:1.2932
# epoch:610  d_loss:0.5808  g_loss:1.6253
# epoch:611  d_loss:0.4026  g_loss:1.6113
# epoch:612  d_loss:0.4483  g_loss:1.9441
# epoch:613  d_loss:0.3260  g_loss:2.1963
# epoch:614  d_loss:0.4713  g_loss:1.8673
# epoch:615  d_loss:0.5056  g_loss:1.7677
# epoch:616  d_loss:0.4563  g_loss:1.9269
# epoch:617  d_loss:0.4054  g_loss:1.8820
# epoch:618  d_loss:0.4871  g_loss:1.4294
# epoch:619  d_loss:0.4383  g_loss:2.0366
# epoch:620  d_loss:0.3172  g_loss:2.5119
# epoch:621  d_loss:0.2952  g_loss:2.0320
# epoch:622  d_loss:0.4363  g_loss:2.3371
# epoch:623  d_loss:0.5199  g_loss:2.0006
# epoch:624  d_loss:0.4578  g_loss:1.2483
# epoch:625  d_loss:0.5436  g_loss:1.4897
# epoch:626  d_loss:0.4432  g_loss:1.6909
# epoch:627  d_loss:0.5414  g_loss:1.6114
# epoch:628  d_loss:0.6620  g_loss:1.9746
# epoch:629  d_loss:0.5825  g_loss:1.9963
# epoch:630  d_loss:0.7351  g_loss:1.5138
# epoch:631  d_loss:0.7861  g_loss:0.7327
# epoch:632  d_loss:0.7678  g_loss:0.9411
# epoch:633  d_loss:0.6767  g_loss:1.2804
# epoch:634  d_loss:0.7183  g_loss:1.3682
# epoch:635  d_loss:0.5587  g_loss:1.5153
# epoch:636  d_loss:0.4541  g_loss:1.8880
# epoch:637  d_loss:0.4084  g_loss:1.8638
# epoch:638  d_loss:0.3146  g_loss:1.9621
# epoch:639  d_loss:0.3602  g_loss:1.8956
# epoch:640  d_loss:0.4015  g_loss:1.7089
# epoch:641  d_loss:0.5055  g_loss:1.4860
# epoch:642  d_loss:0.3149  g_loss:1.9675
# epoch:643  d_loss:0.4236  g_loss:1.9355
# epoch:644  d_loss:0.3768  g_loss:2.1644
# epoch:645  d_loss:0.3349  g_loss:1.8776
# epoch:646  d_loss:0.4975  g_loss:1.4418
# epoch:647  d_loss:0.6056  g_loss:1.4087
# epoch:648  d_loss:0.5586  g_loss:1.0745
# epoch:649  d_loss:0.5281  g_loss:1.5193
# epoch:650  d_loss:0.4155  g_loss:1.7915
# epoch:651  d_loss:0.6097  g_loss:1.6156
# epoch:652  d_loss:0.5649  g_loss:1.9827
# epoch:653  d_loss:0.6795  g_loss:1.3543
# epoch:654  d_loss:0.7375  g_loss:1.2882
# epoch:655  d_loss:0.7255  g_loss:1.0544
# epoch:656  d_loss:0.6564  g_loss:0.9921
# epoch:657  d_loss:0.5362  g_loss:1.1591
# epoch:658  d_loss:0.5444  g_loss:1.3259
# epoch:659  d_loss:0.4621  g_loss:1.6424
# epoch:660  d_loss:0.5291  g_loss:1.6890
# epoch:661  d_loss:0.4292  g_loss:1.7721
# epoch:662  d_loss:0.5711  g_loss:1.3196
# epoch:663  d_loss:0.4457  g_loss:1.7239
# epoch:664  d_loss:0.3563  g_loss:1.5843
# epoch:665  d_loss:0.2745  g_loss:1.7325
# epoch:666  d_loss:0.3073  g_loss:1.7436
# epoch:667  d_loss:0.2750  g_loss:2.3584
# epoch:668  d_loss:0.3989  g_loss:1.9043
# epoch:669  d_loss:0.4552  g_loss:1.7609
# epoch:670  d_loss:0.4268  g_loss:1.9184
# epoch:671  d_loss:0.4072  g_loss:1.8310
# epoch:672  d_loss:0.3445  g_loss:1.7546
# epoch:673  d_loss:0.3295  g_loss:1.8326
# epoch:674  d_loss:0.4022  g_loss:1.9806
# epoch:675  d_loss:0.3152  g_loss:1.7931
# epoch:676  d_loss:0.5071  g_loss:1.8115
# epoch:677  d_loss:0.4150  g_loss:1.9246
# epoch:678  d_loss:0.5040  g_loss:1.7772
# epoch:679  d_loss:0.7091  g_loss:1.3150
# epoch:680  d_loss:0.6079  g_loss:1.7328
# epoch:681  d_loss:0.4907  g_loss:1.7022
# epoch:682  d_loss:0.5434  g_loss:1.9588
# epoch:683  d_loss:0.5238  g_loss:1.8503
# epoch:684  d_loss:0.5995  g_loss:1.8318
# epoch:685  d_loss:0.4131  g_loss:1.7006
# epoch:686  d_loss:0.5419  g_loss:1.3816
# epoch:687  d_loss:0.4434  g_loss:1.5646
# epoch:688  d_loss:0.3478  g_loss:1.9193
# epoch:689  d_loss:0.3533  g_loss:2.3661
# epoch:690  d_loss:0.2468  g_loss:2.6899
# epoch:691  d_loss:0.2835  g_loss:2.5251
# epoch:692  d_loss:0.2851  g_loss:2.4575
# epoch:693  d_loss:0.3635  g_loss:2.3392
# epoch:694  d_loss:0.2644  g_loss:2.2602
# epoch:695  d_loss:0.2441  g_loss:2.4069
# epoch:696  d_loss:0.2317  g_loss:2.3940
# epoch:697  d_loss:0.2652  g_loss:2.9224
# epoch:698  d_loss:0.2932  g_loss:2.2964
# epoch:699  d_loss:0.3485  g_loss:2.2126
# epoch:700  d_loss:0.3907  g_loss:1.9713
# epoch:701  d_loss:0.3727  g_loss:1.6589
# epoch:702  d_loss:0.4884  g_loss:2.1202
# epoch:703  d_loss:0.5223  g_loss:1.9818
# epoch:704  d_loss:0.7242  g_loss:2.2061
# epoch:705  d_loss:1.3347  g_loss:1.3487
# epoch:706  d_loss:1.2549  g_loss:0.7577
# epoch:707  d_loss:0.8788  g_loss:0.9605
# epoch:708  d_loss:0.7238  g_loss:1.4789
# epoch:709  d_loss:0.8706  g_loss:2.2452
# epoch:710  d_loss:0.7505  g_loss:2.5213
# epoch:711  d_loss:0.5563  g_loss:2.1094
# epoch:712  d_loss:0.7412  g_loss:1.8315
# epoch:713  d_loss:0.6073  g_loss:1.7222
# epoch:714  d_loss:0.3741  g_loss:2.1908
# epoch:715  d_loss:0.2652  g_loss:2.8190
# epoch:716  d_loss:0.2019  g_loss:3.4018
# epoch:717  d_loss:0.2596  g_loss:3.7380
# epoch:718  d_loss:0.3897  g_loss:2.8399
# epoch:719  d_loss:0.3101  g_loss:2.5963
# epoch:720  d_loss:0.3915  g_loss:2.3222
# epoch:721  d_loss:0.3753  g_loss:2.2832
# epoch:722  d_loss:0.2514  g_loss:2.6757
# epoch:723  d_loss:0.3280  g_loss:2.3168
# epoch:724  d_loss:0.2627  g_loss:2.6552
# epoch:725  d_loss:0.2665  g_loss:3.1480
# epoch:726  d_loss:0.2061  g_loss:3.2737
# epoch:727  d_loss:0.3299  g_loss:3.3782
# epoch:728  d_loss:0.4810  g_loss:2.4199
# epoch:729  d_loss:0.3696  g_loss:2.7621
# epoch:730  d_loss:0.3400  g_loss:2.6916
# epoch:731  d_loss:0.4143  g_loss:2.2966
# epoch:732  d_loss:0.5125  g_loss:1.9178
# epoch:733  d_loss:0.6025  g_loss:1.5515
# epoch:734  d_loss:0.6360  g_loss:1.6329
# epoch:735  d_loss:0.4134  g_loss:2.0174
# epoch:736  d_loss:0.6285  g_loss:2.0999
# epoch:737  d_loss:0.6819  g_loss:1.6904
# epoch:738  d_loss:0.5885  g_loss:1.8805
# epoch:739  d_loss:0.8995  g_loss:1.4853
# epoch:740  d_loss:0.3930  g_loss:1.5981
# epoch:741  d_loss:0.5591  g_loss:1.5208
# epoch:742  d_loss:0.6893  g_loss:1.6328
# epoch:743  d_loss:0.6721  g_loss:1.3826
# epoch:744  d_loss:0.6779  g_loss:1.7059
# epoch:745  d_loss:0.5745  g_loss:1.6201
# epoch:746  d_loss:0.5354  g_loss:1.5835
# epoch:747  d_loss:0.6566  g_loss:1.6292
# epoch:748  d_loss:0.7518  g_loss:1.0762
# epoch:749  d_loss:0.6507  g_loss:1.4358
# epoch:750  d_loss:0.4294  g_loss:1.5681
# epoch:751  d_loss:0.4780  g_loss:1.4801
# epoch:752  d_loss:0.3815  g_loss:2.0582
# epoch:753  d_loss:0.2875  g_loss:2.6773
# epoch:754  d_loss:0.4069  g_loss:2.5100
# epoch:755  d_loss:0.3563  g_loss:2.6151
# epoch:756  d_loss:0.2616  g_loss:2.1533
# epoch:757  d_loss:0.3304  g_loss:2.3743
# epoch:758  d_loss:0.2119  g_loss:2.8064
# epoch:759  d_loss:0.2004  g_loss:2.7699
# epoch:760  d_loss:0.2184  g_loss:2.8578
# epoch:761  d_loss:0.3153  g_loss:2.6214
# epoch:762  d_loss:0.1737  g_loss:3.0314
# epoch:763  d_loss:0.2423  g_loss:2.7270
# epoch:764  d_loss:0.1832  g_loss:2.6754
# epoch:765  d_loss:0.1784  g_loss:2.6885
# epoch:766  d_loss:0.2766  g_loss:2.3483
# epoch:767  d_loss:0.1539  g_loss:3.3892
# epoch:768  d_loss:0.2468  g_loss:2.9044
# epoch:769  d_loss:0.1180  g_loss:2.7037
# epoch:770  d_loss:0.2866  g_loss:2.9233
# epoch:771  d_loss:0.4003  g_loss:2.7069
# epoch:772  d_loss:0.3336  g_loss:1.7000
# epoch:773  d_loss:0.3292  g_loss:1.7724
# epoch:774  d_loss:0.4026  g_loss:2.1365
# epoch:775  d_loss:0.5224  g_loss:1.6058
# epoch:776  d_loss:0.5753  g_loss:2.4493
# epoch:777  d_loss:0.5149  g_loss:2.0506
# epoch:778  d_loss:0.6234  g_loss:1.7360
# epoch:779  d_loss:0.7266  g_loss:1.6694
# epoch:780  d_loss:0.6543  g_loss:1.8744
# epoch:781  d_loss:0.4560  g_loss:2.1364
# epoch:782  d_loss:0.5634  g_loss:1.9434
# epoch:783  d_loss:0.4671  g_loss:1.5566
# epoch:784  d_loss:0.6317  g_loss:1.6607
# epoch:785  d_loss:0.5537  g_loss:1.3573
# epoch:786  d_loss:0.4559  g_loss:1.3500
# epoch:787  d_loss:0.4575  g_loss:1.9252
# epoch:788  d_loss:0.3634  g_loss:2.0209
# epoch:789  d_loss:0.4482  g_loss:2.2897
# epoch:790  d_loss:0.3664  g_loss:2.7339
# epoch:791  d_loss:0.2879  g_loss:2.4381
# epoch:792  d_loss:0.3040  g_loss:2.1300
# epoch:793  d_loss:0.2993  g_loss:2.2316
# epoch:794  d_loss:0.2995  g_loss:2.0497
# epoch:795  d_loss:0.2012  g_loss:2.5101
# epoch:796  d_loss:0.1441  g_loss:2.3134
# epoch:797  d_loss:0.2487  g_loss:2.7565
# epoch:798  d_loss:0.2290  g_loss:3.1455
# epoch:799  d_loss:0.3277  g_loss:3.3541
# epoch:800  d_loss:0.2576  g_loss:2.7079
# epoch:801  d_loss:0.2617  g_loss:2.4857
# epoch:802  d_loss:0.3343  g_loss:2.1660
# epoch:803  d_loss:0.3201  g_loss:2.3220
# epoch:804  d_loss:0.3385  g_loss:2.6344
# epoch:805  d_loss:0.3395  g_loss:2.4123
# epoch:806  d_loss:0.4045  g_loss:1.8480
# epoch:807  d_loss:0.4395  g_loss:1.7481
# epoch:808  d_loss:0.5091  g_loss:1.7787
# epoch:809  d_loss:0.5976  g_loss:2.1158
# epoch:810  d_loss:0.6685  g_loss:1.6154
# epoch:811  d_loss:0.6321  g_loss:1.4261
# epoch:812  d_loss:0.6876  g_loss:1.1105
# epoch:813  d_loss:0.5884  g_loss:1.5588
# epoch:814  d_loss:0.6869  g_loss:1.3871
# epoch:815  d_loss:0.6780  g_loss:2.0083
# epoch:816  d_loss:0.6915  g_loss:1.4574
# epoch:817  d_loss:0.5478  g_loss:1.3521
# epoch:818  d_loss:0.4976  g_loss:1.3117
# epoch:819  d_loss:0.6069  g_loss:1.4821
# epoch:820  d_loss:0.4236  g_loss:1.6649
# epoch:821  d_loss:0.3879  g_loss:1.8798
# epoch:822  d_loss:0.5413  g_loss:1.7892
# epoch:823  d_loss:0.6029  g_loss:1.3975
# epoch:824  d_loss:0.3917  g_loss:1.4844
# epoch:825  d_loss:0.2864  g_loss:1.3040
# epoch:826  d_loss:0.3061  g_loss:1.4417
# epoch:827  d_loss:0.4462  g_loss:1.5040
# epoch:828  d_loss:0.4515  g_loss:1.3704
# epoch:829  d_loss:0.4052  g_loss:1.5522
# epoch:830  d_loss:0.3621  g_loss:1.7515
# epoch:831  d_loss:0.4501  g_loss:1.6245
# epoch:832  d_loss:0.4827  g_loss:1.5293
# epoch:833  d_loss:0.4333  g_loss:1.8327
# epoch:834  d_loss:0.3372  g_loss:1.3917
# epoch:835  d_loss:0.5418  g_loss:1.2394
# epoch:836  d_loss:0.4772  g_loss:1.3851
# epoch:837  d_loss:0.7412  g_loss:1.4758
# epoch:838  d_loss:0.5122  g_loss:1.4519
# epoch:839  d_loss:0.4686  g_loss:1.7425
# epoch:840  d_loss:0.5301  g_loss:1.8344
# epoch:841  d_loss:0.5433  g_loss:1.5306
# epoch:842  d_loss:0.5028  g_loss:1.3905
# epoch:843  d_loss:0.7117  g_loss:1.0887
# epoch:844  d_loss:0.7220  g_loss:1.1511
# epoch:845  d_loss:0.7459  g_loss:1.1323
# epoch:846  d_loss:0.6871  g_loss:1.2952
# epoch:847  d_loss:0.5841  g_loss:1.3655
# epoch:848  d_loss:0.5941  g_loss:1.6710
# epoch:849  d_loss:0.4731  g_loss:1.5636
# epoch:850  d_loss:0.5139  g_loss:1.6123
# epoch:851  d_loss:0.7006  g_loss:1.4119
# epoch:852  d_loss:0.6508  g_loss:1.4034
# epoch:853  d_loss:0.5045  g_loss:1.3675
# epoch:854  d_loss:0.4793  g_loss:1.2738
# epoch:855  d_loss:0.3790  g_loss:1.8331
# epoch:856  d_loss:0.2691  g_loss:2.2952
# epoch:857  d_loss:0.3100  g_loss:2.4349
# epoch:858  d_loss:0.2943  g_loss:2.3474
# epoch:859  d_loss:0.2789  g_loss:2.4142
# epoch:860  d_loss:0.3729  g_loss:2.5378
# epoch:861  d_loss:0.3232  g_loss:2.3072
# epoch:862  d_loss:0.2772  g_loss:2.4194
# epoch:863  d_loss:0.2635  g_loss:2.4334
# epoch:864  d_loss:0.2379  g_loss:2.3001
# epoch:865  d_loss:0.2859  g_loss:2.1116
# epoch:866  d_loss:0.2046  g_loss:2.3833
# epoch:867  d_loss:0.2635  g_loss:2.4419
# epoch:868  d_loss:0.3408  g_loss:2.6456
# epoch:869  d_loss:0.3917  g_loss:2.1331
# epoch:870  d_loss:0.4576  g_loss:1.7602
# epoch:871  d_loss:0.5434  g_loss:1.7474
# epoch:872  d_loss:0.5117  g_loss:1.8119
# epoch:873  d_loss:0.4137  g_loss:2.1195
# epoch:874  d_loss:0.6684  g_loss:2.0809
# epoch:875  d_loss:0.8245  g_loss:1.7447
# epoch:876  d_loss:0.8147  g_loss:1.5201
# epoch:877  d_loss:0.8755  g_loss:1.4679
# epoch:878  d_loss:0.9411  g_loss:1.3560
# epoch:879  d_loss:0.6030  g_loss:1.6108
# epoch:880  d_loss:0.6299  g_loss:1.9613
# epoch:881  d_loss:1.0377  g_loss:1.4319
# epoch:882  d_loss:0.7378  g_loss:1.5661
# epoch:883  d_loss:0.8719  g_loss:1.1223
# epoch:884  d_loss:0.6709  g_loss:1.3448
# epoch:885  d_loss:0.8297  g_loss:1.6158
# epoch:886  d_loss:0.6964  g_loss:1.8704
# epoch:887  d_loss:0.6796  g_loss:1.7356
# epoch:888  d_loss:0.6172  g_loss:1.1836
# epoch:889  d_loss:0.4352  g_loss:1.4527
# epoch:890  d_loss:0.3129  g_loss:1.8173
# epoch:891  d_loss:0.3353  g_loss:1.6787
# epoch:892  d_loss:0.4751  g_loss:1.6817
# epoch:893  d_loss:0.4513  g_loss:1.6871
# epoch:894  d_loss:0.2891  g_loss:1.6586
# epoch:895  d_loss:0.3205  g_loss:2.3812
# epoch:896  d_loss:0.3068  g_loss:2.1190
# epoch:897  d_loss:0.2309  g_loss:2.2451
# epoch:898  d_loss:0.2625  g_loss:2.2917
# epoch:899  d_loss:0.2575  g_loss:2.2392
# epoch:900  d_loss:0.2825  g_loss:2.4752
# epoch:901  d_loss:0.3624  g_loss:1.9718
# epoch:902  d_loss:0.3198  g_loss:1.9246
# epoch:903  d_loss:0.2464  g_loss:2.3750
# epoch:904  d_loss:0.3804  g_loss:2.3778
# epoch:905  d_loss:0.3070  g_loss:2.5517
# epoch:906  d_loss:0.5364  g_loss:2.0700
# epoch:907  d_loss:0.3431  g_loss:1.7757
# epoch:908  d_loss:0.4164  g_loss:1.8645
# epoch:909  d_loss:0.3809  g_loss:1.6972
# epoch:910  d_loss:0.3436  g_loss:1.9267
# epoch:911  d_loss:0.3982  g_loss:1.9869
# epoch:912  d_loss:0.4927  g_loss:1.7881
# epoch:913  d_loss:0.3712  g_loss:1.9423
# epoch:914  d_loss:0.5410  g_loss:1.5303
# epoch:915  d_loss:0.5711  g_loss:1.2674
# epoch:916  d_loss:0.4598  g_loss:1.7657
# epoch:917  d_loss:0.4205  g_loss:1.9322
# epoch:918  d_loss:0.5932  g_loss:1.7626
# epoch:919  d_loss:0.4815  g_loss:1.5920
# epoch:920  d_loss:0.5894  g_loss:1.4024
# epoch:921  d_loss:0.4173  g_loss:1.4917
# epoch:922  d_loss:0.5246  g_loss:1.5156
# epoch:923  d_loss:0.5718  g_loss:1.4977
# epoch:924  d_loss:0.5922  g_loss:1.2170
# epoch:925  d_loss:0.6591  g_loss:1.1081
# epoch:926  d_loss:0.5751  g_loss:1.3869
# epoch:927  d_loss:0.5705  g_loss:1.3730
# epoch:928  d_loss:0.6106  g_loss:1.6083
# epoch:929  d_loss:0.6107  g_loss:1.4722
# epoch:930  d_loss:0.5678  g_loss:1.3257
# epoch:931  d_loss:0.4909  g_loss:1.5897
# epoch:932  d_loss:0.4812  g_loss:1.6167
# epoch:933  d_loss:0.5556  g_loss:1.3770
# epoch:934  d_loss:0.4442  g_loss:1.6671
# epoch:935  d_loss:0.4179  g_loss:1.8471
# epoch:936  d_loss:0.4061  g_loss:1.9910
# epoch:937  d_loss:0.4911  g_loss:1.9292
# epoch:938  d_loss:0.4625  g_loss:1.8470
# epoch:939  d_loss:0.3719  g_loss:1.5682
# epoch:940  d_loss:0.3042  g_loss:2.0848
# epoch:941  d_loss:0.3088  g_loss:2.1123
# epoch:942  d_loss:0.3486  g_loss:2.1744
# epoch:943  d_loss:0.3669  g_loss:2.2373
# epoch:944  d_loss:0.3231  g_loss:2.0259
# epoch:945  d_loss:0.2740  g_loss:2.0004
# epoch:946  d_loss:0.2919  g_loss:2.0342
# epoch:947  d_loss:0.3784  g_loss:1.8881
# epoch:948  d_loss:0.3916  g_loss:1.8024
# epoch:949  d_loss:0.2157  g_loss:2.3511
# epoch:950  d_loss:0.2724  g_loss:2.5397
# epoch:951  d_loss:0.4602  g_loss:2.3168
# epoch:952  d_loss:0.4794  g_loss:2.2837
# epoch:953  d_loss:0.5006  g_loss:1.8614
# epoch:954  d_loss:0.2749  g_loss:1.8448
# epoch:955  d_loss:0.3802  g_loss:1.8194
# epoch:956  d_loss:0.3548  g_loss:1.7655
# epoch:957  d_loss:0.2927  g_loss:2.4189
# epoch:958  d_loss:0.4647  g_loss:2.3762
# epoch:959  d_loss:0.3402  g_loss:2.8411
# epoch:960  d_loss:0.3959  g_loss:2.4297
# epoch:961  d_loss:0.5036  g_loss:1.8819
# epoch:962  d_loss:0.5656  g_loss:1.6702
# epoch:963  d_loss:0.3992  g_loss:2.4247
# epoch:964  d_loss:0.3350  g_loss:2.0040
# epoch:965  d_loss:0.5373  g_loss:2.1364
# epoch:966  d_loss:0.3602  g_loss:2.4498
# epoch:967  d_loss:0.4700  g_loss:2.6630
# epoch:968  d_loss:0.5542  g_loss:2.1543
# epoch:969  d_loss:0.5848  g_loss:1.6513
# epoch:970  d_loss:0.3907  g_loss:1.8382
# epoch:971  d_loss:0.5690  g_loss:1.5137
# epoch:972  d_loss:0.4634  g_loss:2.0014
# epoch:973  d_loss:0.5471  g_loss:2.2711
# epoch:974  d_loss:0.4638  g_loss:2.3674
# epoch:975  d_loss:0.4472  g_loss:2.1301
# epoch:976  d_loss:0.2957  g_loss:2.9917
# epoch:977  d_loss:0.3298  g_loss:2.6234
# epoch:978  d_loss:0.2354  g_loss:2.6167
# epoch:979  d_loss:0.3157  g_loss:2.4186
# epoch:980  d_loss:0.4352  g_loss:2.7609
# epoch:981  d_loss:0.4692  g_loss:2.2399
# epoch:982  d_loss:0.3116  g_loss:2.6375
# epoch:983  d_loss:0.2283  g_loss:2.5304
# epoch:984  d_loss:0.2327  g_loss:2.6628
# epoch:985  d_loss:0.3312  g_loss:2.4896
# epoch:986  d_loss:0.4400  g_loss:2.3570
# epoch:987  d_loss:0.4021  g_loss:2.2640
# epoch:988  d_loss:0.2652  g_loss:2.2558
# epoch:989  d_loss:0.2935  g_loss:2.9799
# epoch:990  d_loss:0.2691  g_loss:2.5279
# epoch:991  d_loss:0.3513  g_loss:2.3236
# epoch:992  d_loss:0.5126  g_loss:2.0361
# epoch:993  d_loss:0.4850  g_loss:1.7844
# epoch:994  d_loss:0.3403  g_loss:1.8163
# epoch:995  d_loss:0.3571  g_loss:2.2139
# epoch:996  d_loss:0.5590  g_loss:2.3675
# epoch:997  d_loss:0.4390  g_loss:1.9641
# epoch:998  d_loss:0.3484  g_loss:2.1707
# epoch:999  d_loss:0.4351  g_loss:1.8384
# epoch:1000  d_loss:0.5177  g_loss:1.8269
# epoch:1001  d_loss:0.4851  g_loss:2.2492
# epoch:1002  d_loss:0.4452  g_loss:2.5317
# epoch:1003  d_loss:0.6084  g_loss:1.9153
# epoch:1004  d_loss:0.4616  g_loss:1.8496
# epoch:1005  d_loss:0.6450  g_loss:1.7954
# epoch:1006  d_loss:0.3601  g_loss:2.5755
# epoch:1007  d_loss:0.4568  g_loss:2.2171
# epoch:1008  d_loss:0.4655  g_loss:2.0980
# epoch:1009  d_loss:0.3777  g_loss:1.8581
# epoch:1010  d_loss:0.4567  g_loss:1.9907
# epoch:1011  d_loss:0.4929  g_loss:1.8919
# epoch:1012  d_loss:0.3918  g_loss:2.0886
# epoch:1013  d_loss:0.3422  g_loss:2.5123
# epoch:1014  d_loss:0.3494  g_loss:2.6869
# epoch:1015  d_loss:0.3043  g_loss:2.6220
# epoch:1016  d_loss:0.3296  g_loss:2.8744
# epoch:1017  d_loss:0.3439  g_loss:2.3348
# epoch:1018  d_loss:0.3975  g_loss:3.0113
# epoch:1019  d_loss:0.2706  g_loss:2.6018
# epoch:1020  d_loss:0.3552  g_loss:2.3140
# epoch:1021  d_loss:0.2343  g_loss:2.6104
# epoch:1022  d_loss:0.2542  g_loss:2.1531
# epoch:1023  d_loss:0.2272  g_loss:2.7823
# epoch:1024  d_loss:0.2637  g_loss:2.6530
# epoch:1025  d_loss:0.2797  g_loss:2.3385
# epoch:1026  d_loss:0.2813  g_loss:2.7662
# epoch:1027  d_loss:0.4502  g_loss:2.5587
# epoch:1028  d_loss:0.1931  g_loss:2.5390
# epoch:1029  d_loss:0.2248  g_loss:2.6810
# epoch:1030  d_loss:0.3349  g_loss:2.6724
# epoch:1031  d_loss:0.2743  g_loss:2.4365
# epoch:1032  d_loss:0.3354  g_loss:2.5370
# epoch:1033  d_loss:0.2956  g_loss:2.6522
# epoch:1034  d_loss:0.3662  g_loss:2.4449
# epoch:1035  d_loss:0.3662  g_loss:2.2904
# epoch:1036  d_loss:0.3025  g_loss:2.4902
# epoch:1037  d_loss:0.4656  g_loss:1.9861
# epoch:1038  d_loss:0.3251  g_loss:2.5038
# epoch:1039  d_loss:0.2915  g_loss:2.3657
# epoch:1040  d_loss:0.3820  g_loss:2.5255
# epoch:1041  d_loss:0.2467  g_loss:2.7289
# epoch:1042  d_loss:0.3842  g_loss:2.5497
# epoch:1043  d_loss:0.4108  g_loss:2.3395
# epoch:1044  d_loss:0.3870  g_loss:2.8151
# epoch:1045  d_loss:0.3346  g_loss:2.8957
# epoch:1046  d_loss:0.3690  g_loss:2.4703
# epoch:1047  d_loss:0.3909  g_loss:2.7745
# epoch:1048  d_loss:0.5225  g_loss:1.9810
# epoch:1049  d_loss:0.6493  g_loss:1.9480
# epoch:1050  d_loss:0.4535  g_loss:2.4450
# epoch:1051  d_loss:0.5939  g_loss:2.4612
# epoch:1052  d_loss:0.4706  g_loss:1.6935
# epoch:1053  d_loss:0.3994  g_loss:1.6565
# epoch:1054  d_loss:0.3006  g_loss:1.8767
# epoch:1055  d_loss:0.2647  g_loss:1.9470
# epoch:1056  d_loss:0.4334  g_loss:2.0146
# epoch:1057  d_loss:0.5087  g_loss:1.8349
# epoch:1058  d_loss:0.3801  g_loss:2.0685
# epoch:1059  d_loss:0.4406  g_loss:2.3431
# epoch:1060  d_loss:0.3698  g_loss:2.3934
# epoch:1061  d_loss:0.3269  g_loss:2.2442
# epoch:1062  d_loss:0.4937  g_loss:1.7500
# epoch:1063  d_loss:0.4601  g_loss:2.0452
# epoch:1064  d_loss:0.3228  g_loss:2.2792
# epoch:1065  d_loss:0.3471  g_loss:2.3260
# epoch:1066  d_loss:0.2598  g_loss:2.4885
# epoch:1067  d_loss:0.3037  g_loss:2.6024
# epoch:1068  d_loss:0.2239  g_loss:2.3216
# epoch:1069  d_loss:0.2683  g_loss:2.4768
# epoch:1070  d_loss:0.2405  g_loss:2.8272
# epoch:1071  d_loss:0.2683  g_loss:2.8907
# epoch:1072  d_loss:0.3249  g_loss:2.7402
# epoch:1073  d_loss:0.3529  g_loss:2.6069
# epoch:1074  d_loss:0.2974  g_loss:3.2354
# epoch:1075  d_loss:0.2808  g_loss:2.6266
# epoch:1076  d_loss:0.3024  g_loss:2.4942
# epoch:1077  d_loss:0.2646  g_loss:2.5282
# epoch:1078  d_loss:0.2577  g_loss:2.1636
# epoch:1079  d_loss:0.3780  g_loss:2.0622
# epoch:1080  d_loss:0.2720  g_loss:2.9438
# epoch:1081  d_loss:0.4429  g_loss:2.3482
# epoch:1082  d_loss:0.3329  g_loss:2.2688
# epoch:1083  d_loss:0.5662  g_loss:1.4939
# epoch:1084  d_loss:0.3200  g_loss:2.0455
# epoch:1085  d_loss:0.4911  g_loss:1.9723
# epoch:1086  d_loss:0.3913  g_loss:1.8646
# epoch:1087  d_loss:0.3656  g_loss:1.8824
# epoch:1088  d_loss:0.3387  g_loss:2.3550
# epoch:1089  d_loss:0.3485  g_loss:2.5092
# epoch:1090  d_loss:0.4022  g_loss:1.9160
# epoch:1091  d_loss:0.4855  g_loss:2.0428
# epoch:1092  d_loss:0.3036  g_loss:2.0922
# epoch:1093  d_loss:0.2950  g_loss:1.8597
# epoch:1094  d_loss:0.2700  g_loss:2.1406
# epoch:1095  d_loss:0.3135  g_loss:1.9945
# epoch:1096  d_loss:0.5116  g_loss:1.8127
# epoch:1097  d_loss:0.3347  g_loss:2.0212
# epoch:1098  d_loss:0.4065  g_loss:1.9104
# epoch:1099  d_loss:0.5470  g_loss:1.9956
# epoch:1100  d_loss:0.4144  g_loss:2.3817
# epoch:1101  d_loss:0.4340  g_loss:1.8725
# epoch:1102  d_loss:0.2568  g_loss:2.6297
# epoch:1103  d_loss:0.4279  g_loss:1.8486
# epoch:1104  d_loss:0.4277  g_loss:2.0044
# epoch:1105  d_loss:0.4676  g_loss:1.8268
# epoch:1106  d_loss:0.4560  g_loss:1.9693
# epoch:1107  d_loss:0.5587  g_loss:2.1546
# epoch:1108  d_loss:0.4024  g_loss:2.0394
# epoch:1109  d_loss:0.4834  g_loss:1.9318
# epoch:1110  d_loss:0.5000  g_loss:2.0919
# epoch:1111  d_loss:0.3075  g_loss:2.3094
# epoch:1112  d_loss:0.4374  g_loss:2.1483
# epoch:1113  d_loss:0.2609  g_loss:2.3410
# epoch:1114  d_loss:0.3504  g_loss:1.9809
# epoch:1115  d_loss:0.3281  g_loss:1.6795
# epoch:1116  d_loss:0.4578  g_loss:1.7038
# epoch:1117  d_loss:0.3682  g_loss:2.1235
# epoch:1118  d_loss:0.4212  g_loss:2.3273
# epoch:1119  d_loss:0.4499  g_loss:2.4976
# epoch:1120  d_loss:0.3950  g_loss:2.6087
# epoch:1121  d_loss:0.4007  g_loss:1.6463
# epoch:1122  d_loss:0.4842  g_loss:1.6581
# epoch:1123  d_loss:0.4068  g_loss:1.2906
# epoch:1124  d_loss:0.3969  g_loss:1.7100
# epoch:1125  d_loss:0.4554  g_loss:1.7242
# epoch:1126  d_loss:0.4682  g_loss:1.9019
# epoch:1127  d_loss:0.2914  g_loss:2.4960
# epoch:1128  d_loss:0.4206  g_loss:1.8042
# epoch:1129  d_loss:0.5402  g_loss:1.2602
# epoch:1130  d_loss:0.6750  g_loss:0.8881
# epoch:1131  d_loss:0.5828  g_loss:1.3063
# epoch:1132  d_loss:0.3901  g_loss:1.7034
# epoch:1133  d_loss:0.3525  g_loss:2.3314
# epoch:1134  d_loss:0.4331  g_loss:1.9271
# epoch:1135  d_loss:0.5047  g_loss:1.6781
# epoch:1136  d_loss:0.5651  g_loss:1.7701
# epoch:1137  d_loss:0.5149  g_loss:1.2899
# epoch:1138  d_loss:0.4599  g_loss:1.3286
# epoch:1139  d_loss:0.3743  g_loss:1.4513
# epoch:1140  d_loss:0.2675  g_loss:1.9942
# epoch:1141  d_loss:0.3969  g_loss:1.8224
# epoch:1142  d_loss:0.3639  g_loss:1.7849
# epoch:1143  d_loss:0.4401  g_loss:1.8942
# epoch:1144  d_loss:0.4421  g_loss:1.9887
# epoch:1145  d_loss:0.3235  g_loss:2.0538
# epoch:1146  d_loss:0.2916  g_loss:2.0194
# epoch:1147  d_loss:0.1993  g_loss:2.3887
# epoch:1148  d_loss:0.2565  g_loss:2.2032
# epoch:1149  d_loss:0.3116  g_loss:2.4282
# epoch:1150  d_loss:0.4109  g_loss:1.9246
# epoch:1151  d_loss:0.3168  g_loss:1.9559
# epoch:1152  d_loss:0.3515  g_loss:1.9227
# epoch:1153  d_loss:0.5305  g_loss:1.8129
# epoch:1154  d_loss:0.2701  g_loss:2.4290
# epoch:1155  d_loss:0.3151  g_loss:2.1132
# epoch:1156  d_loss:0.3123  g_loss:2.2955
# epoch:1157  d_loss:0.3245  g_loss:2.4138
# epoch:1158  d_loss:0.3427  g_loss:2.6859
# epoch:1159  d_loss:0.4387  g_loss:1.5709
# epoch:1160  d_loss:0.4391  g_loss:1.7799
# epoch:1161  d_loss:0.3760  g_loss:2.4522
# epoch:1162  d_loss:0.2863  g_loss:2.7520
# epoch:1163  d_loss:0.4506  g_loss:2.5758
# epoch:1164  d_loss:0.5095  g_loss:2.0651
# epoch:1165  d_loss:0.3895  g_loss:1.6078
# epoch:1166  d_loss:0.5595  g_loss:1.5898
# epoch:1167  d_loss:0.3852  g_loss:1.7868
# epoch:1168  d_loss:0.3945  g_loss:2.0679
# epoch:1169  d_loss:0.4943  g_loss:2.3145
# epoch:1170  d_loss:0.4579  g_loss:1.9505
# epoch:1171  d_loss:0.5183  g_loss:1.5820
# epoch:1172  d_loss:0.5931  g_loss:1.6585
# epoch:1173  d_loss:0.4831  g_loss:1.7376
# epoch:1174  d_loss:0.3482  g_loss:1.6529
# epoch:1175  d_loss:0.4720  g_loss:1.7625
# epoch:1176  d_loss:0.5560  g_loss:1.9816
# epoch:1177  d_loss:0.5116  g_loss:1.6156
# epoch:1178  d_loss:0.4272  g_loss:1.5911
# ...
# epoch:3620  d_loss:0.5061  g_loss:1.4667
# epoch:3621  d_loss:0.4703  g_loss:1.0725
# epoch:3622  d_loss:0.3966  g_loss:1.5422
# epoch:3623  d_loss:0.4751  g_loss:1.4968
# epoch:3624  d_loss:0.3902  g_loss:1.7915
# epoch:3625  d_loss:0.6016  g_loss:1.6984
# epoch:3626  d_loss:0.4269  g_loss:1.8210
# epoch:3627  d_loss:0.6880  g_loss:1.5242
# epoch:3628  d_loss:0.6919  g_loss:1.2831
# epoch:3629  d_loss:0.6019  g_loss:1.5346
# epoch:3630  d_loss:0.4944  g_loss:1.5583
# epoch:3631  d_loss:0.5137  g_loss:1.4343
# epoch:3632  d_loss:0.4802  g_loss:1.6367
# epoch:3633  d_loss:0.4279  g_loss:1.3921
# epoch:3634  d_loss:0.4056  g_loss:1.5404
# epoch:3635  d_loss:0.5571  g_loss:1.5543
# epoch:3636  d_loss:0.4997  g_loss:1.3119
# epoch:3637  d_loss:0.6078  g_loss:1.6270
# epoch:3638  d_loss:0.5282  g_loss:1.4597
# epoch:3639  d_loss:0.5726  g_loss:1.6334
# epoch:3640  d_loss:0.4857  g_loss:1.4984
# epoch:3641  d_loss:0.4420  g_loss:1.5311
# epoch:3642  d_loss:0.5440  g_loss:1.3918
# epoch:3643  d_loss:0.5368  g_loss:1.4917
# epoch:3644  d_loss:0.4544  g_loss:1.9667
# epoch:3645  d_loss:0.4521  g_loss:1.5248
# epoch:3646  d_loss:0.4555  g_loss:1.7080
# epoch:3647  d_loss:0.3896  g_loss:1.5619
# epoch:3648  d_loss:0.3554  g_loss:1.8197
# epoch:3649  d_loss:0.4976  g_loss:1.6245
# epoch:3650  d_loss:0.3789  g_loss:1.7640
# epoch:3651  d_loss:0.4568  g_loss:1.4780
# epoch:3652  d_loss:0.4724  g_loss:1.3789
# epoch:3653  d_loss:0.4865  g_loss:1.6699
# epoch:3654  d_loss:0.4561  g_loss:1.6057
# epoch:3655  d_loss:0.4609  g_loss:1.6028
# epoch:3656  d_loss:0.4915  g_loss:1.3400
# epoch:3657  d_loss:0.5796  g_loss:1.4020
# epoch:3658  d_loss:0.5256  g_loss:1.5722
# epoch:3659  d_loss:0.4345  g_loss:1.7775
# epoch:3660  d_loss:0.3929  g_loss:1.9656
# epoch:3661  d_loss:0.4949  g_loss:1.9455
# epoch:3662  d_loss:0.4966  g_loss:1.3783
# epoch:3663  d_loss:0.4686  g_loss:1.9170
# epoch:3664  d_loss:0.5087  g_loss:1.6263
# epoch:3665  d_loss:0.3610  g_loss:1.7189
# epoch:3666  d_loss:0.6700  g_loss:1.2645
# epoch:3667  d_loss:0.6087  g_loss:1.2531
# epoch:3668  d_loss:0.4701  g_loss:1.6393
# epoch:3669  d_loss:0.5628  g_loss:1.5819
# epoch:3670  d_loss:0.5483  g_loss:1.5662
# epoch:3671  d_loss:0.6178  g_loss:1.3983
# epoch:3672  d_loss:0.6531  g_loss:1.5658
# epoch:3673  d_loss:0.5231  g_loss:1.4413
# epoch:3674  d_loss:0.5024  g_loss:1.6576
# epoch:3675  d_loss:0.4747  g_loss:1.4230
# epoch:3676  d_loss:0.6492  g_loss:1.3333
# epoch:3677  d_loss:0.5868  g_loss:1.3170
# epoch:3678  d_loss:0.5746  g_loss:1.3193
# epoch:3679  d_loss:0.5767  g_loss:1.2352
# epoch:3680  d_loss:0.4473  g_loss:1.5198
# epoch:3681  d_loss:0.4360  g_loss:1.6592
# epoch:3682  d_loss:0.5032  g_loss:1.1700
# epoch:3683  d_loss:0.5398  g_loss:1.3480
# epoch:3684  d_loss:0.4412  g_loss:1.4135
# epoch:3685  d_loss:0.4553  g_loss:1.5153
# epoch:3686  d_loss:0.5745  g_loss:2.0698
# epoch:3687  d_loss:0.4770  g_loss:1.9928
# epoch:3688  d_loss:0.5173  g_loss:1.5468
# epoch:3689  d_loss:0.4155  g_loss:1.6246
# epoch:3690  d_loss:0.3938  g_loss:1.3907
# epoch:3691  d_loss:0.6678  g_loss:1.3436
# epoch:3692  d_loss:0.3864  g_loss:1.4823
# epoch:3693  d_loss:0.3988  g_loss:1.8259
# epoch:3694  d_loss:0.3734  g_loss:1.6932
# epoch:3695  d_loss:0.4044  g_loss:1.5942
# epoch:3696  d_loss:0.5577  g_loss:1.4831
# epoch:3697  d_loss:0.4338  g_loss:1.6109
# epoch:3698  d_loss:0.4756  g_loss:1.5140
# epoch:3699  d_loss:0.3537  g_loss:1.8881
# epoch:3700  d_loss:0.5083  g_loss:1.9171
# epoch:3701  d_loss:0.5454  g_loss:1.8796
# epoch:3702  d_loss:0.4987  g_loss:1.6897
# epoch:3703  d_loss:0.4702  g_loss:1.8256
# epoch:3704  d_loss:0.4051  g_loss:1.4471
# epoch:3705  d_loss:0.6057  g_loss:1.3271
# epoch:3706  d_loss:0.4547  g_loss:1.5642
# epoch:3707  d_loss:0.4001  g_loss:1.5539
# epoch:3708  d_loss:0.4417  g_loss:1.9427
# epoch:3709  d_loss:0.4353  g_loss:1.9596
# epoch:3710  d_loss:0.5157  g_loss:1.7049
# epoch:3711  d_loss:0.5942  g_loss:1.2706
# epoch:3712  d_loss:0.4204  g_loss:1.4145
# epoch:3713  d_loss:0.4743  g_loss:1.2577
# epoch:3714  d_loss:0.4487  g_loss:1.7111
# epoch:3715  d_loss:0.4002  g_loss:2.0241
# epoch:3716  d_loss:0.4115  g_loss:2.1116
# epoch:3717  d_loss:0.4490  g_loss:1.9977
# epoch:3718  d_loss:0.5208  g_loss:1.9892
# epoch:3719  d_loss:0.4959  g_loss:1.3927
# epoch:3720  d_loss:0.6276  g_loss:1.2465
# epoch:3721  d_loss:0.5678  g_loss:1.2605
# epoch:3722  d_loss:0.5853  g_loss:1.2812
# epoch:3723  d_loss:0.3546  g_loss:1.6157
# epoch:3724  d_loss:0.5444  g_loss:2.0102
# epoch:3725  d_loss:0.4283  g_loss:2.2449
# epoch:3726  d_loss:0.5222  g_loss:1.9916
# epoch:3727  d_loss:0.7794  g_loss:1.3954
# epoch:3728  d_loss:0.6323  g_loss:0.9825
# epoch:3729  d_loss:0.3941  g_loss:1.6116
# epoch:3730  d_loss:0.4569  g_loss:1.5047
# epoch:3731  d_loss:0.5900  g_loss:1.6671
# epoch:3732  d_loss:0.5106  g_loss:1.6368
# epoch:3733  d_loss:0.3681  g_loss:1.9024
# epoch:3734  d_loss:0.4537  g_loss:1.8664
# epoch:3735  d_loss:0.6734  g_loss:1.5179
# epoch:3736  d_loss:0.3766  g_loss:1.8999
# epoch:3737  d_loss:0.5040  g_loss:1.5987
# epoch:3738  d_loss:0.4722  g_loss:1.2891
# epoch:3739  d_loss:0.6143  g_loss:1.5030
# epoch:3740  d_loss:0.5779  g_loss:1.4275
# epoch:3741  d_loss:0.4640  g_loss:1.2281
# epoch:3742  d_loss:0.5518  g_loss:1.3369
# epoch:3743  d_loss:0.4899  g_loss:1.4970
# epoch:3744  d_loss:0.4632  g_loss:1.6244
# epoch:3745  d_loss:0.5107  g_loss:1.7059
# epoch:3746  d_loss:0.4597  g_loss:1.4372
# epoch:3747  d_loss:0.4502  g_loss:1.7011
# epoch:3748  d_loss:0.5349  g_loss:1.5205
# epoch:3749  d_loss:0.6082  g_loss:1.6507
# epoch:3750  d_loss:0.4317  g_loss:1.7409
# epoch:3751  d_loss:0.4538  g_loss:1.4171
# epoch:3752  d_loss:0.5306  g_loss:1.6076
# epoch:3753  d_loss:0.5308  g_loss:1.6862
# epoch:3754  d_loss:0.3734  g_loss:1.6571
# epoch:3755  d_loss:0.5256  g_loss:1.8900
# epoch:3756  d_loss:0.4831  g_loss:1.4219
# epoch:3757  d_loss:0.4570  g_loss:1.6805
# epoch:3758  d_loss:0.4809  g_loss:1.7229
# epoch:3759  d_loss:0.4104  g_loss:1.9640
# epoch:3760  d_loss:0.4118  g_loss:1.9670
# epoch:3761  d_loss:0.3956  g_loss:1.7835
# epoch:3762  d_loss:0.5681  g_loss:1.5975
# epoch:3763  d_loss:0.6205  g_loss:1.2673
# epoch:3764  d_loss:0.4197  g_loss:1.8886
# epoch:3765  d_loss:0.5537  g_loss:1.4820
# epoch:3766  d_loss:0.3970  g_loss:2.0460
# epoch:3767  d_loss:0.5528  g_loss:1.6904
# epoch:3768  d_loss:0.4738  g_loss:1.4201
# epoch:3769  d_loss:0.5749  g_loss:1.4393
# epoch:3770  d_loss:0.4516  g_loss:1.7654
# epoch:3771  d_loss:0.5238  g_loss:1.6877
# epoch:3772  d_loss:0.4930  g_loss:1.6493
# epoch:3773  d_loss:0.5419  g_loss:1.6508
# epoch:3774  d_loss:0.5585  g_loss:1.3710
# epoch:3775  d_loss:0.4440  g_loss:1.4562
# epoch:3776  d_loss:0.4592  g_loss:1.4978
# epoch:3777  d_loss:0.4511  g_loss:1.5938
# epoch:3778  d_loss:0.4829  g_loss:2.0849
# epoch:3779  d_loss:0.4492  g_loss:2.1646
# epoch:3780  d_loss:0.6144  g_loss:1.3141
# epoch:3781  d_loss:0.5225  g_loss:1.3932
# epoch:3782  d_loss:0.3914  g_loss:1.8084
# epoch:3783  d_loss:0.4850  g_loss:1.7212
# epoch:3784  d_loss:0.5779  g_loss:1.8210
# epoch:3785  d_loss:0.3825  g_loss:1.7780
# epoch:3786  d_loss:0.3638  g_loss:1.8729
# epoch:3787  d_loss:0.5223  g_loss:1.7746
# epoch:3788  d_loss:0.4628  g_loss:1.7437
# epoch:3789  d_loss:0.4914  g_loss:1.8685
# epoch:3790  d_loss:0.5462  g_loss:1.5168
# epoch:3791  d_loss:0.4277  g_loss:1.3493
# epoch:3792  d_loss:0.6218  g_loss:1.4492
# epoch:3793  d_loss:0.3958  g_loss:1.5978
# epoch:3794  d_loss:0.4037  g_loss:1.7971
# epoch:3795  d_loss:0.4563  g_loss:2.4334
# epoch:3796  d_loss:0.4814  g_loss:1.9640
# epoch:3797  d_loss:0.5479  g_loss:2.0136
# epoch:3798  d_loss:0.6050  g_loss:1.6057
# epoch:3799  d_loss:0.5063  g_loss:1.1018
# epoch:3800  d_loss:0.6551  g_loss:0.9965
# epoch:3801  d_loss:0.5313  g_loss:1.4019
# epoch:3802  d_loss:0.3516  g_loss:1.4898
# epoch:3803  d_loss:0.5457  g_loss:2.0367
# epoch:3804  d_loss:0.5222  g_loss:1.8616
# epoch:3805  d_loss:0.5063  g_loss:2.1790
# epoch:3806  d_loss:0.6347  g_loss:1.6951
# epoch:3807  d_loss:0.6212  g_loss:1.2200
# epoch:3808  d_loss:0.3915  g_loss:1.2056
# epoch:3809  d_loss:0.5074  g_loss:1.5194
# epoch:3810  d_loss:0.5710  g_loss:1.5047
# epoch:3811  d_loss:0.3890  g_loss:1.8739
# epoch:3812  d_loss:0.4827  g_loss:1.8381
# epoch:3813  d_loss:0.5407  g_loss:1.8360
# epoch:3814  d_loss:0.4458  g_loss:1.7943
# epoch:3815  d_loss:0.5168  g_loss:1.9350
# epoch:3816  d_loss:0.4727  g_loss:1.9745
# epoch:3817  d_loss:0.3485  g_loss:1.9081
# epoch:3818  d_loss:0.3836  g_loss:1.6325
# epoch:3819  d_loss:0.4290  g_loss:2.1308
# epoch:3820  d_loss:0.2458  g_loss:2.1590
# epoch:3821  d_loss:0.4435  g_loss:1.9173
# epoch:3822  d_loss:0.3778  g_loss:2.1897
# epoch:3823  d_loss:0.4211  g_loss:1.5200
# epoch:3824  d_loss:0.4340  g_loss:1.5048
# epoch:3825  d_loss:0.6088  g_loss:1.0999
# epoch:3826  d_loss:0.4395  g_loss:1.6966
# epoch:3827  d_loss:0.4282  g_loss:2.1282
# epoch:3828  d_loss:0.4823  g_loss:2.2470
# epoch:3829  d_loss:0.4850  g_loss:2.0779
# epoch:3830  d_loss:0.5302  g_loss:2.0017
# epoch:3831  d_loss:0.6728  g_loss:1.6213
# epoch:3832  d_loss:0.4714  g_loss:1.4190
# epoch:3833  d_loss:0.5005  g_loss:1.4618
# epoch:3834  d_loss:0.6365  g_loss:1.1839
# epoch:3835  d_loss:0.4933  g_loss:1.8112
# epoch:3836  d_loss:0.5581  g_loss:2.1189
# epoch:3837  d_loss:0.7096  g_loss:1.7071
# epoch:3838  d_loss:0.5663  g_loss:1.1609
# epoch:3839  d_loss:0.6338  g_loss:1.2435
# epoch:3840  d_loss:0.6271  g_loss:1.1695
# epoch:3841  d_loss:0.5086  g_loss:1.5907
# epoch:3842  d_loss:0.4700  g_loss:1.6147
# epoch:3843  d_loss:0.5655  g_loss:1.7016
# epoch:3844  d_loss:0.5178  g_loss:1.5566
# epoch:3845  d_loss:0.4266  g_loss:1.4549
# epoch:3846  d_loss:0.6039  g_loss:1.5850
# epoch:3847  d_loss:0.5263  g_loss:1.2524
# epoch:3848  d_loss:0.4580  g_loss:1.5392
# epoch:3849  d_loss:0.4304  g_loss:1.8286
# epoch:3850  d_loss:0.4419  g_loss:2.0362
# epoch:3851  d_loss:0.4298  g_loss:1.7127
# epoch:3852  d_loss:0.3984  g_loss:1.9490
# epoch:3853  d_loss:0.2774  g_loss:2.1760
# epoch:3854  d_loss:0.4306  g_loss:1.7616
# epoch:3855  d_loss:0.4328  g_loss:2.2826
# epoch:3856  d_loss:0.4469  g_loss:2.1063
# epoch:3857  d_loss:0.5270  g_loss:1.6048
# epoch:3858  d_loss:0.3285  g_loss:2.0887
# epoch:3859  d_loss:0.5347  g_loss:1.6869
# epoch:3860  d_loss:0.3650  g_loss:1.8214
# epoch:3861  d_loss:0.3713  g_loss:2.3429
# epoch:3862  d_loss:0.4332  g_loss:2.3129
# epoch:3863  d_loss:0.4765  g_loss:2.5543
# epoch:3864  d_loss:0.5810  g_loss:2.0732
# epoch:3865  d_loss:0.6753  g_loss:1.9274
# epoch:3866  d_loss:0.6296  g_loss:1.6109
# epoch:3867  d_loss:0.5330  g_loss:1.8583
# epoch:3868  d_loss:0.5426  g_loss:1.8760
# epoch:3869  d_loss:0.4305  g_loss:2.0924
# epoch:3870  d_loss:0.4266  g_loss:2.0368
# epoch:3871  d_loss:0.5225  g_loss:1.7290
# epoch:3872  d_loss:0.5135  g_loss:1.4354
# epoch:3873  d_loss:0.5274  g_loss:1.5373
# epoch:3874  d_loss:0.5374  g_loss:1.5048
# epoch:3875  d_loss:0.4484  g_loss:1.4845
# epoch:3876  d_loss:0.5824  g_loss:1.5393
# epoch:3877  d_loss:0.7768  g_loss:1.7565
# epoch:3878  d_loss:0.4762  g_loss:2.0193
# epoch:3879  d_loss:0.4046  g_loss:2.0236
# epoch:3880  d_loss:0.5982  g_loss:1.7289
# epoch:3881  d_loss:0.6017  g_loss:1.3396
# epoch:3882  d_loss:0.5499  g_loss:1.4195
# epoch:3883  d_loss:0.4877  g_loss:1.6647
# epoch:3884  d_loss:0.3782  g_loss:1.4685
# epoch:3885  d_loss:0.4272  g_loss:1.8212
# epoch:3886  d_loss:0.3579  g_loss:1.8648
# epoch:3887  d_loss:0.4058  g_loss:2.3400
# epoch:3888  d_loss:0.3565  g_loss:2.2781
# epoch:3889  d_loss:0.5504  g_loss:1.7997
# epoch:3890  d_loss:0.4770  g_loss:1.7271
# epoch:3891  d_loss:0.4382  g_loss:1.5785
# epoch:3892  d_loss:0.3087  g_loss:1.7198
# epoch:3893  d_loss:0.3487  g_loss:1.9176
# epoch:3894  d_loss:0.2492  g_loss:2.4671
# epoch:3895  d_loss:0.5156  g_loss:1.9572
# epoch:3896  d_loss:0.3288  g_loss:2.3751
# epoch:3897  d_loss:0.4314  g_loss:1.7375
# epoch:3898  d_loss:0.4171  g_loss:1.8020
# epoch:3899  d_loss:0.2965  g_loss:2.1154
# epoch:3900  d_loss:0.5324  g_loss:1.8754
# epoch:3901  d_loss:0.4413  g_loss:2.5530
# epoch:3902  d_loss:0.4946  g_loss:2.1478
# epoch:3903  d_loss:0.4164  g_loss:1.7227
# epoch:3904  d_loss:0.4348  g_loss:1.9952
# epoch:3905  d_loss:0.5655  g_loss:1.8215
# epoch:3906  d_loss:0.4439  g_loss:2.0708
# epoch:3907  d_loss:0.4955  g_loss:2.3246
# epoch:3908  d_loss:0.4982  g_loss:2.0092
# epoch:3909  d_loss:0.4199  g_loss:1.8909
# epoch:3910  d_loss:0.4304  g_loss:1.9175
# epoch:3911  d_loss:0.6183  g_loss:1.6707
# epoch:3912  d_loss:0.5249  g_loss:2.0874
# epoch:3913  d_loss:0.6445  g_loss:1.2756
# epoch:3914  d_loss:0.4740  g_loss:1.5055
# epoch:3915  d_loss:0.5635  g_loss:1.6960
# epoch:3916  d_loss:0.7072  g_loss:1.7449
# epoch:3917  d_loss:0.7268  g_loss:1.4389
# epoch:3918  d_loss:0.5230  g_loss:1.3497
# epoch:3919  d_loss:0.4444  g_loss:1.8145
# epoch:3920  d_loss:0.5096  g_loss:1.5765
# epoch:3921  d_loss:0.8035  g_loss:1.6434
# epoch:3922  d_loss:0.4268  g_loss:1.9950
# epoch:3923  d_loss:0.3518  g_loss:2.0214
# epoch:3924  d_loss:0.4360  g_loss:1.9665
# epoch:3925  d_loss:0.3195  g_loss:2.3680
# epoch:3926  d_loss:0.4034  g_loss:1.8031
# epoch:3927  d_loss:0.3354  g_loss:2.2716
# epoch:3928  d_loss:0.3424  g_loss:2.0816
# epoch:3929  d_loss:0.4049  g_loss:1.9119
# epoch:3930  d_loss:0.4180  g_loss:1.9870
# epoch:3931  d_loss:0.3774  g_loss:2.2478
# epoch:3932  d_loss:0.4717  g_loss:1.9880
# epoch:3933  d_loss:0.3564  g_loss:2.4515
# epoch:3934  d_loss:0.3197  g_loss:2.4333
# epoch:3935  d_loss:0.4835  g_loss:2.0851
# epoch:3936  d_loss:0.4687  g_loss:1.8345
# epoch:3937  d_loss:0.4586  g_loss:1.8598
# epoch:3938  d_loss:0.4143  g_loss:1.9952
# epoch:3939  d_loss:0.4603  g_loss:2.2248
# epoch:3940  d_loss:0.4376  g_loss:2.4799
# epoch:3941  d_loss:0.4474  g_loss:1.6579
# epoch:3942  d_loss:0.5315  g_loss:2.1065
# epoch:3943  d_loss:0.4824  g_loss:2.2070
# epoch:3944  d_loss:0.5293  g_loss:1.9007
# epoch:3945  d_loss:0.4424  g_loss:1.8456
# epoch:3946  d_loss:0.4769  g_loss:2.0434
# epoch:3947  d_loss:0.4663  g_loss:1.7724
# epoch:3948  d_loss:0.4657  g_loss:2.0270
# epoch:3949  d_loss:0.5034  g_loss:1.6859
# epoch:3950  d_loss:0.4513  g_loss:2.0567
# epoch:3951  d_loss:0.4330  g_loss:1.8089
# epoch:3952  d_loss:0.4180  g_loss:1.8942
# epoch:3953  d_loss:0.6372  g_loss:1.8985
# epoch:3954  d_loss:0.5908  g_loss:1.7027
# epoch:3955  d_loss:0.5849  g_loss:1.8624
# epoch:3956  d_loss:0.4874  g_loss:2.1474
# epoch:3957  d_loss:0.5444  g_loss:1.8714
# epoch:3958  d_loss:0.4453  g_loss:2.3222
# epoch:3959  d_loss:0.3471  g_loss:1.9687
# epoch:3960  d_loss:0.5034  g_loss:1.7805
# epoch:3961  d_loss:0.5170  g_loss:1.4660
# epoch:3962  d_loss:0.4477  g_loss:1.8571
# epoch:3963  d_loss:0.4234  g_loss:2.0102
# epoch:3964  d_loss:0.3514  g_loss:1.9949
# epoch:3965  d_loss:0.3242  g_loss:1.6957
# epoch:3966  d_loss:0.4984  g_loss:1.4494
# epoch:3967  d_loss:0.3463  g_loss:2.0568
# epoch:3968  d_loss:0.4814  g_loss:1.9187
# epoch:3969  d_loss:0.4933  g_loss:2.2496
# epoch:3970  d_loss:0.3621  g_loss:1.8931
# epoch:3971  d_loss:0.4109  g_loss:1.8372
# epoch:3972  d_loss:0.5677  g_loss:1.7741
# epoch:3973  d_loss:0.4826  g_loss:1.2703
# epoch:3974  d_loss:0.6053  g_loss:1.3483
# epoch:3975  d_loss:0.4951  g_loss:1.4806
# epoch:3976  d_loss:0.5743  g_loss:1.8007
# epoch:3977  d_loss:0.6434  g_loss:1.4255
# epoch:3978  d_loss:0.5650  g_loss:1.5983
# epoch:3979  d_loss:0.6285  g_loss:1.7094
# epoch:3980  d_loss:0.5436  g_loss:1.5554
# epoch:3981  d_loss:0.5775  g_loss:1.8484
# epoch:3982  d_loss:0.5338  g_loss:1.8812
# epoch:3983  d_loss:0.4577  g_loss:1.7135
# epoch:3984  d_loss:0.5216  g_loss:1.8685
# epoch:3985  d_loss:0.4908  g_loss:1.5081
# epoch:3986  d_loss:0.4705  g_loss:1.6187
# epoch:3987  d_loss:0.4066  g_loss:2.0089
# epoch:3988  d_loss:0.2942  g_loss:2.0557
# epoch:3989  d_loss:0.3801  g_loss:2.0806
# epoch:3990  d_loss:0.5114  g_loss:2.1977
# epoch:3991  d_loss:0.4364  g_loss:2.2094
# epoch:3992  d_loss:0.3564  g_loss:2.1867
# epoch:3993  d_loss:0.3199  g_loss:1.7350
# epoch:3994  d_loss:0.4332  g_loss:2.0350
# epoch:3995  d_loss:0.3024  g_loss:2.4278
# epoch:3996  d_loss:0.3319  g_loss:2.2624
# epoch:3997  d_loss:0.4793  g_loss:2.4204
# epoch:3998  d_loss:0.4163  g_loss:1.9534
# epoch:3999  d_loss:0.5200  g_loss:1.9362
# epoch:4000  d_loss:0.5354  g_loss:1.8181
# C:\Users\gilbut\AppData\Local\Temp/ipykernel_14780/1818920397.py:87: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig, axs = plt.subplots(5, 5)

# %% [markdown]
# ## 4. 이미지의 특징을 추출하는 오토인코더

# %% [markdown]
# ### 실습: 오토인코더 실습하기

# %%
from tensorflow.keras.datasets import mnist
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Input, Dense, Conv2D, MaxPooling2D, UpSampling2D, Flatten, Reshape
import matplotlib.pyplot as plt
import numpy as np

# MNIST 데이터셋을 불러옵니다.

(X_train, _), (X_test, _) = mnist.load_data()
X_train = X_train.reshape(X_train.shape[0], 28, 28, 1).astype('float32') / 255
X_test = X_test.reshape(X_test.shape[0], 28, 28, 1).astype('float32') / 255

# 생성자 모델을 만듭니다.
autoencoder = Sequential()

# 인코딩 부분입니다.
autoencoder.add(Conv2D(16, kernel_size=3, padding='same', input_shape=(28,28,1), activation='relu'))
autoencoder.add(MaxPooling2D(pool_size=2, padding='same'))
autoencoder.add(Conv2D(8, kernel_size=3, activation='relu', padding='same'))
autoencoder.add(MaxPooling2D(pool_size=2, padding='same'))
autoencoder.add(Conv2D(8, kernel_size=3, strides=2, padding='same', activation='relu'))

# 디코딩 부분이 이어집니다. 
autoencoder.add(Conv2D(8, kernel_size=3, padding='same', activation='relu'))
autoencoder.add(UpSampling2D())
autoencoder.add(Conv2D(8, kernel_size=3, padding='same', activation='relu'))
autoencoder.add(UpSampling2D())
autoencoder.add(Conv2D(16, kernel_size=3, activation='relu'))
autoencoder.add(UpSampling2D())
autoencoder.add(Conv2D(1, kernel_size=3, padding='same', activation='sigmoid'))

# 전체 구조를 확인해 봅니다.
autoencoder.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_4 (Conv2D)            (None, 28, 28, 16)        160
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 14, 14, 16)        0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 14, 14, 8)         1160
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 7, 7, 8)           0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 4, 4, 8)           584
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 4, 4, 8)           584
# _________________________________________________________________
# up_sampling2d_2 (UpSampling2 (None, 8, 8, 8)           0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 8, 8, 8)           584
# _________________________________________________________________
# up_sampling2d_3 (UpSampling2 (None, 16, 16, 8)         0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 14, 14, 16)        1168
# _________________________________________________________________
# up_sampling2d_4 (UpSampling2 (None, 28, 28, 16)        0
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 28, 28, 1)         145
# =================================================================
# Total params: 4,385
# Trainable params: 4,385
# Non-trainable params: 0
# _________________________________________________________________

# %%
# 컴파일 및 학습을 하는 부분입니다.
autoencoder.compile(optimizer='adam', loss='binary_crossentropy')
autoencoder.fit(X_train, X_train, epochs=50, batch_size=128, validation_data=(X_test, X_test))

# 학습된 결과를 출력하는 부분입니다.
random_test = np.random.randint(X_test.shape[0], size=5)  # 테스트할 이미지를 랜덤하게 불러옵니다.
ae_imgs = autoencoder.predict(X_test)                     # 앞서 만든 오토인코더 모델에 집어 넣습니다.

plt.figure(figsize=(7, 2))                         # 출력될 이미지의 크기를 정합니다.

for i, image_idx in enumerate(random_test):       # 랜덤하게 뽑은 이미지를 차례로 나열합니다.
   ax = plt.subplot(2, 7, i + 1) 
   plt.imshow(X_test[image_idx].reshape(28, 28))   # 테스트할 이미지를 먼저 그대로 보여줍니다.
   ax.axis('off')
   ax = plt.subplot(2, 7, 7 + i +1)
   plt.imshow(ae_imgs[image_idx].reshape(28, 28)) # 오토인코딩 결과를 다음열에 출력합니다.
   ax.axis('off')
plt.show()
# Out:
# Epoch 1/50
# 469/469 [==============================] - 31s 66ms/step - loss: 0.2132 - val_loss: 0.1383
# Epoch 2/50
# 469/469 [==============================] - 31s 66ms/step - loss: 0.1271 - val_loss: 0.1165
# Epoch 3/50
# 469/469 [==============================] - 31s 66ms/step - loss: 0.1124 - val_loss: 0.1065
# Epoch 4/50
# 469/469 [==============================] - 33s 69ms/step - loss: 0.1052 - val_loss: 0.1020
# Epoch 5/50
# 469/469 [==============================] - 31s 65ms/step - loss: 0.1015 - val_loss: 0.0988
# Epoch 6/50
# 469/469 [==============================] - 30s 64ms/step - loss: 0.0992 - val_loss: 0.0970
# Epoch 7/50
# 469/469 [==============================] - 30s 64ms/step - loss: 0.0973 - val_loss: 0.0952
# Epoch 8/50
# 469/469 [==============================] - 30s 64ms/step - loss: 0.0958 - val_loss: 0.0939
# Epoch 9/50
# 469/469 [==============================] - 30s 65ms/step - loss: 0.0944 - val_loss: 0.0927
# Epoch 10/50
# 469/469 [==============================] - 30s 65ms/step - loss: 0.0932 - val_loss: 0.0917
# Epoch 11/50
# 469/469 [==============================] - 32s 67ms/step - loss: 0.0921 - val_loss: 0.0904
# Epoch 12/50
# 469/469 [==============================] - 30s 65ms/step - loss: 0.0911 - val_loss: 0.0896
# Epoch 13/50
# 469/469 [==============================] - 30s 65ms/step - loss: 0.0902 - val_loss: 0.0892
# Epoch 14/50
# 469/469 [==============================] - 30s 65ms/step - loss: 0.0895 - val_loss: 0.0880
# Epoch 15/50
# 469/469 [==============================] - 30s 65ms/step - loss: 0.0888 - val_loss: 0.0877
# Epoch 16/50
# 469/469 [==============================] - 30s 65ms/step - loss: 0.0882 - val_loss: 0.0868
# Epoch 17/50
# 469/469 [==============================] - 30s 65ms/step - loss: 0.0876 - val_loss: 0.0864
# Epoch 18/50
# 469/469 [==============================] - 31s 67ms/step - loss: 0.0872 - val_loss: 0.0863
# Epoch 19/50
# 469/469 [==============================] - 31s 66ms/step - loss: 0.0867 - val_loss: 0.0856
# Epoch 20/50
# 469/469 [==============================] - 32s 68ms/step - loss: 0.0863 - val_loss: 0.0851
# Epoch 21/50
# 469/469 [==============================] - 32s 69ms/step - loss: 0.0860 - val_loss: 0.0848
# Epoch 22/50
# 469/469 [==============================] - 32s 68ms/step - loss: 0.0857 - val_loss: 0.0850
# Epoch 23/50
# 469/469 [==============================] - 31s 67ms/step - loss: 0.0854 - val_loss: 0.0843
# Epoch 24/50
# 469/469 [==============================] - 31s 67ms/step - loss: 0.0851 - val_loss: 0.0841
# Epoch 25/50
# 469/469 [==============================] - 31s 67ms/step - loss: 0.0849 - val_loss: 0.0837
# Epoch 26/50
# 469/469 [==============================] - 32s 68ms/step - loss: 0.0846 - val_loss: 0.0839
# Epoch 27/50
# 469/469 [==============================] - 31s 67ms/step - loss: 0.0844 - val_loss: 0.0833
# Epoch 28/50
# 469/469 [==============================] - 32s 68ms/step - loss: 0.0842 - val_loss: 0.0833
# Epoch 29/50
# 469/469 [==============================] - 31s 65ms/step - loss: 0.0840 - val_loss: 0.0829
# Epoch 30/50
# 469/469 [==============================] - 32s 69ms/step - loss: 0.0839 - val_loss: 0.0827
# Epoch 31/50
# 469/469 [==============================] - 33s 71ms/step - loss: 0.0837 - val_loss: 0.0832
# Epoch 32/50
# 469/469 [==============================] - 34s 72ms/step - loss: 0.0836 - val_loss: 0.0826
# Epoch 33/50
# 469/469 [==============================] - 31s 65ms/step - loss: 0.0834 - val_loss: 0.0824
# Epoch 34/50
# 469/469 [==============================] - 31s 66ms/step - loss: 0.0833 - val_loss: 0.0824
# Epoch 35/50
# 469/469 [==============================] - 31s 66ms/step - loss: 0.0831 - val_loss: 0.0821
# Epoch 36/50
# 469/469 [==============================] - 31s 65ms/step - loss: 0.0830 - val_loss: 0.0820
# Epoch 37/50
# 469/469 [==============================] - 32s 68ms/step - loss: 0.0829 - val_loss: 0.0821
# Epoch 38/50
# 469/469 [==============================] - 32s 68ms/step - loss: 0.0828 - val_loss: 0.0818
# Epoch 39/50
# 469/469 [==============================] - 32s 68ms/step - loss: 0.0827 - val_loss: 0.0818
# Epoch 40/50
# 469/469 [==============================] - 31s 66ms/step - loss: 0.0826 - val_loss: 0.0815
# Epoch 41/50
# 469/469 [==============================] - 31s 67ms/step - loss: 0.0825 - val_loss: 0.0816
# Epoch 42/50
# 469/469 [==============================] - 32s 69ms/step - loss: 0.0824 - val_loss: 0.0815
# Epoch 43/50
# 469/469 [==============================] - 31s 66ms/step - loss: 0.0823 - val_loss: 0.0813
# Epoch 44/50
# 469/469 [==============================] - 31s 67ms/step - loss: 0.0822 - val_loss: 0.0812
# Epoch 45/50
# 469/469 [==============================] - 31s 67ms/step - loss: 0.0821 - val_loss: 0.0811
# Epoch 46/50
# 469/469 [==============================] - 32s 69ms/step - loss: 0.0820 - val_loss: 0.0811
# Epoch 47/50
# 469/469 [==============================] - 31s 66ms/step - loss: 0.0819 - val_loss: 0.0810
# Epoch 48/50
# 469/469 [==============================] - 31s 67ms/step - loss: 0.0818 - val_loss: 0.0810
# Epoch 49/50
# 469/469 [==============================] - 31s 66ms/step - loss: 0.0818 - val_loss: 0.0814
# Epoch 50/50
# 469/469 [==============================] - 31s 65ms/step - loss: 0.0817 - val_loss: 0.0806
